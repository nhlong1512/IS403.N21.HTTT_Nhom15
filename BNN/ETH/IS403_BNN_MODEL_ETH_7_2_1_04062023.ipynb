# %%
# 1. Import thư viện cần thiết
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# %%
# 2. Đọc file csv và gắn index với giá Close
df = pd.read_csv('ETH-USD.csv')
df1=df.reset_index()['Close']
plt.plot(df1)

# %%
# 3. Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
# 4. Chia train test
train_size = int(0.7 * len(df1))
test_size = int(0.2 * len(df1))
val_size = len(df1) - train_size - test_size

train_data = df1[:train_size]
test_data = df1[train_size:train_size+test_size]
val_data = df1[train_size+test_size:]
print(df1)
# Out:
# [[0.00770764]
#  [0.01073007]
#  [0.00947408]
#  ...
#  [0.35867187]
#  [0.35861566]
#  [0.36483649]]

# %%
#in shape của từng tập dư liệu train, test, val
print("Train shape: ",train_data.shape)
print("Test shape: ",test_data.shape)
print("Val shape: ",val_data.shape)
# Out:
# Train shape:  (1085, 1)
# Test shape:  (310, 1)
# Val shape:  (156, 1)

# %%
# 5. Hàm Create Dataset
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, X=0,1,2,3-----99   Y=100
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return numpy.array(dataX), numpy.array(dataY)

# %%
#6. Reshape into X=t,t+1,t+2..t+99 and Y=t+100
time_step = 2
X_train, y_train = create_dataset(train_data, time_step)
X_val, yval = create_dataset(val_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
# 7. Reshape input to be [samples, time steps, features] which is required for BNN
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)
X_val = X_val.reshape(X_val.shape[0],X_val.shape[1] , 1)

# %%
# 8. Import các thư viện cần thiết để xây dựng mô hình BNN (Bayesian Neural Network) với thư viện Keras
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
# Thư viện tensorflow_probability cung cấp các hàm cần thiết xây dựng BNN
import tensorflow_probability as tfp
# Thư viện tensorflow_probability.distributions cung cấp các phân phối xác suất cần thiết xây dựng BNN
tfd = tfp.distributions
# Thư viện tensorflow_probability.layers cung cấp các lớp cần thiết xây dựng BNN
tfpl = tfp.layers
# Thêm drop-out vào Model
from tensorflow.keras.layers import Dropout
# Thêm Adam ( Adaptive Moment Estimation)  vào model
from tensorflow.keras.optimizers import Adam
# Thêm Dense vào model
from tensorflow.keras.layers import Dense

# # Thêm flatten vào Model, flatten là một hàm được sử dụng để chuyển đổi một mảng nhiều chiều thành một mảng một chiều
# from tensorflow.keras.layers import Flatten

# Thêm early vào Model
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import Sequential

# %%
# 9. Define BNN Model
# Tạo một lớp phân phối Gaussian
class GaussianLayer(tfp.layers.DistributionLambda):
    def __init__(self, **kwargs):
        super(GaussianLayer, self).__init__(
            lambda t: tfp.distributions.Normal(loc=t, scale=1), **kwargs)

model = Sequential()
model.add(Dense(64, input_dim=X_train.shape[1]))

model.add(Dropout(0.2))
model.add(Dense(32))
model.add(Dropout(0.2))
model.add(Dense(16))
model.add(Dropout(0.2))
model.add(Dense(8))
model.add( GaussianLayer())
model.add(Dropout(0.2))
model.add(Dense(1))

# %%
# Compile model
model.compile(loss='mean_squared_error', optimizer=Adam(learning_rate=0.001))

# %%
# 11. Train model
early_stop = EarlyStopping(monitor='val_loss', patience=50)
history = model.fit(X_train, y_train, validation_data = (X_test, ytest), epochs=1000,batch_size=64, verbose=1,callbacks=[early_stop])
# sẽ dừng lại khi val_loss không còn giảm nữa sau 50 lần lặp, monitor là giá trị để theo dõi, ở đây là val_loss
# verbose=1 sẽ in ra thông tin khi dừng lại
# Out:
# Epoch 1/1000
# 17/17 [==============================] - 1s 10ms/step - loss: 2.6496 - val_loss: 2.0760
# Epoch 2/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 2.7379 - val_loss: 1.9500
# Epoch 3/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 2.3008 - val_loss: 1.8249
# Epoch 4/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 2.3743 - val_loss: 1.7945
# Epoch 5/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 2.2651 - val_loss: 1.6641
# Epoch 6/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 2.0008 - val_loss: 1.3580
# Epoch 7/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 2.0082 - val_loss: 1.2779
# Epoch 8/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 1.8560 - val_loss: 1.5987
# Epoch 9/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 1.7949 - val_loss: 1.5632
# Epoch 10/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 1.6440 - val_loss: 1.3832
# Epoch 11/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 1.6411 - val_loss: 1.2000
# Epoch 12/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 1.4688 - val_loss: 1.0215
# Epoch 13/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 1.4313 - val_loss: 1.1017
# Epoch 14/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 1.2681 - val_loss: 1.1836
# Epoch 15/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 1.2647 - val_loss: 0.8233
# Epoch 16/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 1.2778 - val_loss: 0.9915
# Epoch 17/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 1.1175 - val_loss: 0.8696
# Epoch 18/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 1.0885 - val_loss: 0.8318
# Epoch 19/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 1.0415 - val_loss: 0.7094
# Epoch 20/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.9372 - val_loss: 0.7285
# Epoch 21/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.8740 - val_loss: 0.6182
# Epoch 22/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.8270 - val_loss: 0.7146
# Epoch 23/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.7269 - val_loss: 0.6190
# Epoch 24/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.7260 - val_loss: 0.5964
# Epoch 25/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6726 - val_loss: 0.5705
# Epoch 26/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6977 - val_loss: 0.5044
# Epoch 27/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.5762 - val_loss: 0.4574
# Epoch 28/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.5847 - val_loss: 0.4939
# Epoch 29/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.5819 - val_loss: 0.4049
# Epoch 30/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4897 - val_loss: 0.3842
# Epoch 31/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4850 - val_loss: 0.3895
# Epoch 32/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4435 - val_loss: 0.3842
# Epoch 33/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4141 - val_loss: 0.3082
# Epoch 34/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3954 - val_loss: 0.2708
# Epoch 35/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3861 - val_loss: 0.2349
# Epoch 36/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3367 - val_loss: 0.2671
# Epoch 37/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.3133 - val_loss: 0.2642
# Epoch 38/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.3241 - val_loss: 0.2370
# Epoch 39/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2913 - val_loss: 0.2276
# Epoch 40/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2526 - val_loss: 0.2042
# Epoch 41/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2549 - val_loss: 0.1886
# Epoch 42/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2356 - val_loss: 0.1741
# Epoch 43/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2196 - val_loss: 0.1509
# Epoch 44/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1983 - val_loss: 0.1396
# Epoch 45/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2068 - val_loss: 0.1272
# Epoch 46/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1740 - val_loss: 0.1372
# Epoch 47/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1591 - val_loss: 0.1259
# Epoch 48/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1437 - val_loss: 0.1060
# Epoch 49/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1382 - val_loss: 0.1013
# Epoch 50/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1345 - val_loss: 0.0958
# Epoch 51/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1276 - val_loss: 0.0875
# Epoch 52/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1239 - val_loss: 0.0777
# Epoch 53/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1051 - val_loss: 0.0802
# Epoch 54/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1086 - val_loss: 0.0844
# Epoch 55/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0978 - val_loss: 0.0639
# Epoch 56/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0840 - val_loss: 0.0661
# Epoch 57/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0755 - val_loss: 0.0583
# Epoch 58/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0791 - val_loss: 0.0523
# Epoch 59/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0697 - val_loss: 0.0492
# Epoch 60/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0645 - val_loss: 0.0455
# Epoch 61/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0596 - val_loss: 0.0433
# Epoch 62/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0558 - val_loss: 0.0422
# Epoch 63/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0534 - val_loss: 0.0362
# Epoch 64/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0502 - val_loss: 0.0309
# Epoch 65/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0456 - val_loss: 0.0330
# Epoch 66/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0450 - val_loss: 0.0297
# Epoch 67/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0413 - val_loss: 0.0265
# Epoch 68/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0383 - val_loss: 0.0281
# Epoch 69/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0350 - val_loss: 0.0262
# Epoch 70/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0337 - val_loss: 0.0175
# Epoch 71/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0346 - val_loss: 0.0209
# Epoch 72/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0290 - val_loss: 0.0159
# Epoch 73/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0289 - val_loss: 0.0168
# Epoch 74/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0283 - val_loss: 0.0162
# Epoch 75/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0255 - val_loss: 0.0161
# Epoch 76/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0238 - val_loss: 0.0129
# Epoch 77/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0230 - val_loss: 0.0131
# Epoch 78/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0228 - val_loss: 0.0126
# Epoch 79/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0198 - val_loss: 0.0105
# Epoch 80/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0204 - val_loss: 0.0109
# Epoch 81/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0177 - val_loss: 0.0105
# Epoch 82/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0162 - val_loss: 0.0104
# Epoch 83/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0182 - val_loss: 0.0089
# Epoch 84/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0169 - val_loss: 0.0082
# Epoch 85/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0152 - val_loss: 0.0064
# Epoch 86/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0162 - val_loss: 0.0078
# Epoch 87/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0132 - val_loss: 0.0089
# Epoch 88/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0122 - val_loss: 0.0056
# Epoch 89/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0127 - val_loss: 0.0075
# Epoch 90/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0150 - val_loss: 0.0056
# Epoch 91/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0148 - val_loss: 0.0062
# Epoch 92/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0124 - val_loss: 0.0064
# Epoch 93/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0127 - val_loss: 0.0053
# Epoch 94/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0121 - val_loss: 0.0048
# Epoch 95/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0108 - val_loss: 0.0054
# Epoch 96/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0117 - val_loss: 0.0041
# Epoch 97/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0107 - val_loss: 0.0053
# Epoch 98/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0108 - val_loss: 0.0046
# Epoch 99/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0106 - val_loss: 0.0039
# Epoch 100/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0105 - val_loss: 0.0052
# Epoch 101/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0097 - val_loss: 0.0038
# Epoch 102/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0095 - val_loss: 0.0035
# Epoch 103/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0097 - val_loss: 0.0040
# Epoch 104/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0099 - val_loss: 0.0024
# Epoch 105/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0093 - val_loss: 0.0034
# Epoch 106/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0087 - val_loss: 0.0036
# Epoch 107/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0107 - val_loss: 0.0031
# Epoch 108/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0091 - val_loss: 0.0033
# Epoch 109/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0085 - val_loss: 0.0029
# Epoch 110/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0091 - val_loss: 0.0030
# Epoch 111/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0094 - val_loss: 0.0025
# Epoch 112/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0080 - val_loss: 0.0028
# Epoch 113/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0087 - val_loss: 0.0027
# Epoch 114/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0095 - val_loss: 0.0033
# Epoch 115/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0087 - val_loss: 0.0023
# Epoch 116/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0078 - val_loss: 0.0036
# Epoch 117/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0083 - val_loss: 0.0028
# Epoch 118/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0089 - val_loss: 0.0028
# Epoch 119/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0083 - val_loss: 0.0024
# Epoch 120/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0080 - val_loss: 0.0016
# Epoch 121/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0083 - val_loss: 0.0024
# Epoch 122/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0072 - val_loss: 0.0038
# Epoch 123/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0085 - val_loss: 0.0020
# Epoch 124/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0075 - val_loss: 0.0039
# Epoch 125/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0082 - val_loss: 0.0035
# Epoch 126/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0081 - val_loss: 0.0021
# Epoch 127/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0086 - val_loss: 0.0027
# Epoch 128/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0079 - val_loss: 0.0020
# Epoch 129/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0070 - val_loss: 0.0020
# Epoch 130/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0078 - val_loss: 0.0021
# Epoch 131/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0079 - val_loss: 0.0026
# Epoch 132/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0084 - val_loss: 0.0027
# Epoch 133/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0071 - val_loss: 0.0027
# Epoch 134/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0088 - val_loss: 0.0024
# Epoch 135/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0073 - val_loss: 0.0032
# Epoch 136/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0081 - val_loss: 0.0016
# Epoch 137/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0077 - val_loss: 0.0017
# Epoch 138/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0071 - val_loss: 0.0027
# Epoch 139/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0068 - val_loss: 0.0032
# Epoch 140/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0077 - val_loss: 0.0016
# Epoch 141/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0083 - val_loss: 0.0022
# Epoch 142/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0074 - val_loss: 0.0015
# Epoch 143/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0075 - val_loss: 0.0020
# Epoch 144/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0077 - val_loss: 0.0042
# Epoch 145/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0071 - val_loss: 0.0017
# Epoch 146/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0066 - val_loss: 0.0022
# Epoch 147/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0065 - val_loss: 0.0016
# Epoch 148/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0073 - val_loss: 0.0019
# Epoch 149/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0068 - val_loss: 0.0044
# Epoch 150/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0071 - val_loss: 0.0033
# Epoch 151/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0077 - val_loss: 0.0035
# Epoch 152/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0069 - val_loss: 0.0021
# Epoch 153/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0075 - val_loss: 0.0013
# Epoch 154/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0060 - val_loss: 0.0013
# Epoch 155/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0069 - val_loss: 0.0013
# Epoch 156/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0068 - val_loss: 0.0013
# Epoch 157/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0074 - val_loss: 0.0013
# Epoch 158/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0068 - val_loss: 0.0014
# Epoch 159/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0065 - val_loss: 0.0017
# Epoch 160/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0072 - val_loss: 0.0024
# Epoch 161/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0056 - val_loss: 0.0011
# Epoch 162/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0082 - val_loss: 0.0013
# Epoch 163/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0075 - val_loss: 0.0011
# Epoch 164/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0060 - val_loss: 0.0012
# Epoch 165/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0068 - val_loss: 0.0014
# Epoch 166/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0061 - val_loss: 0.0014
# Epoch 167/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0071 - val_loss: 0.0030
# Epoch 168/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0069 - val_loss: 0.0022
# Epoch 169/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0066 - val_loss: 0.0034
# Epoch 170/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0069 - val_loss: 0.0028
# Epoch 171/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0070 - val_loss: 0.0024
# Epoch 172/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0052 - val_loss: 0.0026
# Epoch 173/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0063 - val_loss: 0.0034
# Epoch 174/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0072 - val_loss: 0.0050
# Epoch 175/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0068 - val_loss: 0.0040
# Epoch 176/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0062 - val_loss: 0.0027
# Epoch 177/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0060 - val_loss: 0.0015
# Epoch 178/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0057 - val_loss: 0.0018
# Epoch 179/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0059 - val_loss: 0.0011
# Epoch 180/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0066 - val_loss: 0.0012
# Epoch 181/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0066 - val_loss: 0.0015
# Epoch 182/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0061 - val_loss: 0.0017
# Epoch 183/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0075 - val_loss: 0.0062
# Epoch 184/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0081 - val_loss: 0.0079
# Epoch 185/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0073 - val_loss: 0.0037
# Epoch 186/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0059 - val_loss: 0.0016
# Epoch 187/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0065 - val_loss: 0.0015
# Epoch 188/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0061 - val_loss: 0.0020
# Epoch 189/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0067 - val_loss: 0.0012
# Epoch 190/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0066 - val_loss: 0.0012
# Epoch 191/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0056 - val_loss: 0.0036
# Epoch 192/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0061 - val_loss: 0.0038
# Epoch 193/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0059 - val_loss: 0.0040
# Epoch 194/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0055 - val_loss: 0.0014
# Epoch 195/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0064 - val_loss: 0.0019
# Epoch 196/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0066 - val_loss: 0.0012
# Epoch 197/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0064 - val_loss: 0.0011
# Epoch 198/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0066 - val_loss: 0.0014
# Epoch 199/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0065 - val_loss: 0.0011
# Epoch 200/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0059 - val_loss: 0.0013
# Epoch 201/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0067 - val_loss: 0.0026
# Epoch 202/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0057 - val_loss: 0.0021
# Epoch 203/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0057 - val_loss: 0.0015
# Epoch 204/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0054 - val_loss: 0.0014
# Epoch 205/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0066 - val_loss: 0.0031
# Epoch 206/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0062 - val_loss: 0.0020
# Epoch 207/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0064 - val_loss: 0.0015
# Epoch 208/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0060 - val_loss: 0.0020
# Epoch 209/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0062 - val_loss: 0.0012
# Epoch 210/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0056 - val_loss: 0.0012
# Epoch 211/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0065 - val_loss: 0.0015
# Epoch 212/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0060 - val_loss: 0.0012
# Epoch 213/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0057 - val_loss: 0.0016
# Epoch 214/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0064 - val_loss: 9.8575e-04
# Epoch 215/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0058 - val_loss: 0.0022
# Epoch 216/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0057 - val_loss: 0.0012
# Epoch 217/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0068 - val_loss: 0.0021
# Epoch 218/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0062 - val_loss: 0.0012
# Epoch 219/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0059 - val_loss: 0.0012
# Epoch 220/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0065 - val_loss: 0.0018
# Epoch 221/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0064 - val_loss: 0.0011
# Epoch 222/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0057 - val_loss: 9.7279e-04
# Epoch 223/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0057 - val_loss: 9.6645e-04
# Epoch 224/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0056 - val_loss: 9.6854e-04
# Epoch 225/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0068 - val_loss: 0.0021
# Epoch 226/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0059 - val_loss: 0.0021
# Epoch 227/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0061 - val_loss: 0.0015
# Epoch 228/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0063 - val_loss: 0.0011
# Epoch 229/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0055 - val_loss: 9.9889e-04
# Epoch 230/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0068 - val_loss: 0.0010
# Epoch 231/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0064 - val_loss: 0.0013
# Epoch 232/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0057 - val_loss: 0.0020
# Epoch 233/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0055 - val_loss: 0.0012
# Epoch 234/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0064 - val_loss: 0.0038
# Epoch 235/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0071 - val_loss: 9.0589e-04
# Epoch 236/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0060 - val_loss: 0.0010
# Epoch 237/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0067 - val_loss: 0.0012
# Epoch 238/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0060 - val_loss: 0.0011
# Epoch 239/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0065 - val_loss: 0.0010
# Epoch 240/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0058 - val_loss: 0.0027
# Epoch 241/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0072 - val_loss: 9.7343e-04
# Epoch 242/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0060 - val_loss: 0.0033
# Epoch 243/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0072 - val_loss: 0.0021
# Epoch 244/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0067 - val_loss: 0.0010
# Epoch 245/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0061 - val_loss: 0.0010
# Epoch 246/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0057 - val_loss: 0.0011
# Epoch 247/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0060 - val_loss: 0.0014
# Epoch 248/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0067 - val_loss: 0.0018
# Epoch 249/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0063 - val_loss: 0.0012
# Epoch 250/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0051 - val_loss: 9.5751e-04
# Epoch 251/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0059 - val_loss: 9.4309e-04
# Epoch 252/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0059 - val_loss: 0.0010
# Epoch 253/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0066 - val_loss: 9.0507e-04
# Epoch 254/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0056 - val_loss: 0.0011
# Epoch 255/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0058 - val_loss: 0.0011
# Epoch 256/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0061 - val_loss: 0.0021
# Epoch 257/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0061 - val_loss: 0.0011
# Epoch 258/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0062 - val_loss: 9.7344e-04
# Epoch 259/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0064 - val_loss: 9.9130e-04
# Epoch 260/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0064 - val_loss: 9.3879e-04
# Epoch 261/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0056 - val_loss: 0.0019
# Epoch 262/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0053 - val_loss: 0.0012
# Epoch 263/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0059 - val_loss: 8.7375e-04
# Epoch 264/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0052 - val_loss: 9.5098e-04
# Epoch 265/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0053 - val_loss: 0.0011
# Epoch 266/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0055 - val_loss: 0.0013
# Epoch 267/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0056 - val_loss: 0.0013
# Epoch 268/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0055 - val_loss: 0.0014
# Epoch 269/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0054 - val_loss: 8.5960e-04
# Epoch 270/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0063 - val_loss: 0.0017
# Epoch 271/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0054 - val_loss: 0.0011
# Epoch 272/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0061 - val_loss: 9.5621e-04
# Epoch 273/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0068 - val_loss: 0.0010
# Epoch 274/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0053 - val_loss: 0.0012
# Epoch 275/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0054 - val_loss: 8.5547e-04
# Epoch 276/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0063 - val_loss: 0.0011
# Epoch 277/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0066 - val_loss: 9.9419e-04
# Epoch 278/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0056 - val_loss: 9.5863e-04
# Epoch 279/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0054 - val_loss: 7.9971e-04
# Epoch 280/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0057 - val_loss: 0.0019
# Epoch 281/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0059 - val_loss: 0.0029
# Epoch 282/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0067 - val_loss: 9.8266e-04
# Epoch 283/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0061 - val_loss: 9.6651e-04
# Epoch 284/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0058 - val_loss: 9.0236e-04
# Epoch 285/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0058 - val_loss: 0.0010
# Epoch 286/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0062 - val_loss: 9.4908e-04
# Epoch 287/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0059 - val_loss: 0.0012
# Epoch 288/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0053 - val_loss: 8.2433e-04
# Epoch 289/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0055 - val_loss: 8.7274e-04
# Epoch 290/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0046 - val_loss: 7.4457e-04
# Epoch 291/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0052 - val_loss: 9.8461e-04
# Epoch 292/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0055 - val_loss: 0.0011
# Epoch 293/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0054 - val_loss: 0.0016
# Epoch 294/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0051 - val_loss: 9.3727e-04
# Epoch 295/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0052 - val_loss: 7.7646e-04
# Epoch 296/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0057 - val_loss: 0.0018
# Epoch 297/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0057 - val_loss: 0.0011
# Epoch 298/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0057 - val_loss: 9.3679e-04
# Epoch 299/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0057 - val_loss: 0.0014
# Epoch 300/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0062 - val_loss: 8.6908e-04
# Epoch 301/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0057 - val_loss: 9.8302e-04
# Epoch 302/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0052 - val_loss: 0.0013
# Epoch 303/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0060 - val_loss: 0.0028
# Epoch 304/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0056 - val_loss: 0.0018
# Epoch 305/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0061 - val_loss: 0.0012
# Epoch 306/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0056 - val_loss: 8.8870e-04
# Epoch 307/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0054 - val_loss: 0.0012
# Epoch 308/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0055 - val_loss: 0.0010
# Epoch 309/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0055 - val_loss: 0.0019
# Epoch 310/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0050 - val_loss: 0.0012
# Epoch 311/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0059 - val_loss: 0.0036
# Epoch 312/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0058 - val_loss: 0.0012
# Epoch 313/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0060 - val_loss: 7.6310e-04
# Epoch 314/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0052 - val_loss: 9.7903e-04
# Epoch 315/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0064 - val_loss: 0.0057
# Epoch 316/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0067 - val_loss: 7.3719e-04
# Epoch 317/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0050 - val_loss: 7.9595e-04
# Epoch 318/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0048 - val_loss: 8.2899e-04
# Epoch 319/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0056 - val_loss: 9.1900e-04
# Epoch 320/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0053 - val_loss: 9.1191e-04
# Epoch 321/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0059 - val_loss: 8.4105e-04
# Epoch 322/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0062 - val_loss: 0.0025
# Epoch 323/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0057 - val_loss: 0.0010
# Epoch 324/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0052 - val_loss: 0.0014
# Epoch 325/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0054 - val_loss: 8.5536e-04
# Epoch 326/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0052 - val_loss: 0.0019
# Epoch 327/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0065 - val_loss: 0.0016
# Epoch 328/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0065 - val_loss: 0.0011
# Epoch 329/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0057 - val_loss: 8.3687e-04
# Epoch 330/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0059 - val_loss: 0.0017
# Epoch 331/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0054 - val_loss: 8.9174e-04
# Epoch 332/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0049 - val_loss: 8.8736e-04
# Epoch 333/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0056 - val_loss: 8.9744e-04
# Epoch 334/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0057 - val_loss: 0.0019
# Epoch 335/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0060 - val_loss: 0.0013
# Epoch 336/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0060 - val_loss: 9.3175e-04
# Epoch 337/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0056 - val_loss: 0.0017
# Epoch 338/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0063 - val_loss: 9.9384e-04
# Epoch 339/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0060 - val_loss: 0.0010
# Epoch 340/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0053 - val_loss: 7.9451e-04
# Epoch 341/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0056 - val_loss: 7.1721e-04
# Epoch 342/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0057 - val_loss: 0.0016
# Epoch 343/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0054 - val_loss: 8.0993e-04
# Epoch 344/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0055 - val_loss: 0.0016
# Epoch 345/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0070 - val_loss: 0.0016
# Epoch 346/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0056 - val_loss: 7.5471e-04
# Epoch 347/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0051 - val_loss: 0.0016
# Epoch 348/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0056 - val_loss: 8.1160e-04
# Epoch 349/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0055 - val_loss: 9.7088e-04
# Epoch 350/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0057 - val_loss: 9.4248e-04
# Epoch 351/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0059 - val_loss: 8.9521e-04
# Epoch 352/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0060 - val_loss: 0.0015
# Epoch 353/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0056 - val_loss: 0.0012
# Epoch 354/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0055 - val_loss: 7.8631e-04
# Epoch 355/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0062 - val_loss: 0.0019
# Epoch 356/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0057 - val_loss: 8.2743e-04
# Epoch 357/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0049 - val_loss: 8.1620e-04
# Epoch 358/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0066 - val_loss: 9.7005e-04
# Epoch 359/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0059 - val_loss: 9.0734e-04
# Epoch 360/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0060 - val_loss: 0.0048
# Epoch 361/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0063 - val_loss: 0.0026
# Epoch 362/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0058 - val_loss: 8.4625e-04
# Epoch 363/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0069 - val_loss: 0.0017
# Epoch 364/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0055 - val_loss: 0.0018
# Epoch 365/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0055 - val_loss: 8.3565e-04
# Epoch 366/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0053 - val_loss: 8.1086e-04
# Epoch 367/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0058 - val_loss: 0.0021
# Epoch 368/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0060 - val_loss: 0.0019
# Epoch 369/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0061 - val_loss: 8.8183e-04
# Epoch 370/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0060 - val_loss: 0.0010
# Epoch 371/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0059 - val_loss: 0.0012
# Epoch 372/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0054 - val_loss: 8.5196e-04
# Epoch 373/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0058 - val_loss: 0.0014
# Epoch 374/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0062 - val_loss: 8.4030e-04
# Epoch 375/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0066 - val_loss: 0.0025
# Epoch 376/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0049 - val_loss: 0.0015
# Epoch 377/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0056 - val_loss: 9.5744e-04
# Epoch 378/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0051 - val_loss: 8.0637e-04
# Epoch 379/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0052 - val_loss: 9.7938e-04
# Epoch 380/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0054 - val_loss: 0.0014
# Epoch 381/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0055 - val_loss: 0.0018
# Epoch 382/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0052 - val_loss: 0.0010
# Epoch 383/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0055 - val_loss: 9.3330e-04
# Epoch 384/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0062 - val_loss: 0.0033
# Epoch 385/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0068 - val_loss: 0.0020
# Epoch 386/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0055 - val_loss: 0.0012
# Epoch 387/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0048 - val_loss: 9.2735e-04
# Epoch 388/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0048 - val_loss: 9.5125e-04
# Epoch 389/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0057 - val_loss: 9.8747e-04
# Epoch 390/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0052 - val_loss: 0.0011
# Epoch 391/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0054 - val_loss: 0.0020

# %%
# 12. Dự báo dữ liệu test, val
train_predict=model.predict(X_train)
y_pred=model.predict(X_test)
y_pred_val=model.predict(X_val)

# In shape của từng tập dư liệu
print(train_predict.shape, y_pred.shape, y_pred_val.shape)
# Out:
# 34/34 [==============================] - 0s 914us/step
# 10/10 [==============================] - 0s 1ms/step
# 5/5 [==============================] - 0s 2ms/step
# (1082, 1) (307, 1) (153, 1)

# %%
# 13. In shape của từng tập dư liệu y real
print(y_train.shape, ytest.shape, yval.shape)
# Out:
# (1082,) (307,) (153,)

# %%
# 14. Chuẩn hóa dữ liệu y_pred, y_pred_val
train_predict=scaler.inverse_transform(train_predict)
y_pred=scaler.inverse_transform(y_pred)
y_pred_val=scaler.inverse_transform(y_pred_val)

# in head
print(train_predict[:5])
# Out:
# [[324.44205]
#  [335.4413 ]
#  [356.62292]
#  [289.3131 ]
#  [261.7051 ]]

# %%
# 15. Chuẩn hóa ngược lại yval và ytest và y_train sau khi đã reshape
y_train = y_train.reshape(y_train.shape[0],1)
ytest = ytest.reshape(ytest.shape[0],1)
yval = yval.reshape(yval.shape[0],1)

y_train=scaler.inverse_transform(y_train)
ytest=scaler.inverse_transform(ytest)
yval=scaler.inverse_transform(yval)

#in head
print(y_train[:5])
# Out:
# [[149.13501 ]
#  [154.58194 ]
#  [155.638596]
#  [157.746201]
#  [151.699219]]

# %%
# 16. Đánh giá độ chính xác thuật toán bằng MAE va RMSE
import math
from sklearn.metrics import mean_squared_error, mean_absolute_error


print('Train Mean Absolute Error:', mean_absolute_error(y_train, train_predict[:,0]))
print('Test Mean Absolute Error:', mean_absolute_error(ytest, y_pred[:,0]))
print('Val Mean Absolute Error:', mean_absolute_error(yval, y_pred_val[:,0]))
print('Train Root Mean Squared Error:',np.sqrt(mean_squared_error(y_train, train_predict[:,0])))
print('Test Root Mean Squared Error:',np.sqrt(mean_squared_error(ytest, y_pred[:,0])))
print('Val Root Mean Squared Error:',np.sqrt(mean_squared_error(yval, y_pred_val[:,0])))
# Out:
# Train Mean Absolute Error: 177.76379704351075
# Test Mean Absolute Error: 161.0072337820643
# Val Mean Absolute Error: 76.01333040466707
# Train Root Mean Squared Error: 222.39573916522136
# Test Root Mean Squared Error: 210.47118015171233
# Val Root Mean Squared Error: 97.12909466402593

# %%
# 17. Đánh giá model bằng MAPE
def mean_absolute_percentage_error(y_true, y_pred):
    return numpy.mean(numpy.abs((y_true - y_pred) / y_true)) * 100

print('Train Mean Absolute Percentage Error:', mean_absolute_percentage_error(y_train[:,0], train_predict[:,0]))
print('Test Mean Absolute Percentage Error:', mean_absolute_percentage_error(ytest[:,0], y_pred[:,0]))
print('Val Mean Absolute Percentage Error:', mean_absolute_percentage_error(yval[:,0], y_pred_val[:,0]))
print('Train Score: %.2f MAPE' % (mean_absolute_percentage_error(y_train[:,0], train_predict[:,0])))
print('Test Score: %.2f MAPE' % (mean_absolute_percentage_error(ytest[:,0], y_pred[:,0])))
print('Val Score: %.2f MAPE' % (mean_absolute_percentage_error(yval[:,0], y_pred_val[:,0])))
# Out:
# Train Mean Absolute Percentage Error: 51.56789943186689
# Test Mean Absolute Percentage Error: 6.743577477303117
# Val Mean Absolute Percentage Error: 5.21059494698983
# Train Score: 51.57 MAPE
# Test Score: 6.74 MAPE
# Val Score: 5.21 MAPE

# %%
# 18. Lấy time_step ngày cuối cùng của dữ liệu train để dự đoán 30 ngày tiếp theo
x_input = val_data[-time_step:].reshape(-1, 1)   #[-time_step:] lấy time_step phần tử cuối cùng của dữ liệu
print("x_input.shape = ", x_input.shape)

# Dự đoán 30 ngày tiếp theo
lst_output = []

i = 1  # Biến đếm để dừng vòng lặp while
while(i <= 30):
    print("-----------------")
    # Đưa về mảng 1 chiều
    list_input = x_input.reshape(1, -1)[0]
    # in ra x_input của ngày thứ i trong 30 ngày tiếp theo
    print("day ", i, " have input = ", list_input)

    # Dự đoán giá đóng của ngày tiếp theo
    x_input = x_input.reshape(1, time_step, 1) # reshape lại về dạng (1, time_step, 1)
    yhat = model.predict(x_input, verbose=0) # dự đoán giá đóng của ngày tiếp theo

    # in ra giá đóng của ngày thứ i trong 30 ngày tiếp theo
    print("day ",i," have output = ", yhat[0][0])

    # thêm giá đóng của ngày thứ i vào lst_output
    lst_output.append(yhat[0][0])

    # Xóa phần tử đầu tiên x_input
    x_input = np.delete(x_input, 0)
    # thêm yhat vào x_input
    x_input = np.append(x_input, yhat[0][0])
    # Tăng biến đếm lên 1
    i = i + 1
# Out:
# x_input.shape =  (2, 1)
# -----------------
# day  1  have input =  [0.35861566 0.36483649]
# day  1  have output =  0.3496877
# -----------------
# day  2  have input =  [0.36483649 0.3496877 ]
# day  2  have output =  0.35122192
# -----------------
# day  3  have input =  [0.3496877  0.35122192]
# day  3  have output =  0.34873652
# -----------------
# day  4  have input =  [0.35122192 0.34873652]
# day  4  have output =  0.33133388
# -----------------
# day  5  have input =  [0.34873652 0.33133388]
# day  5  have output =  0.32765827
# -----------------
# day  6  have input =  [0.33133388 0.32765827]
# day  6  have output =  0.3176633
# -----------------
# day  7  have input =  [0.32765827 0.31766331]
# day  7  have output =  0.34994006
# -----------------
# day  8  have input =  [0.31766331 0.34994006]
# day  8  have output =  0.32200825
# -----------------
# day  9  have input =  [0.34994006 0.32200825]
# day  9  have output =  0.3181942
# -----------------
# day  10  have input =  [0.32200825 0.31819421]
# day  10  have output =  0.3140477
# -----------------
# day  11  have input =  [0.31819421 0.31404769]
# day  11  have output =  0.26413962
# -----------------
# day  12  have input =  [0.31404769 0.26413962]
# day  12  have output =  0.29447886
# -----------------
# day  13  have input =  [0.26413962 0.29447886]
# day  13  have output =  0.270613
# -----------------
# day  14  have input =  [0.29447886 0.27061301]
# day  14  have output =  0.25598478
# -----------------
# day  15  have input =  [0.27061301 0.25598478]
# day  15  have output =  0.23944291
# -----------------
# day  16  have input =  [0.25598478 0.23944291]
# day  16  have output =  0.27167904
# -----------------
# day  17  have input =  [0.23944291 0.27167904]
# day  17  have output =  0.2676202
# -----------------
# day  18  have input =  [0.27167904 0.26762021]
# day  18  have output =  0.29081726
# -----------------
# day  19  have input =  [0.26762021 0.29081726]
# day  19  have output =  0.3200292
# -----------------
# day  20  have input =  [0.29081726 0.3200292 ]
# day  20  have output =  0.28506514
# -----------------
# day  21  have input =  [0.3200292  0.28506514]
# day  21  have output =  0.30646652
# -----------------
# day  22  have input =  [0.28506514 0.30646652]
# day  22  have output =  0.2865299
# -----------------
# day  23  have input =  [0.30646652 0.2865299 ]
# day  23  have output =  0.2847007
# -----------------
# day  24  have input =  [0.2865299  0.28470069]
# day  24  have output =  0.27527022
# -----------------
# day  25  have input =  [0.28470069 0.27527022]
# day  25  have output =  0.28648862
# -----------------
# day  26  have input =  [0.27527022 0.28648862]
# day  26  have output =  0.28716958
# -----------------
# day  27  have input =  [0.28648862 0.28716958]
# day  27  have output =  0.27720475
# -----------------
# day  28  have input =  [0.28716958 0.27720475]
# day  28  have output =  0.29284674
# -----------------
# day  29  have input =  [0.27720475 0.29284674]
# day  29  have output =  0.27778295
# -----------------
# day  30  have input =  [0.29284674 0.27778295]
# day  30  have output =  0.25850165

# %%
# 19.In ra 30 ngày tiếp theo
print(lst_output)
# Out:
# [0.3496877, 0.35122192, 0.34873652, 0.33133388, 0.32765827, 0.3176633, 0.34994006, 0.32200825, 0.3181942, 0.3140477, 0.26413962, 0.29447886, 0.270613, 0.25598478, 0.23944291, 0.27167904, 0.2676202, 0.29081726, 0.3200292, 0.28506514, 0.30646652, 0.2865299, 0.2847007, 0.27527022, 0.28648862, 0.28716958, 0.27720475, 0.29284674, 0.27778295, 0.25850165]

# %%
# 20. Tạo mảng index tương ứng với các ngày
days = np.array(range(len(df), len(df) + len(lst_output)))

# Vẽ biểu đồ
plt.figure(figsize=(20,10))
plt.plot(days, lst_output, c='r', label='Next 30 days')
plt.plot(df1, c='black', label='Real data')
plt.show()

# %%
# 21.vẽ next 30 days
plt.figure(figsize=(20,10))
plt.plot(days, lst_output, c='r', label='Next 30 days')
plt.show()

# %%
# 22.Chuẩn hóa dữ liệu và chuyển đổi các giá trị dự đoán trở lại đơn vị ban đầu
train_data_inverse=scaler.inverse_transform(np.array(train_data).reshape(-1, 1))
test_data_inverse=scaler.inverse_transform(np.array(test_data).reshape(-1, 1))
val_data_inverse=scaler.inverse_transform(np.array(val_data).reshape(-1, 1))
next_30_days_inverse=scaler.inverse_transform(np.array(lst_output).reshape(-1, 1))

# in dữ liệu
print(train_data_inverse[:5])
print(test_data_inverse[:5])
print(val_data_inverse[:5])
print(next_30_days_inverse[:5])
# Out:
# [[140.819412]
#  [155.047684]
#  [149.13501 ]
#  [154.58194 ]
#  [155.638596]]
# [[4020.26001 ]
#  [3982.099609]
#  [4108.015625]
#  [4047.98291 ]
#  [4093.281006]]
# [[1514.374878]
#  [1555.477905]
#  [1619.698486]
#  [1590.783325]
#  [1572.714478]]
# [[1750.7083]
#  [1757.9307]
#  [1746.2306]
#  [1664.3068]
#  [1647.0035]]

# %%
# 23 .vẽ y_train nối với ytest và y_val với index tương ứng

train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
test_data_index = pd.RangeIndex(start=train_size, stop=train_size+test_size, step=1)
val_data_index = pd.RangeIndex(start=train_size+test_size, stop=train_size+test_size+val_size, step=1)
predict30_data_index = pd.RangeIndex(start=train_size+test_size+val_size, stop=train_size+test_size+val_size+30, step=1)

train_predict_index = pd.RangeIndex(start=0, stop=train_predict.shape[0], step=1)
y_pred_index = pd.RangeIndex(start=train_size+(train_size-train_predict.shape[0]), stop=train_size+(train_size-train_predict.shape[0])+y_pred.shape[0], step=1)
y_pred_val_index = pd.RangeIndex(start=train_size+(train_size-train_predict.shape[0])+y_pred.shape[0]+(val_size-y_pred_val.shape[0]), stop=train_size+(train_size-train_predict.shape[0])+y_pred.shape[0]+y_pred_val.shape[0]+(val_size-y_pred_val.shape[0]), step=1)
plt.figure(figsize=(20,10))
plt.grid(True)
plt.plot(train_data_index, train_data_inverse,  label='Train data')
plt.plot(test_data_index, test_data_inverse, label='Test data')
plt.plot(val_data_index, val_data_inverse,  label='Val data')
plt.plot(predict30_data_index, next_30_days_inverse, label='Predict 30 days')
plt.plot(y_pred_index, y_pred, label='Test predict')
plt.plot(y_pred_val_index, y_pred_val,  label='Val predict')
# trục x là giá trị của cột Close time của df1
plt.xticks(np.arange(0, len(df1), 100), df['Date'][0:len(df):100])
plt.xticks(rotation=60)
plt.legend()
plt.show()

# %%
# PHẦN THÊM : Đánh giá bằng R-Squared
from sklearn.metrics import r2_score
r_squared = r2_score(ytest, y_pred)
print("Test_R-squared: ", r_squared)
r_squared = r2_score(yval, y_pred_val)
print("Val_R-squared: ", r_squared)
# Out:
# Test_R-squared:  0.9338000601079858
# Val_R-squared:  0.7792253043711901
