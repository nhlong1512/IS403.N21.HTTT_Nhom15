# %%
# 1. Import thư viện cần thiết
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# %%
# 2. Đọc file csv và gắn index với giá Close
df = pd.read_csv('DOGE-USD.csv')
df1=df.reset_index()['Close']
plt.plot(df1)

# %%
# 3. Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
# 4. Chia train test
train_size = int(0.6 * len(df1))
test_size = int(0.3 * len(df1))
val_size = len(df1) - train_size - test_size

train_data = df1[:train_size]
test_data = df1[train_size:train_size+test_size]
val_data = df1[train_size+test_size:]
print(df1)
# Out:
# [[0.00125139]
#  [0.00127334]
#  [0.00120455]
#  ...
#  [0.1084392 ]
#  [0.10641649]
#  [0.11049997]]

# %%
#in shape của từng tập dư liệu train, test, val
print("Train shape: ",train_data.shape)
print("Test shape: ",test_data.shape)
print("Val shape: ",val_data.shape)
# Out:
# Train shape:  (930, 1)
# Test shape:  (465, 1)
# Val shape:  (156, 1)

# %%
# 5. Hàm Create Dataset
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, X=0,1,2,3-----99   Y=100
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return numpy.array(dataX), numpy.array(dataY)

# %%
#6. Reshape into X=t,t+1,t+2..t+99 and Y=t+100
time_step = 2
X_train, y_train = create_dataset(train_data, time_step)
X_val, yval = create_dataset(val_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
# 7. Reshape input to be [samples, time steps, features] which is required for BNN
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)
X_val = X_val.reshape(X_val.shape[0],X_val.shape[1] , 1)

# %%
# 8. Import các thư viện cần thiết để xây dựng mô hình BNN (Bayesian Neural Network) với thư viện Keras
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
# Thư viện tensorflow_probability cung cấp các hàm cần thiết xây dựng BNN
import tensorflow_probability as tfp
# Thư viện tensorflow_probability.distributions cung cấp các phân phối xác suất cần thiết xây dựng BNN
tfd = tfp.distributions
# Thư viện tensorflow_probability.layers cung cấp các lớp cần thiết xây dựng BNN
tfpl = tfp.layers
# Thêm drop-out vào Model
from tensorflow.keras.layers import Dropout
# Thêm Adam ( Adaptive Moment Estimation)  vào model
from tensorflow.keras.optimizers import Adam
# Thêm Dense vào model
from tensorflow.keras.layers import Dense

# # Thêm flatten vào Model, flatten là một hàm được sử dụng để chuyển đổi một mảng nhiều chiều thành một mảng một chiều
# from tensorflow.keras.layers import Flatten

# Thêm early vào Model
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import Sequential

# %%
# 9. Define BNN Model
# Tạo một lớp phân phối Gaussian
class GaussianLayer(tfp.layers.DistributionLambda):
    def __init__(self, **kwargs):
        super(GaussianLayer, self).__init__(
            lambda t: tfp.distributions.Normal(loc=t, scale=1), **kwargs)

model = Sequential()
model.add(Dense(64, input_dim=X_train.shape[1]))

model.add(Dropout(0.2))
model.add(Dense(32))
model.add(Dropout(0.2))
model.add(Dense(16))
model.add(Dropout(0.2))
model.add(Dense(8))
model.add( GaussianLayer())
model.add(Dropout(0.2))
model.add(Dense(1))

# %%
# Compile model
model.compile(loss='mean_squared_error', optimizer=Adam(learning_rate=0.001))

# %%
# 11. Train model
early_stop = EarlyStopping(monitor='val_loss', patience=50)
history = model.fit(X_train, y_train, validation_data = (X_test, ytest), epochs=1000,batch_size=64, verbose=1,callbacks=[early_stop])
# sẽ dừng lại khi val_loss không còn giảm nữa sau 50 lần lặp, monitor là giá trị để theo dõi, ở đây là val_loss
# verbose=1 sẽ in ra thông tin khi dừng lại
# Out:
# Epoch 1/1000
# 15/15 [==============================] - 1s 13ms/step - loss: 2.6962 - val_loss: 1.7224
# Epoch 2/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 2.2902 - val_loss: 1.9290
# Epoch 3/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 2.3084 - val_loss: 1.7638
# Epoch 4/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 2.1009 - val_loss: 1.6599
# Epoch 5/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 2.2265 - val_loss: 1.6489
# Epoch 6/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 2.2918 - val_loss: 1.6568
# Epoch 7/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 2.1596 - val_loss: 1.4142
# Epoch 8/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 1.6406 - val_loss: 1.4890
# Epoch 9/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 1.8175 - val_loss: 1.3090
# Epoch 10/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 1.5961 - val_loss: 1.3306
# Epoch 11/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 1.5952 - val_loss: 1.2118
# Epoch 12/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 1.5849 - val_loss: 1.1722
# Epoch 13/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 1.3598 - val_loss: 1.1215
# Epoch 14/1000
# 15/15 [==============================] - 0s 6ms/step - loss: 1.4298 - val_loss: 1.1070
# Epoch 15/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 1.2536 - val_loss: 1.0983
# Epoch 16/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 1.3953 - val_loss: 1.0113
# Epoch 17/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 1.1927 - val_loss: 0.8855
# Epoch 18/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 1.0820 - val_loss: 1.0225
# Epoch 19/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 1.1551 - val_loss: 0.8633
# Epoch 20/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 1.0091 - val_loss: 0.7477
# Epoch 21/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 1.0111 - val_loss: 0.6863
# Epoch 22/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.9435 - val_loss: 0.7382
# Epoch 23/1000
# 15/15 [==============================] - 0s 6ms/step - loss: 0.8952 - val_loss: 0.6649
# Epoch 24/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.8443 - val_loss: 0.6655
# Epoch 25/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.7745 - val_loss: 0.5911
# Epoch 26/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.6881 - val_loss: 0.5093
# Epoch 27/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6552 - val_loss: 0.5717
# Epoch 28/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6772 - val_loss: 0.5147
# Epoch 29/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.6707 - val_loss: 0.4310
# Epoch 30/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.6419 - val_loss: 0.4581
# Epoch 31/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.5770 - val_loss: 0.4305
# Epoch 32/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.5122 - val_loss: 0.4088
# Epoch 33/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.4749 - val_loss: 0.3871
# Epoch 34/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.4636 - val_loss: 0.3699
# Epoch 35/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.4258 - val_loss: 0.3398
# Epoch 36/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.4512 - val_loss: 0.3050
# Epoch 37/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.3687 - val_loss: 0.3005
# Epoch 38/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.3563 - val_loss: 0.2513
# Epoch 39/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.3255 - val_loss: 0.2537
# Epoch 40/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.3254 - val_loss: 0.2393
# Epoch 41/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2795 - val_loss: 0.2158
# Epoch 42/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.2847 - val_loss: 0.2431
# Epoch 43/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2506 - val_loss: 0.2091
# Epoch 44/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2574 - val_loss: 0.1870
# Epoch 45/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2323 - val_loss: 0.1778
# Epoch 46/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.2204 - val_loss: 0.1750
# Epoch 47/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.2041 - val_loss: 0.1674
# Epoch 48/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.1958 - val_loss: 0.1549
# Epoch 49/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.1606 - val_loss: 0.1221
# Epoch 50/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.1717 - val_loss: 0.1226
# Epoch 51/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.1512 - val_loss: 0.1089
# Epoch 52/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.1389 - val_loss: 0.1234
# Epoch 53/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.1374 - val_loss: 0.1099
# Epoch 54/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.1264 - val_loss: 0.1029
# Epoch 55/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.1118 - val_loss: 0.0988
# Epoch 56/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.1115 - val_loss: 0.0860
# Epoch 57/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0955 - val_loss: 0.0747
# Epoch 58/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0985 - val_loss: 0.0705
# Epoch 59/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0908 - val_loss: 0.0781
# Epoch 60/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0730 - val_loss: 0.0655
# Epoch 61/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0741 - val_loss: 0.0545
# Epoch 62/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0735 - val_loss: 0.0603
# Epoch 63/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0673 - val_loss: 0.0492
# Epoch 64/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0608 - val_loss: 0.0505
# Epoch 65/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0544 - val_loss: 0.0435
# Epoch 66/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0550 - val_loss: 0.0359
# Epoch 67/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0488 - val_loss: 0.0329
# Epoch 68/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0409 - val_loss: 0.0318
# Epoch 69/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0446 - val_loss: 0.0315
# Epoch 70/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0379 - val_loss: 0.0299
# Epoch 71/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0349 - val_loss: 0.0273
# Epoch 72/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0356 - val_loss: 0.0251
# Epoch 73/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0311 - val_loss: 0.0221
# Epoch 74/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0288 - val_loss: 0.0198
# Epoch 75/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0276 - val_loss: 0.0190
# Epoch 76/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0241 - val_loss: 0.0173
# Epoch 77/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0237 - val_loss: 0.0154
# Epoch 78/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0204 - val_loss: 0.0155
# Epoch 79/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0211 - val_loss: 0.0161
# Epoch 80/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0187 - val_loss: 0.0141
# Epoch 81/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0180 - val_loss: 0.0122
# Epoch 82/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0170 - val_loss: 0.0096
# Epoch 83/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0149 - val_loss: 0.0120
# Epoch 84/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0145 - val_loss: 0.0094
# Epoch 85/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0135 - val_loss: 0.0094
# Epoch 86/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0122 - val_loss: 0.0083
# Epoch 87/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0114 - val_loss: 0.0073
# Epoch 88/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0120 - val_loss: 0.0070
# Epoch 89/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0102 - val_loss: 0.0068
# Epoch 90/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0092 - val_loss: 0.0061
# Epoch 91/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0091 - val_loss: 0.0062
# Epoch 92/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0089 - val_loss: 0.0055
# Epoch 93/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0083 - val_loss: 0.0051
# Epoch 94/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0071 - val_loss: 0.0052
# Epoch 95/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0082 - val_loss: 0.0047
# Epoch 96/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0064 - val_loss: 0.0043
# Epoch 97/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0063 - val_loss: 0.0041
# Epoch 98/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0060 - val_loss: 0.0034
# Epoch 99/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0059 - val_loss: 0.0033
# Epoch 100/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0052 - val_loss: 0.0042
# Epoch 101/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0056 - val_loss: 0.0038
# Epoch 102/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0054 - val_loss: 0.0034
# Epoch 103/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0053 - val_loss: 0.0032
# Epoch 104/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0046 - val_loss: 0.0025
# Epoch 105/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0059 - val_loss: 0.0024
# Epoch 106/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0054 - val_loss: 0.0025
# Epoch 107/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0042 - val_loss: 0.0034
# Epoch 108/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0045 - val_loss: 0.0027
# Epoch 109/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0055 - val_loss: 0.0024
# Epoch 110/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0045 - val_loss: 0.0022
# Epoch 111/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0046 - val_loss: 0.0026
# Epoch 112/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0042 - val_loss: 0.0023
# Epoch 113/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0043 - val_loss: 0.0019
# Epoch 114/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0044 - val_loss: 0.0015
# Epoch 115/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0044 - val_loss: 0.0018
# Epoch 116/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0046 - val_loss: 0.0032
# Epoch 117/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0039 - val_loss: 0.0015
# Epoch 118/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0044 - val_loss: 0.0016
# Epoch 119/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0040 - val_loss: 0.0015
# Epoch 120/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0044 - val_loss: 0.0019
# Epoch 121/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0044 - val_loss: 0.0018
# Epoch 122/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0033 - val_loss: 0.0028
# Epoch 123/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0035 - val_loss: 0.0014
# Epoch 124/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0042 - val_loss: 0.0012
# Epoch 125/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0040 - val_loss: 0.0020
# Epoch 126/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0043 - val_loss: 0.0017
# Epoch 127/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0040 - val_loss: 0.0010
# Epoch 128/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0037 - val_loss: 0.0032
# Epoch 129/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0039 - val_loss: 0.0013
# Epoch 130/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0038 - val_loss: 0.0028
# Epoch 131/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0038 - val_loss: 0.0011
# Epoch 132/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0039 - val_loss: 0.0027
# Epoch 133/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0038 - val_loss: 0.0011
# Epoch 134/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0035 - val_loss: 0.0023
# Epoch 135/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0030 - val_loss: 0.0013
# Epoch 136/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0032 - val_loss: 0.0016
# Epoch 137/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0032 - val_loss: 0.0013
# Epoch 138/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0038 - val_loss: 0.0014
# Epoch 139/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0034 - val_loss: 0.0014
# Epoch 140/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0029 - val_loss: 7.8582e-04
# Epoch 141/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0030 - val_loss: 0.0015
# Epoch 142/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0039 - val_loss: 0.0013
# Epoch 143/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0032 - val_loss: 9.2316e-04
# Epoch 144/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0030 - val_loss: 0.0016
# Epoch 145/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0030 - val_loss: 7.5760e-04
# Epoch 146/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0034 - val_loss: 0.0018
# Epoch 147/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0030 - val_loss: 0.0013
# Epoch 148/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0038 - val_loss: 0.0015
# Epoch 149/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0034 - val_loss: 0.0020
# Epoch 150/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0027 - val_loss: 0.0010
# Epoch 151/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0027 - val_loss: 0.0012
# Epoch 152/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0037 - val_loss: 9.5437e-04
# Epoch 153/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0037 - val_loss: 0.0012
# Epoch 154/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0038 - val_loss: 0.0056
# Epoch 155/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0035 - val_loss: 0.0017
# Epoch 156/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0028 - val_loss: 9.7761e-04
# Epoch 157/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0034 - val_loss: 9.5702e-04
# Epoch 158/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0037 - val_loss: 0.0014
# Epoch 159/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0023 - val_loss: 7.5041e-04
# Epoch 160/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0036 - val_loss: 0.0032
# Epoch 161/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0034 - val_loss: 8.9114e-04
# Epoch 162/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0025 - val_loss: 6.8179e-04
# Epoch 163/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0034 - val_loss: 0.0017
# Epoch 164/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0031 - val_loss: 9.2435e-04
# Epoch 165/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0030 - val_loss: 0.0012
# Epoch 166/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0030 - val_loss: 8.1565e-04
# Epoch 167/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0029 - val_loss: 0.0015
# Epoch 168/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0023 - val_loss: 5.9663e-04
# Epoch 169/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0028 - val_loss: 6.3059e-04
# Epoch 170/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0036 - val_loss: 0.0015
# Epoch 171/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0030 - val_loss: 0.0021
# Epoch 172/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0035 - val_loss: 6.1443e-04
# Epoch 173/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0028 - val_loss: 0.0017
# Epoch 174/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0022 - val_loss: 6.4670e-04
# Epoch 175/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0023 - val_loss: 0.0017
# Epoch 176/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0031 - val_loss: 7.2479e-04
# Epoch 177/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0036 - val_loss: 0.0038
# Epoch 178/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0026 - val_loss: 0.0010
# Epoch 179/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0027 - val_loss: 8.7422e-04
# Epoch 180/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0033 - val_loss: 0.0025
# Epoch 181/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0034 - val_loss: 9.1653e-04
# Epoch 182/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0039 - val_loss: 7.8486e-04
# Epoch 183/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0028 - val_loss: 0.0010
# Epoch 184/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0031 - val_loss: 0.0011
# Epoch 185/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0034 - val_loss: 0.0015
# Epoch 186/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0034 - val_loss: 0.0047
# Epoch 187/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0037 - val_loss: 9.7707e-04
# Epoch 188/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0030 - val_loss: 5.7603e-04
# Epoch 189/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0033 - val_loss: 0.0017
# Epoch 190/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0033 - val_loss: 5.8954e-04
# Epoch 191/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0034 - val_loss: 6.7125e-04
# Epoch 192/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0045 - val_loss: 0.0052
# Epoch 193/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0030 - val_loss: 7.3040e-04
# Epoch 194/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0027 - val_loss: 9.7859e-04
# Epoch 195/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0026 - val_loss: 0.0012
# Epoch 196/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0034 - val_loss: 9.8036e-04
# Epoch 197/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0033 - val_loss: 0.0018
# Epoch 198/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0027 - val_loss: 0.0019
# Epoch 199/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0022 - val_loss: 5.4201e-04
# Epoch 200/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0030 - val_loss: 0.0017
# Epoch 201/1000
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0033 - val_loss: 5.5789e-04
# Epoch 202/1000
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0030 - val_loss: 0.0012
# Epoch 203/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0031 - val_loss: 7.5671e-04
# Epoch 204/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0034 - val_loss: 5.1260e-04
# Epoch 205/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0034 - val_loss: 0.0013
# Epoch 206/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0032 - val_loss: 6.1687e-04
# Epoch 207/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0030 - val_loss: 0.0016
# Epoch 208/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0021 - val_loss: 7.6228e-04
# Epoch 209/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0025 - val_loss: 0.0020
# Epoch 210/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0031 - val_loss: 5.7772e-04
# Epoch 211/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0027 - val_loss: 0.0011
# Epoch 212/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0028 - val_loss: 0.0018
# Epoch 213/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0033 - val_loss: 6.5084e-04
# Epoch 214/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0027 - val_loss: 6.5687e-04
# Epoch 215/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0026 - val_loss: 6.9406e-04
# Epoch 216/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0036 - val_loss: 0.0019
# Epoch 217/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0036 - val_loss: 9.1445e-04
# Epoch 218/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0026 - val_loss: 0.0023
# Epoch 219/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0025 - val_loss: 0.0014
# Epoch 220/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0025 - val_loss: 0.0012
# Epoch 221/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0028 - val_loss: 5.8036e-04
# Epoch 222/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0025 - val_loss: 7.4743e-04
# Epoch 223/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0028 - val_loss: 6.1551e-04
# Epoch 224/1000
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0036 - val_loss: 7.9157e-04
# Epoch 225/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0034 - val_loss: 0.0055
# Epoch 226/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0040 - val_loss: 0.0016
# Epoch 227/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0041 - val_loss: 9.9556e-04
# Epoch 228/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0045 - val_loss: 0.0053
# Epoch 229/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0031 - val_loss: 0.0015
# Epoch 230/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0041 - val_loss: 0.0024
# Epoch 231/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0037 - val_loss: 0.0034
# Epoch 232/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0032 - val_loss: 6.9604e-04
# Epoch 233/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0025 - val_loss: 0.0020
# Epoch 234/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0032 - val_loss: 6.0208e-04
# Epoch 235/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0031 - val_loss: 0.0019
# Epoch 236/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0033 - val_loss: 6.1705e-04
# Epoch 237/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0028 - val_loss: 0.0011
# Epoch 238/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0028 - val_loss: 7.9157e-04
# Epoch 239/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0031 - val_loss: 7.5315e-04
# Epoch 240/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0031 - val_loss: 0.0016
# Epoch 241/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0029 - val_loss: 0.0012
# Epoch 242/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0025 - val_loss: 0.0016
# Epoch 243/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0020 - val_loss: 7.1453e-04
# Epoch 244/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0032 - val_loss: 0.0018
# Epoch 245/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0031 - val_loss: 0.0017
# Epoch 246/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0036 - val_loss: 5.0821e-04
# Epoch 247/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0025 - val_loss: 0.0018
# Epoch 248/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0030 - val_loss: 5.8787e-04
# Epoch 249/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0021 - val_loss: 0.0011
# Epoch 250/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0028 - val_loss: 4.9531e-04
# Epoch 251/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0031 - val_loss: 6.4045e-04
# Epoch 252/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0023 - val_loss: 0.0010
# Epoch 253/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0024 - val_loss: 5.9574e-04
# Epoch 254/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0026 - val_loss: 5.2269e-04
# Epoch 255/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0023 - val_loss: 0.0011
# Epoch 256/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0031 - val_loss: 0.0015
# Epoch 257/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0023 - val_loss: 6.0833e-04
# Epoch 258/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0028 - val_loss: 0.0018
# Epoch 259/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0027 - val_loss: 9.0918e-04
# Epoch 260/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0023 - val_loss: 9.8422e-04
# Epoch 261/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0027 - val_loss: 4.5810e-04
# Epoch 262/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0027 - val_loss: 5.1137e-04
# Epoch 263/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0032 - val_loss: 0.0023
# Epoch 264/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0026 - val_loss: 6.4340e-04
# Epoch 265/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0023 - val_loss: 9.8660e-04
# Epoch 266/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0034 - val_loss: 0.0033
# Epoch 267/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0028 - val_loss: 0.0017
# Epoch 268/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0036 - val_loss: 0.0011
# Epoch 269/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0026 - val_loss: 0.0014
# Epoch 270/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0032 - val_loss: 4.9394e-04
# Epoch 271/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0028 - val_loss: 5.1374e-04
# Epoch 272/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 8.9834e-04
# Epoch 273/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0035 - val_loss: 5.1524e-04
# Epoch 274/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0035 - val_loss: 5.5359e-04
# Epoch 275/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0027 - val_loss: 0.0016
# Epoch 276/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0033 - val_loss: 0.0017
# Epoch 277/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0027 - val_loss: 5.5250e-04
# Epoch 278/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0026 - val_loss: 0.0023
# Epoch 279/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0025 - val_loss: 0.0011
# Epoch 280/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0031 - val_loss: 4.8864e-04
# Epoch 281/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0027 - val_loss: 0.0022
# Epoch 282/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0024 - val_loss: 5.3981e-04
# Epoch 283/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0035 - val_loss: 6.0532e-04
# Epoch 284/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0025 - val_loss: 0.0013
# Epoch 285/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0030 - val_loss: 9.8464e-04
# Epoch 286/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0028 - val_loss: 5.5000e-04
# Epoch 287/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0030 - val_loss: 4.9237e-04
# Epoch 288/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0024 - val_loss: 6.8499e-04
# Epoch 289/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0028 - val_loss: 0.0013
# Epoch 290/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0034 - val_loss: 5.0793e-04
# Epoch 291/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0032 - val_loss: 5.3323e-04
# Epoch 292/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0032 - val_loss: 0.0014
# Epoch 293/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0028 - val_loss: 4.2304e-04
# Epoch 294/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0024 - val_loss: 4.4992e-04
# Epoch 295/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0031 - val_loss: 0.0012
# Epoch 296/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0026 - val_loss: 0.0010
# Epoch 297/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0027 - val_loss: 4.5830e-04
# Epoch 298/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0036 - val_loss: 7.6958e-04
# Epoch 299/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0030 - val_loss: 0.0012
# Epoch 300/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0029 - val_loss: 0.0019
# Epoch 301/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0026 - val_loss: 5.9769e-04
# Epoch 302/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0029 - val_loss: 6.0644e-04
# Epoch 303/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0023 - val_loss: 0.0015
# Epoch 304/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0025 - val_loss: 0.0033
# Epoch 305/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0032 - val_loss: 0.0014
# Epoch 306/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0024 - val_loss: 7.9549e-04
# Epoch 307/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0033 - val_loss: 0.0018
# Epoch 308/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0028 - val_loss: 0.0034
# Epoch 309/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0029 - val_loss: 5.2377e-04
# Epoch 310/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0025 - val_loss: 0.0013
# Epoch 311/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0031 - val_loss: 7.0370e-04
# Epoch 312/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0023 - val_loss: 4.8644e-04
# Epoch 313/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0024 - val_loss: 0.0012
# Epoch 314/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0020 - val_loss: 8.1008e-04
# Epoch 315/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0021 - val_loss: 4.9782e-04
# Epoch 316/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0027 - val_loss: 4.5296e-04
# Epoch 317/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0023 - val_loss: 6.0851e-04
# Epoch 318/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0024 - val_loss: 4.9489e-04
# Epoch 319/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0024 - val_loss: 9.8759e-04
# Epoch 320/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0024 - val_loss: 0.0010
# Epoch 321/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0037 - val_loss: 7.1525e-04
# Epoch 322/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0025 - val_loss: 5.0007e-04
# Epoch 323/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0028 - val_loss: 5.3024e-04
# Epoch 324/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0024 - val_loss: 0.0012
# Epoch 325/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0025 - val_loss: 0.0019
# Epoch 326/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0024 - val_loss: 6.9417e-04
# Epoch 327/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0020 - val_loss: 5.0957e-04
# Epoch 328/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0023 - val_loss: 4.5008e-04
# Epoch 329/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0027 - val_loss: 0.0023
# Epoch 330/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0035 - val_loss: 0.0011
# Epoch 331/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0024 - val_loss: 8.9905e-04
# Epoch 332/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0024 - val_loss: 7.3563e-04
# Epoch 333/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0024 - val_loss: 0.0013
# Epoch 334/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0022 - val_loss: 8.7564e-04
# Epoch 335/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0029 - val_loss: 9.2731e-04
# Epoch 336/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0024 - val_loss: 5.6072e-04
# Epoch 337/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0027 - val_loss: 6.3820e-04
# Epoch 338/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0021 - val_loss: 8.1622e-04
# Epoch 339/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0021 - val_loss: 5.2227e-04
# Epoch 340/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0021 - val_loss: 0.0014
# Epoch 341/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0027 - val_loss: 5.5745e-04
# Epoch 342/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0031 - val_loss: 4.8392e-04
# Epoch 343/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0025 - val_loss: 5.6262e-04

# %%
# 12. Dự báo dữ liệu test, val
train_predict=model.predict(X_train)
y_pred=model.predict(X_test)
y_pred_val=model.predict(X_val)

# In shape của từng tập dư liệu
print(train_predict.shape, y_pred.shape, y_pred_val.shape)
# Out:
# 29/29 [==============================] - 0s 974us/step
# 15/15 [==============================] - 0s 1ms/step
# 5/5 [==============================] - 0s 1ms/step
# (927, 1) (462, 1) (153, 1)

# %%
# 13. In shape của từng tập dư liệu y real
print(y_train.shape, ytest.shape, yval.shape)
# Out:
# (927,) (462,) (153,)

# %%
# 14. Chuẩn hóa dữ liệu y_pred, y_pred_val
train_predict=scaler.inverse_transform(train_predict)
y_pred=scaler.inverse_transform(y_pred)
y_pred_val=scaler.inverse_transform(y_pred_val)

# in head
print(train_predict[:5])
# Out:
# [[-0.00690147]
#  [ 0.0044371 ]
#  [ 0.01895431]
#  [-0.00665008]
#  [ 0.01455448]]

# %%
# 15. Chuẩn hóa ngược lại yval và ytest và y_train sau khi đã reshape
y_train = y_train.reshape(y_train.shape[0],1)
ytest = ytest.reshape(ytest.shape[0],1)
yval = yval.reshape(yval.shape[0],1)

y_train=scaler.inverse_transform(y_train)
ytest=scaler.inverse_transform(ytest)
yval=scaler.inverse_transform(yval)

#in head
print(y_train[:5])
# Out:
# [[0.00236 ]
#  [0.002315]
#  [0.002319]
#  [0.002328]
#  [0.002285]]

# %%
# 16. Đánh giá độ chính xác thuật toán bằng MAE va RMSE
import math
from sklearn.metrics import mean_squared_error, mean_absolute_error


print('Train Mean Absolute Error:', mean_absolute_error(y_train, train_predict[:,0]))
print('Test Mean Absolute Error:', mean_absolute_error(ytest, y_pred[:,0]))
print('Val Mean Absolute Error:', mean_absolute_error(yval, y_pred_val[:,0]))
print('Train Root Mean Squared Error:',np.sqrt(mean_squared_error(y_train, train_predict[:,0])))
print('Test Root Mean Squared Error:',np.sqrt(mean_squared_error(ytest, y_pred[:,0])))
print('Val Root Mean Squared Error:',np.sqrt(mean_squared_error(yval, y_pred_val[:,0])))
# Out:
# Train Mean Absolute Error: 0.012256406003818976
# Test Mean Absolute Error: 0.011798696343283118
# Val Mean Absolute Error: 0.010661779208261203
# Train Root Mean Squared Error: 0.020803128388876324
# Test Root Mean Squared Error: 0.01585967708232379
# Val Root Mean Squared Error: 0.013437251344085376

# %%
# 17. Đánh giá model bằng MAPE
def mean_absolute_percentage_error(y_true, y_pred):
    return numpy.mean(numpy.abs((y_true - y_pred) / y_true)) * 100

print('Train Mean Absolute Percentage Error:', mean_absolute_percentage_error(y_train[:,0], train_predict[:,0]))
print('Test Mean Absolute Percentage Error:', mean_absolute_percentage_error(ytest[:,0], y_pred[:,0]))
print('Val Mean Absolute Percentage Error:', mean_absolute_percentage_error(yval[:,0], y_pred_val[:,0]))
print('Train Score: %.2f MAPE' % (mean_absolute_percentage_error(y_train[:,0], train_predict[:,0])))
print('Test Score: %.2f MAPE' % (mean_absolute_percentage_error(ytest[:,0], y_pred[:,0])))
print('Val Score: %.2f MAPE' % (mean_absolute_percentage_error(yval[:,0], y_pred_val[:,0])))
# Out:
# Train Mean Absolute Percentage Error: 301.98576264569124
# Test Mean Absolute Percentage Error: 9.419134094106624
# Val Mean Absolute Percentage Error: 12.599009909992445
# Train Score: 301.99 MAPE
# Test Score: 9.42 MAPE
# Val Score: 12.60 MAPE

# %%
# 18. Lấy time_step ngày cuối cùng của dữ liệu train để dự đoán 30 ngày tiếp theo
x_input = val_data[-time_step:].reshape(-1, 1)   #[-time_step:] lấy time_step phần tử cuối cùng của dữ liệu
print("x_input.shape = ", x_input.shape)

# Dự đoán 30 ngày tiếp theo
lst_output = []

i = 1  # Biến đếm để dừng vòng lặp while
while(i <= 30):
    print("-----------------")
    # Đưa về mảng 1 chiều
    list_input = x_input.reshape(1, -1)[0]
    # in ra x_input của ngày thứ i trong 30 ngày tiếp theo
    print("day ", i, " have input = ", list_input)

    # Dự đoán giá đóng của ngày tiếp theo
    x_input = x_input.reshape(1, time_step, 1) # reshape lại về dạng (1, time_step, 1)
    yhat = model.predict(x_input, verbose=0) # dự đoán giá đóng của ngày tiếp theo

    # in ra giá đóng của ngày thứ i trong 30 ngày tiếp theo
    print("day ",i," have output = ", yhat[0][0])

    # thêm giá đóng của ngày thứ i vào lst_output
    lst_output.append(yhat[0][0])

    # Xóa phần tử đầu tiên x_input
    x_input = np.delete(x_input, 0)
    # thêm yhat vào x_input
    x_input = np.append(x_input, yhat[0][0])
    # Tăng biến đếm lên 1
    i = i + 1
# Out:
# x_input.shape =  (2, 1)
# -----------------
# day  1  have input =  [0.10641649 0.11049997]
# day  1  have output =  0.11955598
# -----------------
# day  2  have input =  [0.11049997 0.11955598]
# day  2  have output =  0.11321596
# -----------------
# day  3  have input =  [0.11955598 0.11321596]
# day  3  have output =  0.116800115
# -----------------
# day  4  have input =  [0.11321596 0.11680011]
# day  4  have output =  0.11689067
# -----------------
# day  5  have input =  [0.11680011 0.11689067]
# day  5  have output =  0.11461681
# -----------------
# day  6  have input =  [0.11689067 0.11461681]
# day  6  have output =  0.11047862
# -----------------
# day  7  have input =  [0.11461681 0.11047862]
# day  7  have output =  0.1179529
# -----------------
# day  8  have input =  [0.11047862 0.1179529 ]
# day  8  have output =  0.117333606
# -----------------
# day  9  have input =  [0.1179529  0.11733361]
# day  9  have output =  0.13330139
# -----------------
# day  10  have input =  [0.11733361 0.13330139]
# day  10  have output =  0.12642106
# -----------------
# day  11  have input =  [0.13330139 0.12642106]
# day  11  have output =  0.12665245
# -----------------
# day  12  have input =  [0.12642106 0.12665245]
# day  12  have output =  0.1353851
# -----------------
# day  13  have input =  [0.12665245 0.1353851 ]
# day  13  have output =  0.16413084
# -----------------
# day  14  have input =  [0.1353851  0.16413084]
# day  14  have output =  0.1544893
# -----------------
# day  15  have input =  [0.16413084 0.15448929]
# day  15  have output =  0.17358342
# -----------------
# day  16  have input =  [0.15448929 0.17358342]
# day  16  have output =  0.1754958
# -----------------
# day  17  have input =  [0.17358342 0.1754958 ]
# day  17  have output =  0.17552385
# -----------------
# day  18  have input =  [0.1754958  0.17552385]
# day  18  have output =  0.14151022
# -----------------
# day  19  have input =  [0.17552385 0.14151022]
# day  19  have output =  0.14013867
# -----------------
# day  20  have input =  [0.14151022 0.14013867]
# day  20  have output =  0.12866175
# -----------------
# day  21  have input =  [0.14013867 0.12866175]
# day  21  have output =  0.15501569
# -----------------
# day  22  have input =  [0.12866175 0.15501569]
# day  22  have output =  0.15426862
# -----------------
# day  23  have input =  [0.15501569 0.15426862]
# day  23  have output =  0.15937786
# -----------------
# day  24  have input =  [0.15426862 0.15937786]
# day  24  have output =  0.15397906
# -----------------
# day  25  have input =  [0.15937786 0.15397906]
# day  25  have output =  0.16192992
# -----------------
# day  26  have input =  [0.15397906 0.16192992]
# day  26  have output =  0.18377958
# -----------------
# day  27  have input =  [0.16192992 0.18377958]
# day  27  have output =  0.16017503
# -----------------
# day  28  have input =  [0.18377958 0.16017503]
# day  28  have output =  0.18093032
# -----------------
# day  29  have input =  [0.16017503 0.18093032]
# day  29  have output =  0.17776258
# -----------------
# day  30  have input =  [0.18093032 0.17776258]
# day  30  have output =  0.190067

# %%
# 19.In ra 30 ngày tiếp theo
print(lst_output)
# Out:
# [0.11955598, 0.11321596, 0.116800115, 0.11689067, 0.11461681, 0.11047862, 0.1179529, 0.117333606, 0.13330139, 0.12642106, 0.12665245, 0.1353851, 0.16413084, 0.1544893, 0.17358342, 0.1754958, 0.17552385, 0.14151022, 0.14013867, 0.12866175, 0.15501569, 0.15426862, 0.15937786, 0.15397906, 0.16192992, 0.18377958, 0.16017503, 0.18093032, 0.17776258, 0.190067]

# %%
# 20. Tạo mảng index tương ứng với các ngày
days = np.array(range(len(df), len(df) + len(lst_output)))

# Vẽ biểu đồ
plt.figure(figsize=(20,10))
plt.plot(days, lst_output, c='r', label='Next 30 days')
plt.plot(df1, c='black', label='Real data')
plt.show()

# %%
# 21.vẽ next 30 days
plt.figure(figsize=(20,10))
plt.plot(days, lst_output, c='r', label='Next 30 days')
plt.show()

# %%
# 22.Chuẩn hóa dữ liệu và chuyển đổi các giá trị dự đoán trở lại đơn vị ban đầu
train_data_inverse=scaler.inverse_transform(np.array(train_data).reshape(-1, 1))
test_data_inverse=scaler.inverse_transform(np.array(test_data).reshape(-1, 1))
val_data_inverse=scaler.inverse_transform(np.array(val_data).reshape(-1, 1))
next_30_days_inverse=scaler.inverse_transform(np.array(lst_output).reshape(-1, 1))

# in dữ liệu
print(train_data_inverse[:5])
print(test_data_inverse[:5])
print(val_data_inverse[:5])
print(next_30_days_inverse[:5])
# Out:
# [[0.002392]
#  [0.002407]
#  [0.00236 ]
#  [0.002315]
#  [0.002319]]
# [[0.173556]
#  [0.170801]
#  [0.190349]
#  [0.191303]
#  [0.194764]]
# [[0.077018]
#  [0.083897]
#  [0.121603]
#  [0.117802]
#  [0.127026]]
# [[0.08322243]
#  [0.07889067]
#  [0.08133951]
#  [0.08140138]
#  [0.07984779]]

# %%
# 23 .vẽ y_train nối với ytest và y_val với index tương ứng

train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
test_data_index = pd.RangeIndex(start=train_size, stop=train_size+test_size, step=1)
val_data_index = pd.RangeIndex(start=train_size+test_size, stop=train_size+test_size+val_size, step=1)
predict30_data_index = pd.RangeIndex(start=train_size+test_size+val_size, stop=train_size+test_size+val_size+30, step=1)

train_predict_index = pd.RangeIndex(start=0, stop=train_predict.shape[0], step=1)
y_pred_index = pd.RangeIndex(start=train_size+(train_size-train_predict.shape[0]), stop=train_size+(train_size-train_predict.shape[0])+y_pred.shape[0], step=1)
y_pred_val_index = pd.RangeIndex(start=train_size+(train_size-train_predict.shape[0])+y_pred.shape[0]+(val_size-y_pred_val.shape[0]), stop=train_size+(train_size-train_predict.shape[0])+y_pred.shape[0]+y_pred_val.shape[0]+(val_size-y_pred_val.shape[0]), step=1)
plt.figure(figsize=(20,10))
plt.grid(True)
plt.plot(train_data_index, train_data_inverse,  label='Train data')
plt.plot(test_data_index, test_data_inverse, label='Test data')
plt.plot(val_data_index, val_data_inverse,  label='Val data')
plt.plot(predict30_data_index, next_30_days_inverse, label='Predict 30 days')
plt.plot(y_pred_index, y_pred, label='Test predict')
plt.plot(y_pred_val_index, y_pred_val,  label='Val predict')
# trục x là giá trị của cột Close time của df1
plt.xticks(np.arange(0, len(df1), 100), df['Date'][0:len(df):100])
plt.xticks(rotation=60)
plt.legend()
plt.show()

# %%
# PHẦN THÊM : Đánh giá bằng R-Squared
from sklearn.metrics import r2_score
r_squared = r2_score(ytest, y_pred)
print("Test_R-squared: ", r_squared)
r_squared = r2_score(yval, y_pred_val)
print("Val_R-squared: ", r_squared)
# Out:
# Test_R-squared:  0.9559127531306174
# Val_R-squared:  0.014096437556546548
