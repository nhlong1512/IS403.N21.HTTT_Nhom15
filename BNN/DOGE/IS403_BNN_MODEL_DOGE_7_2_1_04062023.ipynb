# %%
# 1. Import thư viện cần thiết
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# %%
# 2. Đọc file csv và gắn index với giá Close
df = pd.read_csv('DOGE-USD.csv')
df1=df.reset_index()['Close']
plt.plot(df1)

# %%
# 3. Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
# 4. Chia train test
train_size = int(0.7 * len(df1))
test_size = int(0.2 * len(df1))
val_size = len(df1) - train_size - test_size

train_data = df1[:train_size]
test_data = df1[train_size:train_size+test_size]
val_data = df1[train_size+test_size:]
print(df1)
# Out:
# [[0.00125139]
#  [0.00127334]
#  [0.00120455]
#  ...
#  [0.1084392 ]
#  [0.10641649]
#  [0.11049997]]

# %%
#in shape của từng tập dư liệu train, test, val
print("Train shape: ",train_data.shape)
print("Test shape: ",test_data.shape)
print("Val shape: ",val_data.shape)
# Out:
# Train shape:  (1085, 1)
# Test shape:  (310, 1)
# Val shape:  (156, 1)

# %%
# 5. Hàm Create Dataset
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, X=0,1,2,3-----99   Y=100
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return numpy.array(dataX), numpy.array(dataY)

# %%
#6. Reshape into X=t,t+1,t+2..t+99 and Y=t+100
time_step = 2
X_train, y_train = create_dataset(train_data, time_step)
X_val, yval = create_dataset(val_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
# 7. Reshape input to be [samples, time steps, features] which is required for BNN
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)
X_val = X_val.reshape(X_val.shape[0],X_val.shape[1] , 1)

# %%
# 8. Import các thư viện cần thiết để xây dựng mô hình BNN (Bayesian Neural Network) với thư viện Keras
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
# Thư viện tensorflow_probability cung cấp các hàm cần thiết xây dựng BNN
import tensorflow_probability as tfp
# Thư viện tensorflow_probability.distributions cung cấp các phân phối xác suất cần thiết xây dựng BNN
tfd = tfp.distributions
# Thư viện tensorflow_probability.layers cung cấp các lớp cần thiết xây dựng BNN
tfpl = tfp.layers
# Thêm drop-out vào Model
from tensorflow.keras.layers import Dropout
# Thêm Adam ( Adaptive Moment Estimation)  vào model
from tensorflow.keras.optimizers import Adam
# Thêm Dense vào model
from tensorflow.keras.layers import Dense

# # Thêm flatten vào Model, flatten là một hàm được sử dụng để chuyển đổi một mảng nhiều chiều thành một mảng một chiều
# from tensorflow.keras.layers import Flatten

# Thêm early vào Model
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import Sequential

# %%
# 9. Define BNN Model
# Tạo một lớp phân phối Gaussian
class GaussianLayer(tfp.layers.DistributionLambda):
    def __init__(self, **kwargs):
        super(GaussianLayer, self).__init__(
            lambda t: tfp.distributions.Normal(loc=t, scale=1), **kwargs)

model = Sequential()
model.add(Dense(64, input_dim=X_train.shape[1]))

model.add(Dropout(0.2))
model.add(Dense(32))
model.add(Dropout(0.2))
model.add(Dense(16))
model.add(Dropout(0.2))
model.add(Dense(8))
model.add( GaussianLayer())
model.add(Dropout(0.2))
model.add(Dense(1))

# %%
# Compile model
model.compile(loss='mean_squared_error', optimizer=Adam(learning_rate=0.001))

# %%
# 11. Train model
early_stop = EarlyStopping(monitor='val_loss', patience=50)
history = model.fit(X_train, y_train, validation_data = (X_test, ytest), epochs=1000,batch_size=64, verbose=1,callbacks=[early_stop])
# sẽ dừng lại khi val_loss không còn giảm nữa sau 50 lần lặp, monitor là giá trị để theo dõi, ở đây là val_loss
# verbose=1 sẽ in ra thông tin khi dừng lại
# Out:
# Epoch 1/1000
# 17/17 [==============================] - 1s 15ms/step - loss: 1.2695 - val_loss: 0.8644
# Epoch 2/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 1.2364 - val_loss: 0.9926
# Epoch 3/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 1.0170 - val_loss: 0.8973
# Epoch 4/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 1.0122 - val_loss: 0.9446
# Epoch 5/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 1.0026 - val_loss: 0.6847
# Epoch 6/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.8437 - val_loss: 0.6235
# Epoch 7/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.7955 - val_loss: 0.7039
# Epoch 8/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.7733 - val_loss: 0.5346
# Epoch 9/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.6951 - val_loss: 0.5391
# Epoch 10/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.6449 - val_loss: 0.5246
# Epoch 11/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6217 - val_loss: 0.3982
# Epoch 12/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4781 - val_loss: 0.3166
# Epoch 13/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4628 - val_loss: 0.3381
# Epoch 14/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4410 - val_loss: 0.3445
# Epoch 15/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.3947 - val_loss: 0.2096
# Epoch 16/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.3688 - val_loss: 0.2830
# Epoch 17/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3307 - val_loss: 0.2488
# Epoch 18/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.3036 - val_loss: 0.1814
# Epoch 19/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2710 - val_loss: 0.1862
# Epoch 20/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2370 - val_loss: 0.1709
# Epoch 21/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2083 - val_loss: 0.1605
# Epoch 22/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2071 - val_loss: 0.1679
# Epoch 23/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1852 - val_loss: 0.1191
# Epoch 24/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1665 - val_loss: 0.1144
# Epoch 25/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1468 - val_loss: 0.1058
# Epoch 26/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1382 - val_loss: 0.0960
# Epoch 27/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1116 - val_loss: 0.0846
# Epoch 28/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1025 - val_loss: 0.0854
# Epoch 29/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0998 - val_loss: 0.0696
# Epoch 30/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0858 - val_loss: 0.0566
# Epoch 31/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0765 - val_loss: 0.0578
# Epoch 32/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0695 - val_loss: 0.0632
# Epoch 33/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0616 - val_loss: 0.0498
# Epoch 34/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0628 - val_loss: 0.0424
# Epoch 35/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0515 - val_loss: 0.0410
# Epoch 36/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0496 - val_loss: 0.0317
# Epoch 37/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0424 - val_loss: 0.0300
# Epoch 38/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0447 - val_loss: 0.0313
# Epoch 39/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0356 - val_loss: 0.0248
# Epoch 40/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0319 - val_loss: 0.0234
# Epoch 41/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0288 - val_loss: 0.0176
# Epoch 42/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0266 - val_loss: 0.0185
# Epoch 43/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0264 - val_loss: 0.0170
# Epoch 44/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0236 - val_loss: 0.0149
# Epoch 45/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0211 - val_loss: 0.0133
# Epoch 46/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0183 - val_loss: 0.0109
# Epoch 47/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0184 - val_loss: 0.0089
# Epoch 48/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0149 - val_loss: 0.0102
# Epoch 49/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0135 - val_loss: 0.0086
# Epoch 50/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0135 - val_loss: 0.0070
# Epoch 51/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0130 - val_loss: 0.0062
# Epoch 52/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0111 - val_loss: 0.0063
# Epoch 53/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0112 - val_loss: 0.0055
# Epoch 54/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0101 - val_loss: 0.0052
# Epoch 55/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0098 - val_loss: 0.0042
# Epoch 56/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0089 - val_loss: 0.0042
# Epoch 57/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0076 - val_loss: 0.0047
# Epoch 58/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0085 - val_loss: 0.0037
# Epoch 59/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0083 - val_loss: 0.0029
# Epoch 60/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0075 - val_loss: 0.0030
# Epoch 61/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0069 - val_loss: 0.0025
# Epoch 62/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0066 - val_loss: 0.0031
# Epoch 63/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0061 - val_loss: 0.0024
# Epoch 64/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0059 - val_loss: 0.0025
# Epoch 65/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0055 - val_loss: 0.0021
# Epoch 66/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0051 - val_loss: 0.0020
# Epoch 67/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0053 - val_loss: 0.0018
# Epoch 68/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0060 - val_loss: 0.0018
# Epoch 69/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0050 - val_loss: 0.0017
# Epoch 70/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0047 - val_loss: 0.0017
# Epoch 71/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0043 - val_loss: 0.0017
# Epoch 72/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0047 - val_loss: 0.0015
# Epoch 73/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0044 - val_loss: 0.0015
# Epoch 74/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0045 - val_loss: 0.0013
# Epoch 75/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0012
# Epoch 76/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0044 - val_loss: 0.0012
# Epoch 77/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0045 - val_loss: 0.0012
# Epoch 78/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0037 - val_loss: 0.0011
# Epoch 79/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0047 - val_loss: 0.0011
# Epoch 80/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0035 - val_loss: 9.9433e-04
# Epoch 81/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0042 - val_loss: 0.0010
# Epoch 82/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0044 - val_loss: 7.9940e-04
# Epoch 83/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0036 - val_loss: 8.8822e-04
# Epoch 84/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0034 - val_loss: 8.7147e-04
# Epoch 85/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0053 - val_loss: 9.1313e-04
# Epoch 86/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0038 - val_loss: 7.8790e-04
# Epoch 87/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0038 - val_loss: 8.2412e-04
# Epoch 88/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0040 - val_loss: 6.4024e-04
# Epoch 89/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0034 - val_loss: 7.1773e-04
# Epoch 90/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0039 - val_loss: 6.7169e-04
# Epoch 91/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0039 - val_loss: 7.6178e-04
# Epoch 92/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0033 - val_loss: 8.0484e-04
# Epoch 93/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0036 - val_loss: 9.2461e-04
# Epoch 94/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0039 - val_loss: 8.2271e-04
# Epoch 95/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0037 - val_loss: 7.5539e-04
# Epoch 96/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0034 - val_loss: 6.5467e-04
# Epoch 97/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0036 - val_loss: 6.8015e-04
# Epoch 98/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0032 - val_loss: 6.2754e-04
# Epoch 99/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0044 - val_loss: 6.3820e-04
# Epoch 100/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0037 - val_loss: 6.7861e-04
# Epoch 101/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0042 - val_loss: 6.4609e-04
# Epoch 102/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0035 - val_loss: 7.1338e-04
# Epoch 103/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0035 - val_loss: 5.4940e-04
# Epoch 104/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0035 - val_loss: 5.6109e-04
# Epoch 105/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0035 - val_loss: 6.6152e-04
# Epoch 106/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0035 - val_loss: 5.8201e-04
# Epoch 107/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0033 - val_loss: 5.5001e-04
# Epoch 108/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0035 - val_loss: 4.5952e-04
# Epoch 109/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0034 - val_loss: 5.6739e-04
# Epoch 110/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0032 - val_loss: 7.0839e-04
# Epoch 111/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0032 - val_loss: 4.9416e-04
# Epoch 112/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0028 - val_loss: 4.8609e-04
# Epoch 113/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0037 - val_loss: 4.6190e-04
# Epoch 114/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0031 - val_loss: 5.4980e-04
# Epoch 115/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0037 - val_loss: 7.2471e-04
# Epoch 116/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0040 - val_loss: 5.1803e-04
# Epoch 117/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0040 - val_loss: 6.8616e-04
# Epoch 118/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0036 - val_loss: 4.2604e-04
# Epoch 119/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0031 - val_loss: 4.8557e-04
# Epoch 120/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0033 - val_loss: 4.6378e-04
# Epoch 121/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0029 - val_loss: 5.4584e-04
# Epoch 122/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0032 - val_loss: 5.1460e-04
# Epoch 123/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0032 - val_loss: 4.3756e-04
# Epoch 124/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0034 - val_loss: 5.1617e-04
# Epoch 125/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0037 - val_loss: 5.0411e-04
# Epoch 126/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0035 - val_loss: 5.9901e-04
# Epoch 127/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0033 - val_loss: 4.3491e-04
# Epoch 128/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0033 - val_loss: 5.0119e-04
# Epoch 129/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0029 - val_loss: 3.9807e-04
# Epoch 130/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0032 - val_loss: 3.7804e-04
# Epoch 131/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0032 - val_loss: 6.1383e-04
# Epoch 132/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0040 - val_loss: 4.9695e-04
# Epoch 133/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0034 - val_loss: 5.1372e-04
# Epoch 134/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0033 - val_loss: 4.9581e-04
# Epoch 135/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0026 - val_loss: 3.8068e-04
# Epoch 136/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0029 - val_loss: 4.3230e-04
# Epoch 137/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0032 - val_loss: 3.9608e-04
# Epoch 138/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0032 - val_loss: 3.7016e-04
# Epoch 139/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0032 - val_loss: 4.1483e-04
# Epoch 140/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0036 - val_loss: 3.6857e-04
# Epoch 141/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0029 - val_loss: 5.8597e-04
# Epoch 142/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0033 - val_loss: 4.0362e-04
# Epoch 143/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0035 - val_loss: 4.5688e-04
# Epoch 144/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0029 - val_loss: 4.9111e-04
# Epoch 145/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0034 - val_loss: 5.4898e-04
# Epoch 146/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0032 - val_loss: 3.7402e-04
# Epoch 147/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0030 - val_loss: 4.0737e-04
# Epoch 148/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0035 - val_loss: 4.2539e-04
# Epoch 149/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0029 - val_loss: 3.8788e-04
# Epoch 150/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0035 - val_loss: 3.4766e-04
# Epoch 151/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0032 - val_loss: 3.9490e-04
# Epoch 152/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0030 - val_loss: 3.2394e-04
# Epoch 153/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0033 - val_loss: 3.7175e-04
# Epoch 154/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0041 - val_loss: 4.1292e-04
# Epoch 155/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0033 - val_loss: 3.7299e-04
# Epoch 156/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0031 - val_loss: 3.6272e-04
# Epoch 157/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0037 - val_loss: 3.6701e-04
# Epoch 158/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0033 - val_loss: 4.0674e-04
# Epoch 159/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0029 - val_loss: 3.8824e-04
# Epoch 160/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0031 - val_loss: 2.9479e-04
# Epoch 161/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0029 - val_loss: 3.6036e-04
# Epoch 162/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0029 - val_loss: 3.9043e-04
# Epoch 163/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0029 - val_loss: 7.2167e-04
# Epoch 164/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0033 - val_loss: 3.3405e-04
# Epoch 165/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0031 - val_loss: 3.7854e-04
# Epoch 166/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0032 - val_loss: 3.9490e-04
# Epoch 167/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0032 - val_loss: 4.1150e-04
# Epoch 168/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0030 - val_loss: 2.9710e-04
# Epoch 169/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0029 - val_loss: 4.8973e-04
# Epoch 170/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0035 - val_loss: 6.0362e-04
# Epoch 171/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0032 - val_loss: 4.1443e-04
# Epoch 172/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0026 - val_loss: 3.9811e-04
# Epoch 173/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0032 - val_loss: 3.0559e-04
# Epoch 174/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0028 - val_loss: 3.3072e-04
# Epoch 175/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0025 - val_loss: 3.2855e-04
# Epoch 176/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0030 - val_loss: 4.8823e-04
# Epoch 177/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0031 - val_loss: 5.7510e-04
# Epoch 178/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0032 - val_loss: 3.8006e-04
# Epoch 179/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0024 - val_loss: 3.4659e-04
# Epoch 180/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0038 - val_loss: 3.1564e-04
# Epoch 181/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0030 - val_loss: 4.3854e-04
# Epoch 182/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0033 - val_loss: 3.1786e-04
# Epoch 183/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0032 - val_loss: 3.2403e-04
# Epoch 184/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0030 - val_loss: 3.2523e-04
# Epoch 185/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0034 - val_loss: 4.2913e-04
# Epoch 186/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0032 - val_loss: 5.7183e-04
# Epoch 187/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0034 - val_loss: 3.5582e-04
# Epoch 188/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0033 - val_loss: 2.9152e-04
# Epoch 189/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0026 - val_loss: 3.0734e-04
# Epoch 190/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0027 - val_loss: 3.2197e-04
# Epoch 191/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0033 - val_loss: 3.3110e-04
# Epoch 192/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0030 - val_loss: 4.6974e-04
# Epoch 193/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0031 - val_loss: 5.0734e-04
# Epoch 194/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0030 - val_loss: 2.9293e-04
# Epoch 195/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0034 - val_loss: 3.5352e-04
# Epoch 196/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0029 - val_loss: 3.4242e-04
# Epoch 197/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0032 - val_loss: 4.5626e-04
# Epoch 198/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0031 - val_loss: 3.8520e-04
# Epoch 199/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0037 - val_loss: 3.0414e-04
# Epoch 200/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0028 - val_loss: 3.0983e-04
# Epoch 201/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0025 - val_loss: 3.9722e-04
# Epoch 202/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0030 - val_loss: 4.4443e-04
# Epoch 203/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0029 - val_loss: 3.0524e-04
# Epoch 204/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0029 - val_loss: 3.6558e-04
# Epoch 205/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0033 - val_loss: 3.7395e-04
# Epoch 206/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0031 - val_loss: 3.5694e-04
# Epoch 207/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0035 - val_loss: 4.0117e-04
# Epoch 208/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0029 - val_loss: 3.3396e-04
# Epoch 209/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0037 - val_loss: 3.3629e-04
# Epoch 210/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0031 - val_loss: 2.8508e-04
# Epoch 211/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0026 - val_loss: 3.2238e-04
# Epoch 212/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0027 - val_loss: 3.1441e-04
# Epoch 213/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0028 - val_loss: 2.9565e-04
# Epoch 214/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0030 - val_loss: 2.9361e-04
# Epoch 215/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0029 - val_loss: 3.4063e-04
# Epoch 216/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0025 - val_loss: 2.6312e-04
# Epoch 217/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0030 - val_loss: 3.6373e-04
# Epoch 218/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0034 - val_loss: 3.8679e-04
# Epoch 219/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0028 - val_loss: 2.9557e-04
# Epoch 220/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0029 - val_loss: 2.4818e-04
# Epoch 221/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0031 - val_loss: 6.0355e-04
# Epoch 222/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0033 - val_loss: 3.2364e-04
# Epoch 223/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0030 - val_loss: 3.0000e-04
# Epoch 224/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0024 - val_loss: 3.5008e-04
# Epoch 225/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0024 - val_loss: 3.4527e-04
# Epoch 226/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0024 - val_loss: 2.6126e-04
# Epoch 227/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0026 - val_loss: 3.3308e-04
# Epoch 228/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0029 - val_loss: 3.2498e-04
# Epoch 229/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0032 - val_loss: 3.1135e-04
# Epoch 230/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0028 - val_loss: 4.4903e-04
# Epoch 231/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0035 - val_loss: 2.9332e-04
# Epoch 232/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0032 - val_loss: 3.7771e-04
# Epoch 233/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0037 - val_loss: 9.1947e-04
# Epoch 234/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0040 - val_loss: 3.2435e-04
# Epoch 235/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0026 - val_loss: 3.0619e-04
# Epoch 236/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0029 - val_loss: 2.4557e-04
# Epoch 237/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0031 - val_loss: 3.4030e-04
# Epoch 238/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0025 - val_loss: 2.9782e-04
# Epoch 239/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0027 - val_loss: 2.8295e-04
# Epoch 240/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0028 - val_loss: 3.0411e-04
# Epoch 241/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0032 - val_loss: 2.9873e-04
# Epoch 242/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0027 - val_loss: 2.8006e-04
# Epoch 243/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0030 - val_loss: 3.1958e-04
# Epoch 244/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0029 - val_loss: 2.7576e-04
# Epoch 245/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0026 - val_loss: 3.0228e-04
# Epoch 246/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0032 - val_loss: 2.7938e-04
# Epoch 247/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0029 - val_loss: 2.5339e-04
# Epoch 248/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0028 - val_loss: 2.4503e-04
# Epoch 249/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0024 - val_loss: 2.8302e-04
# Epoch 250/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0030 - val_loss: 3.1685e-04
# Epoch 251/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0030 - val_loss: 4.1607e-04
# Epoch 252/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0025 - val_loss: 3.3453e-04
# Epoch 253/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0026 - val_loss: 2.4232e-04
# Epoch 254/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0028 - val_loss: 4.9078e-04
# Epoch 255/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0024 - val_loss: 2.6690e-04
# Epoch 256/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0035 - val_loss: 2.5757e-04
# Epoch 257/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0029 - val_loss: 2.5114e-04
# Epoch 258/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0028 - val_loss: 2.8978e-04
# Epoch 259/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0028 - val_loss: 2.7818e-04
# Epoch 260/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0032 - val_loss: 2.7894e-04
# Epoch 261/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0028 - val_loss: 2.3846e-04
# Epoch 262/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0032 - val_loss: 2.6320e-04
# Epoch 263/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0030 - val_loss: 2.5636e-04
# Epoch 264/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0032 - val_loss: 3.0903e-04
# Epoch 265/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0028 - val_loss: 2.5812e-04
# Epoch 266/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0033 - val_loss: 2.9809e-04
# Epoch 267/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0029 - val_loss: 2.2156e-04
# Epoch 268/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0027 - val_loss: 2.3893e-04
# Epoch 269/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0029 - val_loss: 2.7914e-04
# Epoch 270/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0032 - val_loss: 2.4288e-04
# Epoch 271/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 3.0667e-04
# Epoch 272/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0025 - val_loss: 2.6917e-04
# Epoch 273/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0029 - val_loss: 2.9400e-04
# Epoch 274/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0038 - val_loss: 2.8453e-04
# Epoch 275/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0031 - val_loss: 2.8214e-04
# Epoch 276/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0026 - val_loss: 2.7725e-04
# Epoch 277/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0038 - val_loss: 4.0221e-04
# Epoch 278/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0028 - val_loss: 3.0519e-04
# Epoch 279/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0031 - val_loss: 3.2246e-04
# Epoch 280/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0027 - val_loss: 3.2462e-04
# Epoch 281/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0028 - val_loss: 2.6576e-04
# Epoch 282/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0025 - val_loss: 3.1779e-04
# Epoch 283/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0030 - val_loss: 3.2511e-04
# Epoch 284/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0032 - val_loss: 2.7171e-04
# Epoch 285/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0033 - val_loss: 2.5213e-04
# Epoch 286/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0030 - val_loss: 4.4675e-04
# Epoch 287/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0029 - val_loss: 2.6223e-04
# Epoch 288/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0029 - val_loss: 3.2206e-04
# Epoch 289/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0027 - val_loss: 3.0327e-04
# Epoch 290/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0028 - val_loss: 3.0532e-04
# Epoch 291/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0026 - val_loss: 3.1303e-04
# Epoch 292/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0028 - val_loss: 2.7992e-04
# Epoch 293/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0029 - val_loss: 2.9896e-04
# Epoch 294/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0031 - val_loss: 2.9080e-04
# Epoch 295/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0031 - val_loss: 3.0370e-04
# Epoch 296/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0031 - val_loss: 3.2091e-04
# Epoch 297/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0026 - val_loss: 2.4435e-04
# Epoch 298/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0036 - val_loss: 2.9679e-04
# Epoch 299/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0027 - val_loss: 2.5399e-04
# Epoch 300/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0030 - val_loss: 2.1359e-04
# Epoch 301/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0028 - val_loss: 2.5846e-04
# Epoch 302/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0023 - val_loss: 3.0938e-04
# Epoch 303/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0030 - val_loss: 4.0636e-04
# Epoch 304/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0026 - val_loss: 2.9431e-04
# Epoch 305/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0026 - val_loss: 2.4084e-04
# Epoch 306/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0032 - val_loss: 2.7327e-04
# Epoch 307/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0033 - val_loss: 2.8274e-04
# Epoch 308/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0022 - val_loss: 2.4986e-04
# Epoch 309/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0024 - val_loss: 2.5848e-04
# Epoch 310/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0028 - val_loss: 2.8894e-04
# Epoch 311/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0030 - val_loss: 3.0461e-04
# Epoch 312/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0031 - val_loss: 3.0931e-04
# Epoch 313/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0032 - val_loss: 4.4847e-04
# Epoch 314/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0031 - val_loss: 5.5373e-04
# Epoch 315/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0034 - val_loss: 3.2711e-04
# Epoch 316/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0024 - val_loss: 2.2657e-04
# Epoch 317/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0025 - val_loss: 2.7572e-04
# Epoch 318/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0025 - val_loss: 2.9907e-04
# Epoch 319/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0029 - val_loss: 2.8876e-04
# Epoch 320/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0036 - val_loss: 3.4284e-04
# Epoch 321/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0039 - val_loss: 2.8660e-04
# Epoch 322/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0030 - val_loss: 3.3286e-04
# Epoch 323/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0026 - val_loss: 3.8484e-04
# Epoch 324/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0026 - val_loss: 3.9826e-04
# Epoch 325/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0034 - val_loss: 9.1255e-04
# Epoch 326/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0039 - val_loss: 4.1232e-04
# Epoch 327/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0023 - val_loss: 3.8160e-04
# Epoch 328/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0031 - val_loss: 3.5682e-04
# Epoch 329/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0029 - val_loss: 3.6951e-04
# Epoch 330/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0024 - val_loss: 3.6567e-04
# Epoch 331/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0037 - val_loss: 3.8989e-04
# Epoch 332/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0031 - val_loss: 3.7371e-04
# Epoch 333/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0030 - val_loss: 3.6873e-04
# Epoch 334/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0032 - val_loss: 4.3450e-04
# Epoch 335/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0030 - val_loss: 2.7504e-04
# Epoch 336/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0028 - val_loss: 3.3947e-04
# Epoch 337/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0029 - val_loss: 2.8647e-04
# Epoch 338/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0029 - val_loss: 3.2568e-04
# Epoch 339/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0027 - val_loss: 4.1537e-04
# Epoch 340/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0026 - val_loss: 2.9011e-04
# Epoch 341/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0029 - val_loss: 2.9777e-04
# Epoch 342/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0029 - val_loss: 2.8704e-04
# Epoch 343/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0027 - val_loss: 2.8444e-04
# Epoch 344/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0029 - val_loss: 3.4513e-04
# Epoch 345/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0025 - val_loss: 3.4366e-04
# Epoch 346/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0028 - val_loss: 3.0409e-04
# Epoch 347/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0028 - val_loss: 2.4627e-04
# Epoch 348/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0027 - val_loss: 2.5400e-04
# Epoch 349/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0032 - val_loss: 3.0632e-04
# Epoch 350/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0030 - val_loss: 2.6045e-04

# %%
# 12. Dự báo dữ liệu test, val
train_predict=model.predict(X_train)
y_pred=model.predict(X_test)
y_pred_val=model.predict(X_val)

# In shape của từng tập dư liệu
print(train_predict.shape, y_pred.shape, y_pred_val.shape)
# Out:
# 34/34 [==============================] - 0s 1ms/step
# 10/10 [==============================] - 0s 1ms/step
# 5/5 [==============================] - 0s 2ms/step
# (1082, 1) (307, 1) (153, 1)

# %%
# 13. In shape của từng tập dư liệu y real
print(y_train.shape, ytest.shape, yval.shape)
# Out:
# (1082,) (307,) (153,)

# %%
# 14. Chuẩn hóa dữ liệu y_pred, y_pred_val
train_predict=scaler.inverse_transform(train_predict)
y_pred=scaler.inverse_transform(y_pred)
y_pred_val=scaler.inverse_transform(y_pred_val)

# in head
print(train_predict[:5])
# Out:
# [[-0.01681281]
#  [ 0.014183  ]
#  [-0.00302851]
#  [ 0.00207396]
#  [-0.00173783]]

# %%
# 15. Chuẩn hóa ngược lại yval và ytest và y_train sau khi đã reshape
y_train = y_train.reshape(y_train.shape[0],1)
ytest = ytest.reshape(ytest.shape[0],1)
yval = yval.reshape(yval.shape[0],1)

y_train=scaler.inverse_transform(y_train)
ytest=scaler.inverse_transform(ytest)
yval=scaler.inverse_transform(yval)

#in head
print(y_train[:5])
# Out:
# [[0.00236 ]
#  [0.002315]
#  [0.002319]
#  [0.002328]
#  [0.002285]]

# %%
# 16. Đánh giá độ chính xác thuật toán bằng MAE va RMSE
import math
from sklearn.metrics import mean_squared_error, mean_absolute_error


print('Train Mean Absolute Error:', mean_absolute_error(y_train, train_predict[:,0]))
print('Test Mean Absolute Error:', mean_absolute_error(ytest, y_pred[:,0]))
print('Val Mean Absolute Error:', mean_absolute_error(yval, y_pred_val[:,0]))
print('Train Root Mean Squared Error:',np.sqrt(mean_squared_error(y_train, train_predict[:,0])))
print('Test Root Mean Squared Error:',np.sqrt(mean_squared_error(ytest, y_pred[:,0])))
print('Val Root Mean Squared Error:',np.sqrt(mean_squared_error(yval, y_pred_val[:,0])))
# Out:
# Train Mean Absolute Error: 0.012024401524518221
# Test Mean Absolute Error: 0.008605545635622566
# Val Mean Absolute Error: 0.00907912253991607
# Train Root Mean Squared Error: 0.020351090904962198
# Test Root Mean Squared Error: 0.01105253836294264
# Val Root Mean Squared Error: 0.011318079747112478

# %%
# 17. Đánh giá model bằng MAPE
def mean_absolute_percentage_error(y_true, y_pred):
    return numpy.mean(numpy.abs((y_true - y_pred) / y_true)) * 100

print('Train Mean Absolute Percentage Error:', mean_absolute_percentage_error(y_train[:,0], train_predict[:,0]))
print('Test Mean Absolute Percentage Error:', mean_absolute_percentage_error(ytest[:,0], y_pred[:,0]))
print('Val Mean Absolute Percentage Error:', mean_absolute_percentage_error(yval[:,0], y_pred_val[:,0]))
print('Train Score: %.2f MAPE' % (mean_absolute_percentage_error(y_train[:,0], train_predict[:,0])))
print('Test Score: %.2f MAPE' % (mean_absolute_percentage_error(ytest[:,0], y_pred[:,0])))
print('Val Score: %.2f MAPE' % (mean_absolute_percentage_error(yval[:,0], y_pred_val[:,0])))
# Out:
# Train Mean Absolute Percentage Error: 228.49198545860875
# Test Mean Absolute Percentage Error: 9.558853104791364
# Val Mean Absolute Percentage Error: 10.671923587450356
# Train Score: 228.49 MAPE
# Test Score: 9.56 MAPE
# Val Score: 10.67 MAPE

# %%
# 18. Lấy time_step ngày cuối cùng của dữ liệu train để dự đoán 30 ngày tiếp theo
x_input = val_data[-time_step:].reshape(-1, 1)   #[-time_step:] lấy time_step phần tử cuối cùng của dữ liệu
print("x_input.shape = ", x_input.shape)

# Dự đoán 30 ngày tiếp theo
lst_output = []

i = 1  # Biến đếm để dừng vòng lặp while
while(i <= 30):
    print("-----------------")
    # Đưa về mảng 1 chiều
    list_input = x_input.reshape(1, -1)[0]
    # in ra x_input của ngày thứ i trong 30 ngày tiếp theo
    print("day ", i, " have input = ", list_input)

    # Dự đoán giá đóng của ngày tiếp theo
    x_input = x_input.reshape(1, time_step, 1) # reshape lại về dạng (1, time_step, 1)
    yhat = model.predict(x_input, verbose=0) # dự đoán giá đóng của ngày tiếp theo

    # in ra giá đóng của ngày thứ i trong 30 ngày tiếp theo
    print("day ",i," have output = ", yhat[0][0])

    # thêm giá đóng của ngày thứ i vào lst_output
    lst_output.append(yhat[0][0])

    # Xóa phần tử đầu tiên x_input
    x_input = np.delete(x_input, 0)
    # thêm yhat vào x_input
    x_input = np.append(x_input, yhat[0][0])
    # Tăng biến đếm lên 1
    i = i + 1
# Out:
# x_input.shape =  (2, 1)
# -----------------
# day  1  have input =  [0.10641649 0.11049997]
# day  1  have output =  0.13221964
# -----------------
# day  2  have input =  [0.11049997 0.13221964]
# day  2  have output =  0.09622248
# -----------------
# day  3  have input =  [0.13221964 0.09622248]
# day  3  have output =  0.08146995
# -----------------
# day  4  have input =  [0.09622248 0.08146995]
# day  4  have output =  0.101404764
# -----------------
# day  5  have input =  [0.08146995 0.10140476]
# day  5  have output =  0.106019914
# -----------------
# day  6  have input =  [0.10140476 0.10601991]
# day  6  have output =  0.121341854
# -----------------
# day  7  have input =  [0.10601991 0.12134185]
# day  7  have output =  0.1310247
# -----------------
# day  8  have input =  [0.12134185 0.1310247 ]
# day  8  have output =  0.13800544
# -----------------
# day  9  have input =  [0.1310247  0.13800544]
# day  9  have output =  0.13945685
# -----------------
# day  10  have input =  [0.13800544 0.13945685]
# day  10  have output =  0.15048046
# -----------------
# day  11  have input =  [0.13945685 0.15048046]
# day  11  have output =  0.1675556
# -----------------
# day  12  have input =  [0.15048046 0.1675556 ]
# day  12  have output =  0.14612709
# -----------------
# day  13  have input =  [0.1675556  0.14612709]
# day  13  have output =  0.18153977
# -----------------
# day  14  have input =  [0.14612709 0.18153977]
# day  14  have output =  0.15877225
# -----------------
# day  15  have input =  [0.18153977 0.15877225]
# day  15  have output =  0.17357624
# -----------------
# day  16  have input =  [0.15877225 0.17357624]
# day  16  have output =  0.15430935
# -----------------
# day  17  have input =  [0.17357624 0.15430935]
# day  17  have output =  0.14774634
# -----------------
# day  18  have input =  [0.15430935 0.14774634]
# day  18  have output =  0.14518914
# -----------------
# day  19  have input =  [0.14774634 0.14518914]
# day  19  have output =  0.1388485
# -----------------
# day  20  have input =  [0.14518914 0.1388485 ]
# day  20  have output =  0.15571499
# -----------------
# day  21  have input =  [0.1388485  0.15571499]
# day  21  have output =  0.1428768
# -----------------
# day  22  have input =  [0.15571499 0.1428768 ]
# day  22  have output =  0.13371685
# -----------------
# day  23  have input =  [0.1428768  0.13371685]
# day  23  have output =  0.13264531
# -----------------
# day  24  have input =  [0.13371685 0.13264531]
# day  24  have output =  0.12003213
# -----------------
# day  25  have input =  [0.13264531 0.12003213]
# day  25  have output =  0.14516431
# -----------------
# day  26  have input =  [0.12003213 0.14516431]
# day  26  have output =  0.11583854
# -----------------
# day  27  have input =  [0.14516431 0.11583854]
# day  27  have output =  0.11860152
# -----------------
# day  28  have input =  [0.11583854 0.11860152]
# day  28  have output =  0.12328891
# -----------------
# day  29  have input =  [0.11860152 0.12328891]
# day  29  have output =  0.10804913
# -----------------
# day  30  have input =  [0.12328891 0.10804913]
# day  30  have output =  0.11500572

# %%
# 19.In ra 30 ngày tiếp theo
print(lst_output)
# Out:
# [0.13221964, 0.09622248, 0.08146995, 0.101404764, 0.106019914, 0.121341854, 0.1310247, 0.13800544, 0.13945685, 0.15048046, 0.1675556, 0.14612709, 0.18153977, 0.15877225, 0.17357624, 0.15430935, 0.14774634, 0.14518914, 0.1388485, 0.15571499, 0.1428768, 0.13371685, 0.13264531, 0.12003213, 0.14516431, 0.11583854, 0.11860152, 0.12328891, 0.10804913, 0.11500572]

# %%
# 20. Tạo mảng index tương ứng với các ngày
days = np.array(range(len(df), len(df) + len(lst_output)))

# Vẽ biểu đồ
plt.figure(figsize=(20,10))
plt.plot(days, lst_output, c='r', label='Next 30 days')
plt.plot(df1, c='black', label='Real data')
plt.show()

# %%
# 21.vẽ next 30 days
plt.figure(figsize=(20,10))
plt.plot(days, lst_output, c='r', label='Next 30 days')
plt.show()

# %%
# 22.Chuẩn hóa dữ liệu và chuyển đổi các giá trị dự đoán trở lại đơn vị ban đầu
train_data_inverse=scaler.inverse_transform(np.array(train_data).reshape(-1, 1))
test_data_inverse=scaler.inverse_transform(np.array(test_data).reshape(-1, 1))
val_data_inverse=scaler.inverse_transform(np.array(val_data).reshape(-1, 1))
next_30_days_inverse=scaler.inverse_transform(np.array(lst_output).reshape(-1, 1))

# in dữ liệu
print(train_data_inverse[:5])
print(test_data_inverse[:5])
print(val_data_inverse[:5])
print(next_30_days_inverse[:5])
# Out:
# [[0.002392]
#  [0.002407]
#  [0.00236 ]
#  [0.002315]
#  [0.002319]]
# [[0.171175]
#  [0.173214]
#  [0.18449 ]
#  [0.186622]
#  [0.190657]]
# [[0.077018]
#  [0.083897]
#  [0.121603]
#  [0.117802]
#  [0.127026]]
# [[0.09187474]
#  [0.06728005]
#  [0.05720053]
#  [0.07082079]
#  [0.07397404]]

# %%
# 23 .vẽ y_train nối với ytest và y_val với index tương ứng

train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
test_data_index = pd.RangeIndex(start=train_size, stop=train_size+test_size, step=1)
val_data_index = pd.RangeIndex(start=train_size+test_size, stop=train_size+test_size+val_size, step=1)
predict30_data_index = pd.RangeIndex(start=train_size+test_size+val_size, stop=train_size+test_size+val_size+30, step=1)

train_predict_index = pd.RangeIndex(start=0, stop=train_predict.shape[0], step=1)
y_pred_index = pd.RangeIndex(start=train_size+(train_size-train_predict.shape[0]), stop=train_size+(train_size-train_predict.shape[0])+y_pred.shape[0], step=1)
y_pred_val_index = pd.RangeIndex(start=train_size+(train_size-train_predict.shape[0])+y_pred.shape[0]+(val_size-y_pred_val.shape[0]), stop=train_size+(train_size-train_predict.shape[0])+y_pred.shape[0]+y_pred_val.shape[0]+(val_size-y_pred_val.shape[0]), step=1)
plt.figure(figsize=(20,10))
plt.grid(True)
plt.plot(train_data_index, train_data_inverse,  label='Train data')
plt.plot(test_data_index, test_data_inverse, label='Test data')
plt.plot(val_data_index, val_data_inverse,  label='Val data')
plt.plot(predict30_data_index, next_30_days_inverse, label='Predict 30 days')
plt.plot(y_pred_index, y_pred, label='Test predict')
plt.plot(y_pred_val_index, y_pred_val,  label='Val predict')
# trục x là giá trị của cột Close time của df1
plt.xticks(np.arange(0, len(df1), 100), df['Date'][0:len(df):100])
plt.xticks(rotation=60)
plt.legend()
plt.show()

# %%
# PHẦN THÊM : Đánh giá bằng R-Squared
from sklearn.metrics import r2_score
r_squared = r2_score(ytest, y_pred)
print("Test_R-squared: ", r_squared)
r_squared = r2_score(yval, y_pred_val)
print("Val_R-squared: ", r_squared)
# Out:
# Test_R-squared:  0.9225208929167332
# Val_R-squared:  0.30054616816458124
