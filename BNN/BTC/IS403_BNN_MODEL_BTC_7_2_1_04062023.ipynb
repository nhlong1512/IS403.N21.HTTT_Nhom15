# %%
# 1. Import thư viện cần thiết
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# %%
# 2. Đọc file csv và gắn index với giá Close
df = pd.read_csv('BTC-USD.csv')
df1=df.reset_index()['Close']
plt.plot(df1)

# %%
# 3. Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
# 4. Chia train test
train_size = int(0.7 * len(df1))
test_size = int(0.2 * len(df1))
val_size = len(df1) - train_size - test_size

train_data = df1[:train_size]
test_data = df1[train_size:train_size+test_size]
val_data = df1[train_size+test_size:]
print(df1)
# Out:
# [[0.00692016]
#  [0.00847686]
#  [0.00681452]
#  ...
#  [0.38881093]
#  [0.38390378]
#  [0.39083755]]

# %%
#in shape của từng tập dư liệu train, test, val
print("Train shape: ",train_data.shape)
print("Test shape: ",test_data.shape)
print("Val shape: ",val_data.shape)
# Out:
# Train shape:  (1085, 1)
# Test shape:  (310, 1)
# Val shape:  (156, 1)

# %%
# 5. Hàm Create Dataset
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, X=0,1,2,3-----99   Y=100
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return numpy.array(dataX), numpy.array(dataY)

# %%
#6. Reshape into X=t,t+1,t+2..t+99 and Y=t+100
time_step = 2
X_train, y_train = create_dataset(train_data, time_step)
X_val, yval = create_dataset(val_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
# 7. Reshape input to be [samples, time steps, features] which is required for BNN
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)
X_val = X_val.reshape(X_val.shape[0],X_val.shape[1] , 1)

# %%
# 8. Import các thư viện cần thiết để xây dựng mô hình BNN (Bayesian Neural Network) với thư viện Keras
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
# Thư viện tensorflow_probability cung cấp các hàm cần thiết xây dựng BNN
import tensorflow_probability as tfp
# Thư viện tensorflow_probability.distributions cung cấp các phân phối xác suất cần thiết xây dựng BNN
tfd = tfp.distributions
# Thư viện tensorflow_probability.layers cung cấp các lớp cần thiết xây dựng BNN
tfpl = tfp.layers
# Thêm drop-out vào Model
from tensorflow.keras.layers import Dropout
# Thêm Adam ( Adaptive Moment Estimation)  vào model
from tensorflow.keras.optimizers import Adam
# Thêm Dense vào model
from tensorflow.keras.layers import Dense

# # Thêm flatten vào Model, flatten là một hàm được sử dụng để chuyển đổi một mảng nhiều chiều thành một mảng một chiều
# from tensorflow.keras.layers import Flatten

# Thêm early vào Model
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import Sequential

# %%
# 9. Define BNN Model
# Tạo một lớp phân phối Gaussian
class GaussianLayer(tfp.layers.DistributionLambda):
    def __init__(self, **kwargs):
        super(GaussianLayer, self).__init__(
            lambda t: tfp.distributions.Normal(loc=t, scale=1), **kwargs)

model = Sequential()
model.add(Dense(64, input_dim=X_train.shape[1]))

model.add(Dropout(0.2))
model.add(Dense(32))
model.add(Dropout(0.2))
model.add(Dense(16))
model.add(Dropout(0.2))
model.add(Dense(8))
model.add( GaussianLayer())
model.add(Dropout(0.2))
model.add(Dense(1))

# %%
# Compile model
model.compile(loss='mean_squared_error', optimizer=Adam(learning_rate=0.001))

# %%
# 11. Train model
early_stop = EarlyStopping(monitor='val_loss', patience=50)
history = model.fit(X_train, y_train, validation_data = (X_test, ytest), epochs=1000,batch_size=64, verbose=1,callbacks=[early_stop])
# sẽ dừng lại khi val_loss không còn giảm nữa sau 50 lần lặp, monitor là giá trị để theo dõi, ở đây là val_loss
# verbose=1 sẽ in ra thông tin khi dừng lại
# Out:
# Epoch 1/1000
# 17/17 [==============================] - 3s 24ms/step - loss: 2.2335 - val_loss: 1.6718
# Epoch 2/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 2.1754 - val_loss: 1.7348
# Epoch 3/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 2.0095 - val_loss: 1.5195
# Epoch 4/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 1.9834 - val_loss: 1.3837
# Epoch 5/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 1.6783 - val_loss: 1.2629
# Epoch 6/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 1.6264 - val_loss: 1.3383
# Epoch 7/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 1.6802 - val_loss: 1.0671
# Epoch 8/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 1.5162 - val_loss: 1.0084
# Epoch 9/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 1.2516 - val_loss: 1.0338
# Epoch 10/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 1.3203 - val_loss: 0.8251
# Epoch 11/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 1.1068 - val_loss: 0.9447
# Epoch 12/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 1.0661 - val_loss: 0.8282
# Epoch 13/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 1.1014 - val_loss: 0.9062
# Epoch 14/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.9226 - val_loss: 0.6681
# Epoch 15/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.9663 - val_loss: 0.8155
# Epoch 16/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.8722 - val_loss: 0.7543
# Epoch 17/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.7706 - val_loss: 0.5729
# Epoch 18/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6921 - val_loss: 0.5723
# Epoch 19/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6669 - val_loss: 0.5928
# Epoch 20/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6383 - val_loss: 0.4908
# Epoch 21/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6799 - val_loss: 0.4189
# Epoch 22/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.5988 - val_loss: 0.4184
# Epoch 23/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.5383 - val_loss: 0.4123
# Epoch 24/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.5091 - val_loss: 0.3659
# Epoch 25/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4673 - val_loss: 0.3770
# Epoch 26/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4263 - val_loss: 0.3150
# Epoch 27/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3872 - val_loss: 0.2906
# Epoch 28/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3859 - val_loss: 0.2476
# Epoch 29/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3717 - val_loss: 0.2968
# Epoch 30/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3130 - val_loss: 0.2345
# Epoch 31/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.3174 - val_loss: 0.2514
# Epoch 32/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2810 - val_loss: 0.2019
# Epoch 33/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2432 - val_loss: 0.2218
# Epoch 34/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2537 - val_loss: 0.1651
# Epoch 35/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2156 - val_loss: 0.1490
# Epoch 36/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2032 - val_loss: 0.1439
# Epoch 37/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1794 - val_loss: 0.1245
# Epoch 38/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1793 - val_loss: 0.1331
# Epoch 39/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1606 - val_loss: 0.1338
# Epoch 40/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1559 - val_loss: 0.1230
# Epoch 41/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1334 - val_loss: 0.0984
# Epoch 42/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1252 - val_loss: 0.1022
# Epoch 43/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1320 - val_loss: 0.0861
# Epoch 44/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1146 - val_loss: 0.0808
# Epoch 45/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1030 - val_loss: 0.0745
# Epoch 46/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0978 - val_loss: 0.0691
# Epoch 47/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0906 - val_loss: 0.0671
# Epoch 48/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0927 - val_loss: 0.0601
# Epoch 49/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0802 - val_loss: 0.0570
# Epoch 50/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0735 - val_loss: 0.0416
# Epoch 51/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0739 - val_loss: 0.0426
# Epoch 52/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0625 - val_loss: 0.0369
# Epoch 53/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0568 - val_loss: 0.0334
# Epoch 54/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0536 - val_loss: 0.0398
# Epoch 55/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0506 - val_loss: 0.0306
# Epoch 56/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0481 - val_loss: 0.0310
# Epoch 57/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0430 - val_loss: 0.0336
# Epoch 58/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0402 - val_loss: 0.0269
# Epoch 59/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0391 - val_loss: 0.0216
# Epoch 60/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0358 - val_loss: 0.0228
# Epoch 61/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0338 - val_loss: 0.0189
# Epoch 62/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0308 - val_loss: 0.0187
# Epoch 63/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0298 - val_loss: 0.0175
# Epoch 64/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0286 - val_loss: 0.0130
# Epoch 65/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0245 - val_loss: 0.0128
# Epoch 66/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0257 - val_loss: 0.0141
# Epoch 67/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0245 - val_loss: 0.0136
# Epoch 68/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0222 - val_loss: 0.0132
# Epoch 69/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0207 - val_loss: 0.0101
# Epoch 70/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0221 - val_loss: 0.0097
# Epoch 71/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0194 - val_loss: 0.0084
# Epoch 72/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0167 - val_loss: 0.0083
# Epoch 73/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0168 - val_loss: 0.0077
# Epoch 74/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0181 - val_loss: 0.0088
# Epoch 75/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0168 - val_loss: 0.0060
# Epoch 76/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0151 - val_loss: 0.0067
# Epoch 77/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0154 - val_loss: 0.0058
# Epoch 78/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0136 - val_loss: 0.0051
# Epoch 79/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0146 - val_loss: 0.0069
# Epoch 80/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0128 - val_loss: 0.0046
# Epoch 81/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0140 - val_loss: 0.0062
# Epoch 82/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0137 - val_loss: 0.0044
# Epoch 83/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0128 - val_loss: 0.0041
# Epoch 84/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0131 - val_loss: 0.0041
# Epoch 85/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0124 - val_loss: 0.0043
# Epoch 86/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0124 - val_loss: 0.0044
# Epoch 87/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0118 - val_loss: 0.0037
# Epoch 88/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0108 - val_loss: 0.0040
# Epoch 89/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0113 - val_loss: 0.0033
# Epoch 90/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0117 - val_loss: 0.0036
# Epoch 91/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0108 - val_loss: 0.0027
# Epoch 92/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0108 - val_loss: 0.0040
# Epoch 93/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0100 - val_loss: 0.0028
# Epoch 94/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0088 - val_loss: 0.0026
# Epoch 95/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0111 - val_loss: 0.0025
# Epoch 96/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0093 - val_loss: 0.0026
# Epoch 97/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0101 - val_loss: 0.0029
# Epoch 98/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0103 - val_loss: 0.0023
# Epoch 99/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0109 - val_loss: 0.0022
# Epoch 100/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0097 - val_loss: 0.0022
# Epoch 101/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0091 - val_loss: 0.0021
# Epoch 102/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0100 - val_loss: 0.0023
# Epoch 103/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0089 - val_loss: 0.0022
# Epoch 104/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0095 - val_loss: 0.0015
# Epoch 105/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0099 - val_loss: 0.0018
# Epoch 106/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0097 - val_loss: 0.0027
# Epoch 107/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0093 - val_loss: 0.0022
# Epoch 108/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0090 - val_loss: 0.0018
# Epoch 109/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0091 - val_loss: 0.0020
# Epoch 110/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0084 - val_loss: 0.0019
# Epoch 111/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0089 - val_loss: 0.0025
# Epoch 112/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0094 - val_loss: 0.0025
# Epoch 113/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0089 - val_loss: 0.0021
# Epoch 114/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0095 - val_loss: 0.0019
# Epoch 115/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0082 - val_loss: 0.0015
# Epoch 116/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0083 - val_loss: 0.0019
# Epoch 117/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0088 - val_loss: 0.0021
# Epoch 118/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0076 - val_loss: 0.0032
# Epoch 119/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0089 - val_loss: 0.0016
# Epoch 120/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0082 - val_loss: 0.0018
# Epoch 121/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0087 - val_loss: 0.0015
# Epoch 122/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0091 - val_loss: 0.0015
# Epoch 123/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0080 - val_loss: 0.0015
# Epoch 124/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0078 - val_loss: 0.0017
# Epoch 125/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0079 - val_loss: 0.0016
# Epoch 126/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0087 - val_loss: 0.0014
# Epoch 127/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0090 - val_loss: 0.0014
# Epoch 128/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0075 - val_loss: 0.0016
# Epoch 129/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0073 - val_loss: 0.0017
# Epoch 130/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0085 - val_loss: 0.0017
# Epoch 131/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0080 - val_loss: 0.0013
# Epoch 132/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0087 - val_loss: 0.0014
# Epoch 133/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0081 - val_loss: 0.0015
# Epoch 134/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0079 - val_loss: 0.0014
# Epoch 135/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0080 - val_loss: 0.0015
# Epoch 136/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0074 - val_loss: 0.0016
# Epoch 137/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0077 - val_loss: 0.0013
# Epoch 138/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0076 - val_loss: 0.0012
# Epoch 139/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0069 - val_loss: 0.0014
# Epoch 140/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0071 - val_loss: 0.0014
# Epoch 141/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0081 - val_loss: 0.0017
# Epoch 142/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0072 - val_loss: 0.0013
# Epoch 143/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0071 - val_loss: 0.0015
# Epoch 144/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0067 - val_loss: 0.0014
# Epoch 145/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0079 - val_loss: 0.0012
# Epoch 146/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0083 - val_loss: 0.0011
# Epoch 147/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0072 - val_loss: 0.0011
# Epoch 148/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0079 - val_loss: 0.0012
# Epoch 149/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0071 - val_loss: 0.0011
# Epoch 150/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0065 - val_loss: 0.0022
# Epoch 151/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0074 - val_loss: 0.0016
# Epoch 152/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0078 - val_loss: 0.0011
# Epoch 153/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0073 - val_loss: 0.0011
# Epoch 154/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0068 - val_loss: 0.0013
# Epoch 155/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0070 - val_loss: 0.0012
# Epoch 156/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0075 - val_loss: 0.0013
# Epoch 157/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0071 - val_loss: 0.0018
# Epoch 158/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0077 - val_loss: 0.0015
# Epoch 159/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0073 - val_loss: 0.0013
# Epoch 160/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0076 - val_loss: 0.0012
# Epoch 161/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0082 - val_loss: 9.9521e-04
# Epoch 162/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0070 - val_loss: 0.0020
# Epoch 163/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0078 - val_loss: 0.0015
# Epoch 164/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0075 - val_loss: 0.0011
# Epoch 165/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0073 - val_loss: 0.0012
# Epoch 166/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0079 - val_loss: 0.0012
# Epoch 167/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0067 - val_loss: 9.4856e-04
# Epoch 168/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0066 - val_loss: 0.0011
# Epoch 169/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0075 - val_loss: 0.0014
# Epoch 170/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0063 - val_loss: 0.0011
# Epoch 171/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0074 - val_loss: 0.0013
# Epoch 172/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0075 - val_loss: 0.0021
# Epoch 173/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0066 - val_loss: 0.0017
# Epoch 174/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0069 - val_loss: 0.0013
# Epoch 175/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0072 - val_loss: 0.0010
# Epoch 176/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0068 - val_loss: 9.3760e-04
# Epoch 177/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0074 - val_loss: 0.0011
# Epoch 178/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0073 - val_loss: 0.0013
# Epoch 179/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0075 - val_loss: 0.0014
# Epoch 180/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0076 - val_loss: 9.2175e-04
# Epoch 181/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0061 - val_loss: 0.0015
# Epoch 182/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0064 - val_loss: 0.0010
# Epoch 183/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0070 - val_loss: 9.6931e-04
# Epoch 184/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0072 - val_loss: 0.0011
# Epoch 185/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0069 - val_loss: 9.4685e-04
# Epoch 186/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0063 - val_loss: 0.0015
# Epoch 187/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0080 - val_loss: 9.2408e-04
# Epoch 188/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0066 - val_loss: 9.2175e-04
# Epoch 189/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0068 - val_loss: 8.0053e-04
# Epoch 190/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0069 - val_loss: 9.4904e-04
# Epoch 191/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0067 - val_loss: 8.6599e-04
# Epoch 192/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0070 - val_loss: 0.0010
# Epoch 193/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0070 - val_loss: 0.0011
# Epoch 194/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0057 - val_loss: 0.0013
# Epoch 195/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0063 - val_loss: 9.0862e-04
# Epoch 196/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0062 - val_loss: 9.6915e-04
# Epoch 197/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0073 - val_loss: 0.0010
# Epoch 198/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0062 - val_loss: 9.0834e-04
# Epoch 199/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0060 - val_loss: 0.0011
# Epoch 200/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0069 - val_loss: 0.0011
# Epoch 201/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0065 - val_loss: 9.0087e-04
# Epoch 202/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0068 - val_loss: 0.0010
# Epoch 203/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0067 - val_loss: 7.5271e-04
# Epoch 204/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0071 - val_loss: 0.0013
# Epoch 205/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0072 - val_loss: 9.6802e-04
# Epoch 206/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0064 - val_loss: 0.0012
# Epoch 207/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0069 - val_loss: 9.5831e-04
# Epoch 208/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0067 - val_loss: 0.0016
# Epoch 209/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0075 - val_loss: 0.0013
# Epoch 210/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0072 - val_loss: 9.4299e-04
# Epoch 211/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0070 - val_loss: 8.1088e-04
# Epoch 212/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0063 - val_loss: 8.8770e-04
# Epoch 213/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0063 - val_loss: 8.9472e-04
# Epoch 214/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0073 - val_loss: 6.9076e-04
# Epoch 215/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0060 - val_loss: 0.0013
# Epoch 216/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0063 - val_loss: 0.0015
# Epoch 217/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0067 - val_loss: 0.0013
# Epoch 218/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0060 - val_loss: 8.3732e-04
# Epoch 219/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0069 - val_loss: 0.0011
# Epoch 220/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0069 - val_loss: 0.0011
# Epoch 221/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0069 - val_loss: 8.0905e-04
# Epoch 222/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0062 - val_loss: 9.9933e-04
# Epoch 223/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0064 - val_loss: 0.0015
# Epoch 224/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0064 - val_loss: 8.1160e-04
# Epoch 225/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0070 - val_loss: 7.8829e-04
# Epoch 226/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0062 - val_loss: 8.6331e-04
# Epoch 227/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0062 - val_loss: 8.3342e-04
# Epoch 228/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0059 - val_loss: 8.6180e-04
# Epoch 229/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0066 - val_loss: 0.0013
# Epoch 230/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0068 - val_loss: 0.0017
# Epoch 231/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0064 - val_loss: 7.5668e-04
# Epoch 232/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0068 - val_loss: 8.0697e-04
# Epoch 233/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0065 - val_loss: 8.1480e-04
# Epoch 234/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0065 - val_loss: 8.7945e-04
# Epoch 235/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0066 - val_loss: 9.5216e-04
# Epoch 236/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0070 - val_loss: 0.0023
# Epoch 237/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0073 - val_loss: 0.0015
# Epoch 238/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0072 - val_loss: 7.4649e-04
# Epoch 239/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0064 - val_loss: 9.9844e-04
# Epoch 240/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0069 - val_loss: 0.0018
# Epoch 241/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0067 - val_loss: 0.0012
# Epoch 242/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0068 - val_loss: 7.5668e-04
# Epoch 243/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0066 - val_loss: 8.4958e-04
# Epoch 244/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0071 - val_loss: 0.0018
# Epoch 245/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0071 - val_loss: 6.7488e-04
# Epoch 246/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0071 - val_loss: 7.2418e-04
# Epoch 247/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0065 - val_loss: 9.3944e-04
# Epoch 248/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0070 - val_loss: 6.8543e-04
# Epoch 249/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0074 - val_loss: 8.1482e-04
# Epoch 250/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0070 - val_loss: 7.9262e-04
# Epoch 251/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0068 - val_loss: 9.6221e-04
# Epoch 252/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0066 - val_loss: 0.0015
# Epoch 253/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0064 - val_loss: 0.0016
# Epoch 254/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0075 - val_loss: 7.3109e-04
# Epoch 255/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0061 - val_loss: 7.3281e-04
# Epoch 256/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0059 - val_loss: 0.0016
# Epoch 257/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0065 - val_loss: 7.6221e-04
# Epoch 258/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0064 - val_loss: 9.8144e-04
# Epoch 259/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0070 - val_loss: 7.5567e-04
# Epoch 260/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0057 - val_loss: 8.0734e-04
# Epoch 261/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0060 - val_loss: 7.4768e-04
# Epoch 262/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0066 - val_loss: 8.0518e-04
# Epoch 263/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0067 - val_loss: 9.5541e-04
# Epoch 264/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0061 - val_loss: 8.6993e-04
# Epoch 265/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0061 - val_loss: 7.3933e-04
# Epoch 266/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0068 - val_loss: 0.0011
# Epoch 267/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0072 - val_loss: 6.5831e-04
# Epoch 268/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0074 - val_loss: 6.8930e-04
# Epoch 269/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0066 - val_loss: 8.4045e-04
# Epoch 270/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0062 - val_loss: 9.5235e-04
# Epoch 271/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0076 - val_loss: 0.0019
# Epoch 272/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0072 - val_loss: 7.9270e-04
# Epoch 273/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0063 - val_loss: 7.9368e-04
# Epoch 274/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0061 - val_loss: 6.7241e-04
# Epoch 275/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0055 - val_loss: 8.7315e-04
# Epoch 276/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0067 - val_loss: 0.0010
# Epoch 277/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0067 - val_loss: 9.3272e-04
# Epoch 278/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0065 - val_loss: 7.2039e-04
# Epoch 279/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0065 - val_loss: 8.0367e-04
# Epoch 280/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0062 - val_loss: 8.9078e-04
# Epoch 281/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0063 - val_loss: 7.6164e-04
# Epoch 282/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0058 - val_loss: 0.0011
# Epoch 283/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0058 - val_loss: 0.0014
# Epoch 284/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0059 - val_loss: 6.9637e-04
# Epoch 285/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0063 - val_loss: 0.0011
# Epoch 286/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0057 - val_loss: 7.6297e-04
# Epoch 287/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0062 - val_loss: 0.0011
# Epoch 288/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0063 - val_loss: 9.1235e-04
# Epoch 289/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0062 - val_loss: 9.6278e-04
# Epoch 290/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0061 - val_loss: 0.0011
# Epoch 291/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0067 - val_loss: 7.1319e-04
# Epoch 292/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0065 - val_loss: 6.4328e-04
# Epoch 293/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0070 - val_loss: 0.0014
# Epoch 294/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0070 - val_loss: 7.9098e-04
# Epoch 295/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0059 - val_loss: 8.3778e-04
# Epoch 296/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0068 - val_loss: 7.4683e-04
# Epoch 297/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0068 - val_loss: 8.0461e-04
# Epoch 298/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0063 - val_loss: 7.1047e-04
# Epoch 299/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0067 - val_loss: 8.1962e-04
# Epoch 300/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0066 - val_loss: 0.0018
# Epoch 301/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0062 - val_loss: 0.0014
# Epoch 302/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0064 - val_loss: 6.0554e-04
# Epoch 303/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0055 - val_loss: 8.0113e-04
# Epoch 304/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0059 - val_loss: 9.1318e-04
# Epoch 305/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0068 - val_loss: 0.0014
# Epoch 306/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0070 - val_loss: 8.9103e-04
# Epoch 307/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0067 - val_loss: 0.0012
# Epoch 308/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0061 - val_loss: 8.6161e-04
# Epoch 309/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0067 - val_loss: 9.8705e-04
# Epoch 310/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0065 - val_loss: 7.5934e-04
# Epoch 311/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0062 - val_loss: 0.0012
# Epoch 312/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0066 - val_loss: 8.0699e-04
# Epoch 313/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0067 - val_loss: 0.0011
# Epoch 314/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0065 - val_loss: 6.8576e-04
# Epoch 315/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0069 - val_loss: 0.0020
# Epoch 316/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0061 - val_loss: 7.7373e-04
# Epoch 317/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0054 - val_loss: 7.8352e-04
# Epoch 318/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0064 - val_loss: 6.1611e-04
# Epoch 319/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0060 - val_loss: 6.7029e-04
# Epoch 320/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0063 - val_loss: 7.9837e-04
# Epoch 321/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0056 - val_loss: 6.9227e-04
# Epoch 322/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0056 - val_loss: 6.6926e-04
# Epoch 323/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0062 - val_loss: 6.4732e-04
# Epoch 324/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0060 - val_loss: 6.3057e-04
# Epoch 325/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0064 - val_loss: 9.4300e-04
# Epoch 326/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0058 - val_loss: 9.8038e-04
# Epoch 327/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0061 - val_loss: 7.3877e-04
# Epoch 328/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0073 - val_loss: 0.0010
# Epoch 329/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0058 - val_loss: 8.2013e-04
# Epoch 330/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0062 - val_loss: 7.4466e-04
# Epoch 331/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0063 - val_loss: 6.4163e-04
# Epoch 332/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0070 - val_loss: 0.0027
# Epoch 333/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0075 - val_loss: 8.5362e-04
# Epoch 334/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0069 - val_loss: 0.0013
# Epoch 335/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0062 - val_loss: 7.3024e-04
# Epoch 336/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0066 - val_loss: 0.0010
# Epoch 337/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0064 - val_loss: 7.1528e-04
# Epoch 338/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0061 - val_loss: 6.3493e-04
# Epoch 339/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0062 - val_loss: 6.1139e-04
# Epoch 340/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0066 - val_loss: 6.9809e-04
# Epoch 341/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0063 - val_loss: 0.0015
# Epoch 342/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0060 - val_loss: 0.0011
# Epoch 343/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0061 - val_loss: 0.0016
# Epoch 344/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0064 - val_loss: 9.7412e-04
# Epoch 345/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0061 - val_loss: 0.0011
# Epoch 346/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0067 - val_loss: 0.0011
# Epoch 347/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0063 - val_loss: 0.0012
# Epoch 348/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0061 - val_loss: 7.0128e-04
# Epoch 349/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0066 - val_loss: 0.0012
# Epoch 350/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0067 - val_loss: 5.6117e-04
# Epoch 351/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0063 - val_loss: 7.2040e-04
# Epoch 352/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0058 - val_loss: 7.3955e-04
# Epoch 353/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0065 - val_loss: 8.7044e-04
# Epoch 354/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0062 - val_loss: 7.2475e-04
# Epoch 355/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0061 - val_loss: 6.7520e-04
# Epoch 356/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0064 - val_loss: 8.9495e-04
# Epoch 357/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0063 - val_loss: 7.7553e-04
# Epoch 358/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0062 - val_loss: 0.0011
# Epoch 359/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0072 - val_loss: 6.7814e-04
# Epoch 360/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0061 - val_loss: 0.0017
# Epoch 361/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0060 - val_loss: 7.2089e-04
# Epoch 362/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0064 - val_loss: 7.6577e-04
# Epoch 363/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0069 - val_loss: 8.5558e-04
# Epoch 364/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0059 - val_loss: 0.0011
# Epoch 365/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0055 - val_loss: 6.0549e-04
# Epoch 366/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0060 - val_loss: 5.6258e-04
# Epoch 367/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0057 - val_loss: 8.3089e-04
# Epoch 368/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0061 - val_loss: 0.0014
# Epoch 369/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0065 - val_loss: 0.0012
# Epoch 370/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0064 - val_loss: 6.5579e-04
# Epoch 371/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0071 - val_loss: 6.5182e-04
# Epoch 372/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0066 - val_loss: 9.4783e-04
# Epoch 373/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0059 - val_loss: 8.0025e-04
# Epoch 374/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0062 - val_loss: 6.6250e-04
# Epoch 375/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0057 - val_loss: 0.0011
# Epoch 376/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0057 - val_loss: 6.3538e-04
# Epoch 377/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0063 - val_loss: 6.6913e-04
# Epoch 378/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0063 - val_loss: 6.5310e-04
# Epoch 379/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0059 - val_loss: 0.0015
# Epoch 380/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0060 - val_loss: 0.0011
# Epoch 381/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0055 - val_loss: 9.2505e-04
# Epoch 382/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0057 - val_loss: 9.4067e-04
# Epoch 383/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0065 - val_loss: 6.5181e-04
# Epoch 384/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0065 - val_loss: 0.0017
# Epoch 385/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0056 - val_loss: 7.5410e-04
# Epoch 386/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0057 - val_loss: 7.4571e-04
# Epoch 387/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0060 - val_loss: 0.0015
# Epoch 388/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0060 - val_loss: 5.5957e-04
# Epoch 389/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0062 - val_loss: 0.0019
# Epoch 390/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0061 - val_loss: 6.2394e-04
# Epoch 391/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0060 - val_loss: 8.9966e-04
# Epoch 392/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0061 - val_loss: 6.0487e-04
# Epoch 393/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0061 - val_loss: 6.4508e-04
# Epoch 394/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0056 - val_loss: 9.6224e-04
# Epoch 395/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0066 - val_loss: 0.0016
# Epoch 396/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0062 - val_loss: 6.2860e-04
# Epoch 397/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0066 - val_loss: 7.6919e-04
# Epoch 398/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0060 - val_loss: 5.5043e-04
# Epoch 399/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0064 - val_loss: 0.0011
# Epoch 400/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0065 - val_loss: 8.3344e-04
# Epoch 401/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0060 - val_loss: 9.5441e-04
# Epoch 402/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0058 - val_loss: 6.0365e-04
# Epoch 403/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0061 - val_loss: 6.5079e-04
# Epoch 404/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0057 - val_loss: 6.0864e-04
# Epoch 405/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0052 - val_loss: 6.1495e-04
# Epoch 406/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0055 - val_loss: 7.9397e-04
# Epoch 407/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0063 - val_loss: 8.8848e-04
# Epoch 408/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0064 - val_loss: 8.5173e-04
# Epoch 409/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0065 - val_loss: 0.0012
# Epoch 410/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0065 - val_loss: 6.6386e-04
# Epoch 411/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0057 - val_loss: 9.2162e-04
# Epoch 412/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0054 - val_loss: 0.0011
# Epoch 413/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0059 - val_loss: 5.8352e-04
# Epoch 414/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0056 - val_loss: 6.3091e-04
# Epoch 415/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0062 - val_loss: 0.0011
# Epoch 416/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0062 - val_loss: 7.1091e-04
# Epoch 417/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0060 - val_loss: 5.8919e-04
# Epoch 418/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0064 - val_loss: 0.0012
# Epoch 419/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0062 - val_loss: 8.4313e-04
# Epoch 420/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0056 - val_loss: 7.9213e-04
# Epoch 421/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0058 - val_loss: 6.5675e-04
# Epoch 422/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0061 - val_loss: 0.0016
# Epoch 423/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0057 - val_loss: 6.0370e-04
# Epoch 424/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0066 - val_loss: 0.0013
# Epoch 425/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0056 - val_loss: 5.9800e-04
# Epoch 426/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0065 - val_loss: 0.0010
# Epoch 427/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0059 - val_loss: 6.6358e-04
# Epoch 428/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0060 - val_loss: 6.3397e-04
# Epoch 429/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0064 - val_loss: 0.0015
# Epoch 430/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0064 - val_loss: 6.9838e-04
# Epoch 431/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0058 - val_loss: 5.2008e-04
# Epoch 432/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0063 - val_loss: 6.4705e-04
# Epoch 433/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0061 - val_loss: 0.0012
# Epoch 434/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0059 - val_loss: 7.0532e-04
# Epoch 435/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0059 - val_loss: 7.3008e-04
# Epoch 436/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0060 - val_loss: 0.0011
# Epoch 437/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0059 - val_loss: 6.1705e-04
# Epoch 438/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0059 - val_loss: 7.7705e-04
# Epoch 439/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0054 - val_loss: 9.2350e-04
# Epoch 440/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0061 - val_loss: 0.0011
# Epoch 441/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0056 - val_loss: 5.8233e-04
# Epoch 442/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0059 - val_loss: 0.0012
# Epoch 443/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0057 - val_loss: 7.0710e-04
# Epoch 444/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0062 - val_loss: 5.9853e-04
# Epoch 445/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0057 - val_loss: 7.4098e-04
# Epoch 446/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0056 - val_loss: 8.5322e-04
# Epoch 447/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0059 - val_loss: 8.0059e-04
# Epoch 448/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0060 - val_loss: 5.3937e-04
# Epoch 449/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0063 - val_loss: 6.3267e-04
# Epoch 450/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0061 - val_loss: 5.2977e-04
# Epoch 451/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0060 - val_loss: 6.0477e-04
# Epoch 452/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0060 - val_loss: 6.2189e-04
# Epoch 453/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0062 - val_loss: 0.0024
# Epoch 454/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0068 - val_loss: 6.8126e-04
# Epoch 455/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0070 - val_loss: 0.0025
# Epoch 456/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0079 - val_loss: 0.0014
# Epoch 457/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0059 - val_loss: 6.0981e-04
# Epoch 458/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0060 - val_loss: 6.4195e-04
# Epoch 459/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0057 - val_loss: 0.0010
# Epoch 460/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0058 - val_loss: 6.7041e-04
# Epoch 461/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0058 - val_loss: 8.5987e-04
# Epoch 462/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0058 - val_loss: 8.3773e-04
# Epoch 463/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0059 - val_loss: 6.1549e-04
# Epoch 464/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0061 - val_loss: 6.6716e-04
# Epoch 465/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0055 - val_loss: 0.0012
# Epoch 466/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0056 - val_loss: 6.2057e-04
# Epoch 467/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0065 - val_loss: 0.0010
# Epoch 468/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0060 - val_loss: 8.8912e-04
# Epoch 469/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0059 - val_loss: 6.1138e-04
# Epoch 470/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0059 - val_loss: 7.5332e-04
# Epoch 471/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0060 - val_loss: 0.0011
# Epoch 472/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0068 - val_loss: 7.9738e-04
# Epoch 473/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0062 - val_loss: 6.9543e-04
# Epoch 474/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0063 - val_loss: 5.4203e-04
# Epoch 475/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0053 - val_loss: 0.0011
# Epoch 476/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0059 - val_loss: 6.6897e-04
# Epoch 477/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0052 - val_loss: 7.2130e-04
# Epoch 478/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0060 - val_loss: 6.2295e-04
# Epoch 479/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0055 - val_loss: 6.7025e-04
# Epoch 480/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0065 - val_loss: 7.2336e-04
# Epoch 481/1000
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0061 - val_loss: 5.6682e-04

# %%
# 12. Dự báo dữ liệu test, val
train_predict=model.predict(X_train)
y_pred=model.predict(X_test)
y_pred_val=model.predict(X_val)

# In shape của từng tập dư liệu
print(train_predict.shape, y_pred.shape, y_pred_val.shape)
# Out:
# 34/34 [==============================] - 0s 947us/step
# 10/10 [==============================] - 0s 1ms/step
# 5/5 [==============================] - 0s 2ms/step
# (1082, 1) (307, 1) (153, 1)

# %%
# 13. In shape của từng tập dư liệu y real
print(y_train.shape, ytest.shape, yval.shape)
# Out:
# (1082,) (307,) (153,)

# %%
# 14. Chuẩn hóa dữ liệu y_pred, y_pred_val
train_predict=scaler.inverse_transform(train_predict)
y_pred=scaler.inverse_transform(y_pred)
y_pred_val=scaler.inverse_transform(y_pred_val)

# in head
print(train_predict[:5])
# Out:
# [[3547.7754]
#  [5149.416 ]
#  [5384.754 ]
#  [4603.3237]
#  [3362.5962]]

# %%
# 15. Chuẩn hóa ngược lại yval và ytest và y_train sau khi đã reshape
y_train = y_train.reshape(y_train.shape[0],1)
ytest = ytest.reshape(ytest.shape[0],1)
yval = yval.reshape(yval.shape[0],1)

y_train=scaler.inverse_transform(y_train)
ytest=scaler.inverse_transform(ytest)
yval=scaler.inverse_transform(yval)

#in head
print(y_train[:5])
# Out:
# [[3836.741211]
#  [3857.717529]
#  [3845.19458 ]
#  [4076.632568]
#  [4025.248291]]

# %%
# 16. Đánh giá độ chính xác thuật toán bằng MAE va RMSE
import math
from sklearn.metrics import mean_squared_error, mean_absolute_error


print('Train Mean Absolute Error:', mean_absolute_error(y_train, train_predict[:,0]))
print('Test Mean Absolute Error:', mean_absolute_error(ytest, y_pred[:,0]))
print('Val Mean Absolute Error:', mean_absolute_error(yval, y_pred_val[:,0]))
print('Train Root Mean Squared Error:',np.sqrt(mean_squared_error(y_train, train_predict[:,0])))
print('Test Root Mean Squared Error:',np.sqrt(mean_squared_error(ytest, y_pred[:,0])))
print('Val Root Mean Squared Error:',np.sqrt(mean_squared_error(yval, y_pred_val[:,0])))
# Out:
# Train Mean Absolute Error: 1165.5198990069605
# Test Mean Absolute Error: 1172.2992096274431
# Val Mean Absolute Error: 975.6289062622548
# Train Root Mean Squared Error: 1578.8460955203814
# Test Root Mean Squared Error: 1564.7076891055754
# Val Root Mean Squared Error: 1232.4046105147802

# %%
# 17. Đánh giá model bằng MAPE
def mean_absolute_percentage_error(y_true, y_pred):
    return numpy.mean(numpy.abs((y_true - y_pred) / y_true)) * 100

print('Train Mean Absolute Percentage Error:', mean_absolute_percentage_error(y_train[:,0], train_predict[:,0]))
print('Test Mean Absolute Percentage Error:', mean_absolute_percentage_error(ytest[:,0], y_pred[:,0]))
print('Val Mean Absolute Percentage Error:', mean_absolute_percentage_error(yval[:,0], y_pred_val[:,0]))
print('Train Score: %.2f MAPE' % (mean_absolute_percentage_error(y_train[:,0], train_predict[:,0])))
print('Test Score: %.2f MAPE' % (mean_absolute_percentage_error(ytest[:,0], y_pred[:,0])))
print('Val Score: %.2f MAPE' % (mean_absolute_percentage_error(yval[:,0], y_pred_val[:,0])))
# Out:
# Train Mean Absolute Percentage Error: 8.71275686928768
# Test Mean Absolute Percentage Error: 3.9516812613109695
# Val Mean Absolute Percentage Error: 4.8083198209590785
# Train Score: 8.71 MAPE
# Test Score: 3.95 MAPE
# Val Score: 4.81 MAPE

# %%
# 18. Lấy time_step ngày cuối cùng của dữ liệu train để dự đoán 30 ngày tiếp theo
x_input = val_data[-time_step:].reshape(-1, 1)   #[-time_step:] lấy time_step phần tử cuối cùng của dữ liệu
print("x_input.shape = ", x_input.shape)

# Dự đoán 30 ngày tiếp theo
lst_output = []

i = 1  # Biến đếm để dừng vòng lặp while
while(i <= 30):
    print("-----------------")
    # Đưa về mảng 1 chiều
    list_input = x_input.reshape(1, -1)[0]
    # in ra x_input của ngày thứ i trong 30 ngày tiếp theo
    print("day ", i, " have input = ", list_input)

    # Dự đoán giá đóng của ngày tiếp theo
    x_input = x_input.reshape(1, time_step, 1) # reshape lại về dạng (1, time_step, 1)
    yhat = model.predict(x_input, verbose=0) # dự đoán giá đóng của ngày tiếp theo

    # in ra giá đóng của ngày thứ i trong 30 ngày tiếp theo
    print("day ",i," have output = ", yhat[0][0])

    # thêm giá đóng của ngày thứ i vào lst_output
    lst_output.append(yhat[0][0])

    # Xóa phần tử đầu tiên x_input
    x_input = np.delete(x_input, 0)
    # thêm yhat vào x_input
    x_input = np.append(x_input, yhat[0][0])
    # Tăng biến đếm lên 1
    i = i + 1
# Out:
# x_input.shape =  (2, 1)
# -----------------
# day  1  have input =  [0.38390378 0.39083755]
# day  1  have output =  0.3860631
# -----------------
# day  2  have input =  [0.39083755 0.3860631 ]
# day  2  have output =  0.37715006
# -----------------
# day  3  have input =  [0.3860631  0.37715006]
# day  3  have output =  0.37854058
# -----------------
# day  4  have input =  [0.37715006 0.37854058]
# day  4  have output =  0.37927103
# -----------------
# day  5  have input =  [0.37854058 0.37927103]
# day  5  have output =  0.40073472
# -----------------
# day  6  have input =  [0.37927103 0.40073472]
# day  6  have output =  0.43066067
# -----------------
# day  7  have input =  [0.40073472 0.43066067]
# day  7  have output =  0.42783764
# -----------------
# day  8  have input =  [0.43066067 0.42783764]
# day  8  have output =  0.44145417
# -----------------
# day  9  have input =  [0.42783764 0.44145417]
# day  9  have output =  0.45603836
# -----------------
# day  10  have input =  [0.44145417 0.45603836]
# day  10  have output =  0.44897127
# -----------------
# day  11  have input =  [0.45603836 0.44897127]
# day  11  have output =  0.4400208
# -----------------
# day  12  have input =  [0.44897127 0.4400208 ]
# day  12  have output =  0.4358424
# -----------------
# day  13  have input =  [0.4400208  0.43584239]
# day  13  have output =  0.40840113
# -----------------
# day  14  have input =  [0.43584239 0.40840113]
# day  14  have output =  0.42050403
# -----------------
# day  15  have input =  [0.40840113 0.42050403]
# day  15  have output =  0.44119602
# -----------------
# day  16  have input =  [0.42050403 0.44119602]
# day  16  have output =  0.43916267
# -----------------
# day  17  have input =  [0.44119602 0.43916267]
# day  17  have output =  0.43759325
# -----------------
# day  18  have input =  [0.43916267 0.43759325]
# day  18  have output =  0.418911
# -----------------
# day  19  have input =  [0.43759325 0.41891101]
# day  19  have output =  0.4214219
# -----------------
# day  20  have input =  [0.41891101 0.42142189]
# day  20  have output =  0.44886768
# -----------------
# day  21  have input =  [0.42142189 0.44886768]
# day  21  have output =  0.45702344
# -----------------
# day  22  have input =  [0.44886768 0.45702344]
# day  22  have output =  0.4714492
# -----------------
# day  23  have input =  [0.45702344 0.4714492 ]
# day  23  have output =  0.46817607
# -----------------
# day  24  have input =  [0.4714492  0.46817607]
# day  24  have output =  0.47974062
# -----------------
# day  25  have input =  [0.46817607 0.47974062]
# day  25  have output =  0.49528363
# -----------------
# day  26  have input =  [0.47974062 0.49528363]
# day  26  have output =  0.48009562
# -----------------
# day  27  have input =  [0.49528363 0.48009562]
# day  27  have output =  0.47160733
# -----------------
# day  28  have input =  [0.48009562 0.47160733]
# day  28  have output =  0.4789517
# -----------------
# day  29  have input =  [0.47160733 0.47895169]
# day  29  have output =  0.48032486
# -----------------
# day  30  have input =  [0.47895169 0.48032486]
# day  30  have output =  0.48080704

# %%
# 19.In ra 30 ngày tiếp theo
print(lst_output)
# Out:
# [0.3860631, 0.37715006, 0.37854058, 0.37927103, 0.40073472, 0.43066067, 0.42783764, 0.44145417, 0.45603836, 0.44897127, 0.4400208, 0.4358424, 0.40840113, 0.42050403, 0.44119602, 0.43916267, 0.43759325, 0.418911, 0.4214219, 0.44886768, 0.45702344, 0.4714492, 0.46817607, 0.47974062, 0.49528363, 0.48009562, 0.47160733, 0.4789517, 0.48032486, 0.48080704]

# %%
# 20. Tạo mảng index tương ứng với các ngày
days = np.array(range(len(df), len(df) + len(lst_output)))

# Vẽ biểu đồ
plt.figure(figsize=(20,10))
plt.plot(days, lst_output, c='r', label='Next 30 days')
plt.plot(df1, c='black', label='Real data')
plt.show()

# %%
# 21.vẽ next 30 days
plt.figure(figsize=(20,10))
plt.plot(days, lst_output, c='r', label='Next 30 days')
plt.show()

# %%
# 22.Chuẩn hóa dữ liệu và chuyển đổi các giá trị dự đoán trở lại đơn vị ban đầu
train_data_inverse=scaler.inverse_transform(np.array(train_data).reshape(-1, 1))
test_data_inverse=scaler.inverse_transform(np.array(test_data).reshape(-1, 1))
val_data_inverse=scaler.inverse_transform(np.array(val_data).reshape(-1, 1))
next_30_days_inverse=scaler.inverse_transform(np.array(lst_output).reshape(-1, 1))

# in dữ liệu
print(train_data_inverse[:5])
print(test_data_inverse[:5])
print(val_data_inverse[:5])
print(next_30_days_inverse[:5])
# Out:
# [[3843.52002 ]
#  [3943.409424]
#  [3836.741211]
#  [3857.717529]
#  [3845.19458 ]]
# [[48936.61328]
#  [48628.51172]
#  [50784.53906]
#  [50822.19531]
#  [50429.85938]]
# [[20285.83594]
#  [20595.35156]
#  [20818.47656]
#  [20635.60352]
#  [20495.77344]]
# [[28172.121]
#  [27600.195]
#  [27689.42 ]
#  [27736.291]
#  [29113.56 ]]

# %%
# 23 .vẽ y_train nối với ytest và y_val với index tương ứng

train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
test_data_index = pd.RangeIndex(start=train_size, stop=train_size+test_size, step=1)
val_data_index = pd.RangeIndex(start=train_size+test_size, stop=train_size+test_size+val_size, step=1)
predict30_data_index = pd.RangeIndex(start=train_size+test_size+val_size, stop=train_size+test_size+val_size+30, step=1)

train_predict_index = pd.RangeIndex(start=0, stop=train_predict.shape[0], step=1)
y_pred_index = pd.RangeIndex(start=train_size+(train_size-train_predict.shape[0]), stop=train_size+(train_size-train_predict.shape[0])+y_pred.shape[0], step=1)
y_pred_val_index = pd.RangeIndex(start=train_size+(train_size-train_predict.shape[0])+y_pred.shape[0]+(val_size-y_pred_val.shape[0]), stop=train_size+(train_size-train_predict.shape[0])+y_pred.shape[0]+y_pred_val.shape[0]+(val_size-y_pred_val.shape[0]), step=1)
plt.figure(figsize=(20,10))
plt.grid(True)
plt.plot(train_data_index, train_data_inverse,  label='Train data')
plt.plot(test_data_index, test_data_inverse, label='Test data')
plt.plot(val_data_index, val_data_inverse,  label='Val data')
plt.plot(predict30_data_index, next_30_days_inverse, label='Predict 30 days')
plt.plot(y_pred_index, y_pred, label='Test predict')
plt.plot(y_pred_val_index, y_pred_val,  label='Val predict')
# trục x là giá trị của cột Close time của df1
plt.xticks(np.arange(0, len(df1), 100), df['Date'][0:len(df):100])
plt.xticks(rotation=60)
plt.legend()
plt.show()

# %%
# PHẦN THÊM : Đánh giá bằng R-Squared
from sklearn.metrics import r2_score
r_squared = r2_score(ytest, y_pred)
print("Test_R-squared: ", r_squared)
r_squared = r2_score(yval, y_pred_val)
print("Val_R-squared: ", r_squared)
# Out:
# Test_R-squared:  0.9760730942885544
# Val_R-squared:  0.8858072263540773
