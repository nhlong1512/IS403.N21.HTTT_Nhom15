# %%
# 1. Import thư viện cần thiết
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# %%
# 2. Đọc file csv và gắn index với giá Close
df = pd.read_csv('BTC-USD.csv')
df1=df.reset_index()['Close']
plt.plot(df1)

# %%
# 3. Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
# 4. Chia train test
train_size = int(0.6 * len(df1))
test_size = int(0.3 * len(df1))
val_size = len(df1) - train_size - test_size

train_data = df1[:train_size]
test_data = df1[train_size:train_size+test_size]
val_data = df1[train_size+test_size:]
print(df1)
# Out:
# [[0.00692016]
#  [0.00847686]
#  [0.00681452]
#  ...
#  [0.38881093]
#  [0.38390378]
#  [0.39083755]]

# %%
#in shape của từng tập dư liệu train, test, val
print("Train shape: ",train_data.shape)
print("Test shape: ",test_data.shape)
print("Val shape: ",val_data.shape)
# Out:
# Train shape:  (930, 1)
# Test shape:  (465, 1)
# Val shape:  (156, 1)

# %%
# 5. Hàm Create Dataset
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, X=0,1,2,3-----99   Y=100
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return numpy.array(dataX), numpy.array(dataY)

# %%
#6. Reshape into X=t,t+1,t+2..t+99 and Y=t+100
time_step = 2
X_train, y_train = create_dataset(train_data, time_step)
X_val, yval = create_dataset(val_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
# 7. Reshape input to be [samples, time steps, features] which is required for BNN
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)
X_val = X_val.reshape(X_val.shape[0],X_val.shape[1] , 1)

# %%
# 8. Import các thư viện cần thiết để xây dựng mô hình BNN (Bayesian Neural Network) với thư viện Keras
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
# Thư viện tensorflow_probability cung cấp các hàm cần thiết xây dựng BNN
import tensorflow_probability as tfp
# Thư viện tensorflow_probability.distributions cung cấp các phân phối xác suất cần thiết xây dựng BNN
tfd = tfp.distributions
# Thư viện tensorflow_probability.layers cung cấp các lớp cần thiết xây dựng BNN
tfpl = tfp.layers
# Thêm drop-out vào Model
from tensorflow.keras.layers import Dropout
# Thêm Adam ( Adaptive Moment Estimation)  vào model
from tensorflow.keras.optimizers import Adam
# Thêm Dense vào model
from tensorflow.keras.layers import Dense

# # Thêm flatten vào Model, flatten là một hàm được sử dụng để chuyển đổi một mảng nhiều chiều thành một mảng một chiều
# from tensorflow.keras.layers import Flatten

# Thêm early vào Model
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import Sequential

# %%
# 9. Define BNN Model
# Tạo một lớp phân phối Gaussian
class GaussianLayer(tfp.layers.DistributionLambda):
    def __init__(self, **kwargs):
        super(GaussianLayer, self).__init__(
            lambda t: tfp.distributions.Normal(loc=t, scale=1), **kwargs)

model = Sequential()
model.add(Dense(64, input_dim=X_train.shape[1]))

model.add(Dropout(0.2))
model.add(Dense(32))
model.add(Dropout(0.2))
model.add(Dense(16))
model.add(Dropout(0.2))
model.add(Dense(8))
model.add( GaussianLayer())
model.add(Dropout(0.2))
model.add(Dense(1))

# %%
# Compile model
model.compile(loss='mean_squared_error', optimizer=Adam(learning_rate=0.001))

# %%
# 11. Train model
early_stop = EarlyStopping(monitor='val_loss', patience=50)
history = model.fit(X_train, y_train, validation_data = (X_test, ytest), epochs=1000,batch_size=64, verbose=1,callbacks=[early_stop])
# sẽ dừng lại khi val_loss không còn giảm nữa sau 50 lần lặp, monitor là giá trị để theo dõi, ở đây là val_loss
# verbose=1 sẽ in ra thông tin khi dừng lại
# Out:
# Epoch 1/1000
# 15/15 [==============================] - 1s 11ms/step - loss: 1.4069 - val_loss: 1.0848
# Epoch 2/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 1.3119 - val_loss: 1.1546
# Epoch 3/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 1.1703 - val_loss: 0.9849
# Epoch 4/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 1.1456 - val_loss: 0.8226
# Epoch 5/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 1.1059 - val_loss: 0.7414
# Epoch 6/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 1.0316 - val_loss: 0.7220
# Epoch 7/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.8464 - val_loss: 0.6458
# Epoch 8/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.8748 - val_loss: 0.6902
# Epoch 9/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.8737 - val_loss: 0.5981
# Epoch 10/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.7435 - val_loss: 0.6314
# Epoch 11/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6784 - val_loss: 0.5636
# Epoch 12/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6590 - val_loss: 0.5342
# Epoch 13/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6695 - val_loss: 0.4898
# Epoch 14/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.5927 - val_loss: 0.4432
# Epoch 15/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.5526 - val_loss: 0.4567
# Epoch 16/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.5229 - val_loss: 0.3716
# Epoch 17/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.4538 - val_loss: 0.3341
# Epoch 18/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.4397 - val_loss: 0.3834
# Epoch 19/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.4627 - val_loss: 0.3339
# Epoch 20/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.3980 - val_loss: 0.2605
# Epoch 21/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.3627 - val_loss: 0.2764
# Epoch 22/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.3441 - val_loss: 0.2516
# Epoch 23/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.2881 - val_loss: 0.2150
# Epoch 24/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.2779 - val_loss: 0.2403
# Epoch 25/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2732 - val_loss: 0.2247
# Epoch 26/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.2881 - val_loss: 0.2119
# Epoch 27/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.2320 - val_loss: 0.1755
# Epoch 28/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.2087 - val_loss: 0.1568
# Epoch 29/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2086 - val_loss: 0.1506
# Epoch 30/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.2009 - val_loss: 0.1572
# Epoch 31/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.1889 - val_loss: 0.1483
# Epoch 32/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.1719 - val_loss: 0.1415
# Epoch 33/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.1523 - val_loss: 0.1157
# Epoch 34/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.1402 - val_loss: 0.1110
# Epoch 35/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.1360 - val_loss: 0.0999
# Epoch 36/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.1274 - val_loss: 0.0867
# Epoch 37/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.1150 - val_loss: 0.0896
# Epoch 38/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.1092 - val_loss: 0.0804
# Epoch 39/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.1048 - val_loss: 0.0759
# Epoch 40/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0949 - val_loss: 0.0720
# Epoch 41/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0847 - val_loss: 0.0685
# Epoch 42/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0789 - val_loss: 0.0643
# Epoch 43/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0763 - val_loss: 0.0582
# Epoch 44/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0759 - val_loss: 0.0550
# Epoch 45/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0643 - val_loss: 0.0468
# Epoch 46/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0585 - val_loss: 0.0394
# Epoch 47/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0562 - val_loss: 0.0472
# Epoch 48/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0525 - val_loss: 0.0399
# Epoch 49/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0474 - val_loss: 0.0372
# Epoch 50/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0460 - val_loss: 0.0364
# Epoch 51/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0422 - val_loss: 0.0309
# Epoch 52/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0374 - val_loss: 0.0249
# Epoch 53/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0367 - val_loss: 0.0254
# Epoch 54/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0312 - val_loss: 0.0226
# Epoch 55/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0310 - val_loss: 0.0169
# Epoch 56/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0273 - val_loss: 0.0224
# Epoch 57/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0280 - val_loss: 0.0180
# Epoch 58/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0249 - val_loss: 0.0170
# Epoch 59/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0224 - val_loss: 0.0142
# Epoch 60/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0221 - val_loss: 0.0170
# Epoch 61/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0203 - val_loss: 0.0152
# Epoch 62/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0173 - val_loss: 0.0149
# Epoch 63/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0174 - val_loss: 0.0131
# Epoch 64/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0168 - val_loss: 0.0118
# Epoch 65/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0162 - val_loss: 0.0094
# Epoch 66/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0135 - val_loss: 0.0088
# Epoch 67/1000
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0135 - val_loss: 0.0123
# Epoch 68/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0143 - val_loss: 0.0073
# Epoch 69/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0155 - val_loss: 0.0063
# Epoch 70/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0115 - val_loss: 0.0088
# Epoch 71/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0135 - val_loss: 0.0063
# Epoch 72/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0113 - val_loss: 0.0076
# Epoch 73/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0111 - val_loss: 0.0057
# Epoch 74/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0100 - val_loss: 0.0053
# Epoch 75/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0105 - val_loss: 0.0079
# Epoch 76/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0098 - val_loss: 0.0074
# Epoch 77/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0093 - val_loss: 0.0067
# Epoch 78/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0098 - val_loss: 0.0053
# Epoch 79/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0091 - val_loss: 0.0052
# Epoch 80/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0084 - val_loss: 0.0057
# Epoch 81/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0090 - val_loss: 0.0065
# Epoch 82/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0080 - val_loss: 0.0051
# Epoch 83/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0081 - val_loss: 0.0055
# Epoch 84/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0077 - val_loss: 0.0031
# Epoch 85/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0077 - val_loss: 0.0057
# Epoch 86/1000
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0075 - val_loss: 0.0023
# Epoch 87/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0077 - val_loss: 0.0058
# Epoch 88/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0074 - val_loss: 0.0026
# Epoch 89/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0068 - val_loss: 0.0028
# Epoch 90/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0069 - val_loss: 0.0023
# Epoch 91/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0066 - val_loss: 0.0057
# Epoch 92/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0076 - val_loss: 0.0021
# Epoch 93/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0072 - val_loss: 0.0064
# Epoch 94/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0065 - val_loss: 0.0029
# Epoch 95/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0070 - val_loss: 0.0056
# Epoch 96/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0069 - val_loss: 0.0036
# Epoch 97/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0067 - val_loss: 0.0021
# Epoch 98/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0069 - val_loss: 0.0042
# Epoch 99/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0060 - val_loss: 0.0041
# Epoch 100/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0068 - val_loss: 0.0032
# Epoch 101/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0062 - val_loss: 0.0024
# Epoch 102/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0061 - val_loss: 0.0023
# Epoch 103/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0066 - val_loss: 0.0018
# Epoch 104/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0073 - val_loss: 0.0031
# Epoch 105/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0057 - val_loss: 0.0065
# Epoch 106/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0065 - val_loss: 0.0024
# Epoch 107/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0058 - val_loss: 0.0018
# Epoch 108/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0064 - val_loss: 0.0024
# Epoch 109/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0073 - val_loss: 0.0023
# Epoch 110/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0054 - val_loss: 0.0091
# Epoch 111/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0070 - val_loss: 0.0017
# Epoch 112/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0059 - val_loss: 0.0033
# Epoch 113/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0063 - val_loss: 0.0020
# Epoch 114/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0066 - val_loss: 0.0018
# Epoch 115/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0068 - val_loss: 0.0045
# Epoch 116/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0051 - val_loss: 0.0042
# Epoch 117/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0063 - val_loss: 0.0032
# Epoch 118/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0063 - val_loss: 0.0022
# Epoch 119/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0060 - val_loss: 0.0036
# Epoch 120/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0058 - val_loss: 0.0014
# Epoch 121/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0065 - val_loss: 0.0079
# Epoch 122/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0053 - val_loss: 0.0036
# Epoch 123/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0054 - val_loss: 0.0032
# Epoch 124/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0049 - val_loss: 0.0013
# Epoch 125/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0056 - val_loss: 0.0017
# Epoch 126/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0059 - val_loss: 0.0022
# Epoch 127/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0056 - val_loss: 0.0042
# Epoch 128/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0051 - val_loss: 0.0021
# Epoch 129/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0056 - val_loss: 0.0020
# Epoch 130/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0048 - val_loss: 0.0026
# Epoch 131/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0051 - val_loss: 0.0041
# Epoch 132/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0056 - val_loss: 0.0015
# Epoch 133/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0062 - val_loss: 0.0013
# Epoch 134/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0051 - val_loss: 0.0011
# Epoch 135/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0052 - val_loss: 0.0019
# Epoch 136/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0053 - val_loss: 0.0015
# Epoch 137/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0058 - val_loss: 0.0037
# Epoch 138/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0063 - val_loss: 0.0034
# Epoch 139/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0056 - val_loss: 0.0027
# Epoch 140/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0067 - val_loss: 0.0011
# Epoch 141/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0058 - val_loss: 0.0011
# Epoch 142/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0055 - val_loss: 0.0011
# Epoch 143/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0057 - val_loss: 0.0012
# Epoch 144/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0054 - val_loss: 0.0011
# Epoch 145/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0059 - val_loss: 0.0020
# Epoch 146/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0057 - val_loss: 0.0041
# Epoch 147/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0059 - val_loss: 0.0063
# Epoch 148/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0058 - val_loss: 0.0037
# Epoch 149/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0058 - val_loss: 0.0012
# Epoch 150/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0052 - val_loss: 0.0015
# Epoch 151/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0047 - val_loss: 0.0072
# Epoch 152/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0058 - val_loss: 0.0045
# Epoch 153/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0055 - val_loss: 0.0017
# Epoch 154/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0047 - val_loss: 0.0018
# Epoch 155/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0065 - val_loss: 0.0016
# Epoch 156/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0050 - val_loss: 0.0018
# Epoch 157/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0053 - val_loss: 0.0020
# Epoch 158/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0055 - val_loss: 0.0011
# Epoch 159/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0058 - val_loss: 0.0013
# Epoch 160/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0056 - val_loss: 0.0022
# Epoch 161/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0047 - val_loss: 0.0047
# Epoch 162/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0051 - val_loss: 0.0016
# Epoch 163/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0056 - val_loss: 0.0011
# Epoch 164/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0057 - val_loss: 0.0026
# Epoch 165/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0057 - val_loss: 0.0015
# Epoch 166/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0065 - val_loss: 0.0013
# Epoch 167/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0053 - val_loss: 0.0013
# Epoch 168/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0051 - val_loss: 0.0077
# Epoch 169/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0060 - val_loss: 0.0103
# Epoch 170/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0057 - val_loss: 0.0090
# Epoch 171/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0058 - val_loss: 0.0036
# Epoch 172/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0038 - val_loss: 0.0034
# Epoch 173/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0052 - val_loss: 0.0024
# Epoch 174/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0055 - val_loss: 0.0016
# Epoch 175/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0018
# Epoch 176/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0052 - val_loss: 0.0014
# Epoch 177/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0046 - val_loss: 0.0042
# Epoch 178/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0049 - val_loss: 0.0019
# Epoch 179/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0051 - val_loss: 0.0015
# Epoch 180/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0057 - val_loss: 0.0012
# Epoch 181/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0049 - val_loss: 0.0020
# Epoch 182/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0043 - val_loss: 0.0021
# Epoch 183/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0052 - val_loss: 0.0012
# Epoch 184/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0053 - val_loss: 0.0010
# Epoch 185/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0051 - val_loss: 0.0014
# Epoch 186/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0050 - val_loss: 0.0014
# Epoch 187/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0049 - val_loss: 0.0011
# Epoch 188/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0053 - val_loss: 0.0016
# Epoch 189/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0058 - val_loss: 0.0012
# Epoch 190/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0052 - val_loss: 0.0011
# Epoch 191/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0050 - val_loss: 0.0011
# Epoch 192/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0055 - val_loss: 0.0011
# Epoch 193/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0042 - val_loss: 0.0011
# Epoch 194/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0050 - val_loss: 0.0010
# Epoch 195/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0046 - val_loss: 0.0021
# Epoch 196/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0046 - val_loss: 0.0013
# Epoch 197/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0053 - val_loss: 0.0013
# Epoch 198/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0045 - val_loss: 0.0029
# Epoch 199/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0045 - val_loss: 0.0028
# Epoch 200/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0055 - val_loss: 9.8963e-04
# Epoch 201/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0052 - val_loss: 0.0022
# Epoch 202/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0051 - val_loss: 0.0040
# Epoch 203/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0063 - val_loss: 0.0195
# Epoch 204/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0065 - val_loss: 0.0076
# Epoch 205/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0048 - val_loss: 0.0030
# Epoch 206/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0051 - val_loss: 0.0042
# Epoch 207/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0046 - val_loss: 9.8061e-04
# Epoch 208/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0048 - val_loss: 0.0011
# Epoch 209/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0049 - val_loss: 0.0015
# Epoch 210/1000
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0053 - val_loss: 0.0029
# Epoch 211/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0053 - val_loss: 0.0017
# Epoch 212/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0044 - val_loss: 0.0013
# Epoch 213/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0043 - val_loss: 0.0029
# Epoch 214/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0047 - val_loss: 0.0025
# Epoch 215/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0057 - val_loss: 0.0015
# Epoch 216/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0049 - val_loss: 0.0025
# Epoch 217/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0043 - val_loss: 0.0015
# Epoch 218/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0053 - val_loss: 0.0028
# Epoch 219/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0050 - val_loss: 0.0041
# Epoch 220/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0059 - val_loss: 0.0068
# Epoch 221/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0056 - val_loss: 0.0018
# Epoch 222/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0048 - val_loss: 0.0024
# Epoch 223/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0042 - val_loss: 0.0029
# Epoch 224/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0049 - val_loss: 0.0031
# Epoch 225/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0011
# Epoch 226/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0051 - val_loss: 0.0021
# Epoch 227/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0045 - val_loss: 9.4338e-04
# Epoch 228/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0055 - val_loss: 0.0027
# Epoch 229/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0050 - val_loss: 0.0010
# Epoch 230/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0044 - val_loss: 0.0014
# Epoch 231/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0047 - val_loss: 0.0011
# Epoch 232/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0047 - val_loss: 0.0013
# Epoch 233/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0055 - val_loss: 0.0015
# Epoch 234/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0048 - val_loss: 0.0048
# Epoch 235/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0064 - val_loss: 0.0046
# Epoch 236/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0059 - val_loss: 0.0028
# Epoch 237/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0052 - val_loss: 0.0046
# Epoch 238/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0047 - val_loss: 0.0027
# Epoch 239/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0045 - val_loss: 0.0040
# Epoch 240/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0049 - val_loss: 0.0011
# Epoch 241/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0048 - val_loss: 0.0014
# Epoch 242/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0011
# Epoch 243/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0045 - val_loss: 0.0029
# Epoch 244/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0050 - val_loss: 0.0021
# Epoch 245/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0045 - val_loss: 0.0057
# Epoch 246/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0047 - val_loss: 9.3535e-04
# Epoch 247/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0052 - val_loss: 0.0023
# Epoch 248/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0045 - val_loss: 0.0024
# Epoch 249/1000
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0041 - val_loss: 0.0024
# Epoch 250/1000
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0052 - val_loss: 0.0052
# Epoch 251/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0045 - val_loss: 0.0033
# Epoch 252/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0040 - val_loss: 0.0022
# Epoch 253/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0038 - val_loss: 9.5660e-04
# Epoch 254/1000
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0045 - val_loss: 0.0013
# Epoch 255/1000
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0044 - val_loss: 8.9642e-04
# Epoch 256/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0044 - val_loss: 0.0014
# Epoch 257/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0043 - val_loss: 8.8145e-04
# Epoch 258/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0042 - val_loss: 0.0015
# Epoch 259/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0039 - val_loss: 0.0033
# Epoch 260/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0044 - val_loss: 0.0080
# Epoch 261/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0053 - val_loss: 0.0043
# Epoch 262/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0043 - val_loss: 0.0026
# Epoch 263/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0047 - val_loss: 0.0042
# Epoch 264/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0041 - val_loss: 0.0039
# Epoch 265/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0054 - val_loss: 0.0026
# Epoch 266/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0042 - val_loss: 0.0014
# Epoch 267/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0042 - val_loss: 0.0012
# Epoch 268/1000
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0042 - val_loss: 0.0042
# Epoch 269/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0045 - val_loss: 0.0015
# Epoch 270/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0053 - val_loss: 0.0024
# Epoch 271/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0051 - val_loss: 9.4775e-04
# Epoch 272/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0046 - val_loss: 9.8568e-04
# Epoch 273/1000
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0043 - val_loss: 0.0044
# Epoch 274/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0050 - val_loss: 0.0033
# Epoch 275/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0046 - val_loss: 0.0024
# Epoch 276/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0017
# Epoch 277/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0043 - val_loss: 0.0010
# Epoch 278/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0045 - val_loss: 9.5864e-04
# Epoch 279/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0040 - val_loss: 0.0021
# Epoch 280/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0047 - val_loss: 0.0019
# Epoch 281/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0047 - val_loss: 0.0015
# Epoch 282/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0049 - val_loss: 0.0013
# Epoch 283/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0045 - val_loss: 0.0019
# Epoch 284/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0040 - val_loss: 0.0029
# Epoch 285/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0049 - val_loss: 0.0043
# Epoch 286/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0046 - val_loss: 0.0029
# Epoch 287/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0052 - val_loss: 0.0012
# Epoch 288/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0048 - val_loss: 0.0023
# Epoch 289/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0045 - val_loss: 0.0089
# Epoch 290/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0049 - val_loss: 0.0031
# Epoch 291/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0045 - val_loss: 9.3038e-04
# Epoch 292/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0044 - val_loss: 9.0108e-04
# Epoch 293/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0045 - val_loss: 0.0019
# Epoch 294/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0042 - val_loss: 0.0020
# Epoch 295/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0041 - val_loss: 0.0015
# Epoch 296/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0049 - val_loss: 9.9171e-04
# Epoch 297/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0046 - val_loss: 0.0013
# Epoch 298/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0048 - val_loss: 8.0636e-04
# Epoch 299/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0044 - val_loss: 8.3690e-04
# Epoch 300/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0049 - val_loss: 0.0010
# Epoch 301/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0045 - val_loss: 0.0046
# Epoch 302/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0043 - val_loss: 8.6877e-04
# Epoch 303/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0042 - val_loss: 0.0010
# Epoch 304/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0042 - val_loss: 0.0010
# Epoch 305/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0045 - val_loss: 8.6760e-04
# Epoch 306/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0047 - val_loss: 0.0057
# Epoch 307/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0040 - val_loss: 0.0022
# Epoch 308/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0044 - val_loss: 0.0037
# Epoch 309/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0047 - val_loss: 9.5206e-04
# Epoch 310/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0050 - val_loss: 8.2402e-04
# Epoch 311/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0042 - val_loss: 0.0030
# Epoch 312/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0045 - val_loss: 0.0031
# Epoch 313/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0047 - val_loss: 0.0027
# Epoch 314/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0043 - val_loss: 7.7251e-04
# Epoch 315/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0045 - val_loss: 0.0014
# Epoch 316/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0041 - val_loss: 0.0016
# Epoch 317/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0051 - val_loss: 0.0010
# Epoch 318/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0039 - val_loss: 0.0011
# Epoch 319/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0042 - val_loss: 9.1508e-04
# Epoch 320/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0053 - val_loss: 0.0066
# Epoch 321/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0056 - val_loss: 0.0032
# Epoch 322/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0041 - val_loss: 0.0032
# Epoch 323/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0038 - val_loss: 0.0022
# Epoch 324/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0041 - val_loss: 0.0020
# Epoch 325/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0045 - val_loss: 9.7991e-04
# Epoch 326/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0038 - val_loss: 0.0013
# Epoch 327/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0038 - val_loss: 0.0014
# Epoch 328/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0039 - val_loss: 8.0519e-04
# Epoch 329/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0040 - val_loss: 8.5351e-04
# Epoch 330/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0047 - val_loss: 0.0059
# Epoch 331/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0050 - val_loss: 0.0050
# Epoch 332/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0038 - val_loss: 0.0020
# Epoch 333/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0039 - val_loss: 9.8763e-04
# Epoch 334/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0039 - val_loss: 0.0016
# Epoch 335/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0048 - val_loss: 9.7097e-04
# Epoch 336/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 9.8771e-04
# Epoch 337/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0048 - val_loss: 0.0016
# Epoch 338/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0043 - val_loss: 0.0016
# Epoch 339/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0045 - val_loss: 7.6951e-04
# Epoch 340/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0041 - val_loss: 0.0016
# Epoch 341/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0042 - val_loss: 9.7282e-04
# Epoch 342/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0042 - val_loss: 8.1728e-04
# Epoch 343/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0047 - val_loss: 8.9765e-04
# Epoch 344/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0045 - val_loss: 8.5415e-04
# Epoch 345/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0044 - val_loss: 0.0021
# Epoch 346/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0044 - val_loss: 0.0015
# Epoch 347/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0038 - val_loss: 0.0033
# Epoch 348/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0050 - val_loss: 0.0020
# Epoch 349/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0048 - val_loss: 0.0041
# Epoch 350/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0050 - val_loss: 8.3409e-04
# Epoch 351/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0042 - val_loss: 8.3433e-04
# Epoch 352/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0043 - val_loss: 9.4464e-04
# Epoch 353/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0053 - val_loss: 0.0019
# Epoch 354/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0050 - val_loss: 0.0016
# Epoch 355/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0055 - val_loss: 0.0024
# Epoch 356/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0047 - val_loss: 0.0021
# Epoch 357/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0044 - val_loss: 0.0088
# Epoch 358/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0047 - val_loss: 0.0020
# Epoch 359/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0043 - val_loss: 7.6540e-04
# Epoch 360/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0047 - val_loss: 8.4274e-04
# Epoch 361/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0046 - val_loss: 8.3320e-04
# Epoch 362/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0040 - val_loss: 0.0020
# Epoch 363/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0045 - val_loss: 8.9193e-04
# Epoch 364/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0049 - val_loss: 7.8903e-04
# Epoch 365/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0042 - val_loss: 8.2790e-04
# Epoch 366/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0043 - val_loss: 9.6381e-04
# Epoch 367/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0043 - val_loss: 0.0025
# Epoch 368/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0058 - val_loss: 8.6271e-04
# Epoch 369/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0053 - val_loss: 8.1110e-04
# Epoch 370/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0043 - val_loss: 0.0016
# Epoch 371/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0040 - val_loss: 8.4216e-04
# Epoch 372/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0042 - val_loss: 0.0010
# Epoch 373/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0050 - val_loss: 0.0011
# Epoch 374/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0052 - val_loss: 0.0014
# Epoch 375/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0042 - val_loss: 9.8870e-04
# Epoch 376/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0043 - val_loss: 0.0016
# Epoch 377/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0038 - val_loss: 9.6268e-04
# Epoch 378/1000
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0046 - val_loss: 0.0017
# Epoch 379/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0041 - val_loss: 0.0016
# Epoch 380/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0040 - val_loss: 0.0010
# Epoch 381/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 8.4552e-04
# Epoch 382/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0040 - val_loss: 0.0019
# Epoch 383/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0040 - val_loss: 0.0018
# Epoch 384/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0040 - val_loss: 0.0015
# Epoch 385/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0055 - val_loss: 9.3341e-04
# Epoch 386/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0043 - val_loss: 0.0040
# Epoch 387/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0045 - val_loss: 0.0020
# Epoch 388/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0049 - val_loss: 0.0015
# Epoch 389/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0044 - val_loss: 8.9580e-04
# Epoch 390/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0043 - val_loss: 8.1830e-04
# Epoch 391/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0045 - val_loss: 0.0018
# Epoch 392/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0042 - val_loss: 0.0046
# Epoch 393/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0048 - val_loss: 0.0046
# Epoch 394/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0047 - val_loss: 0.0022
# Epoch 395/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0046 - val_loss: 0.0011
# Epoch 396/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0038 - val_loss: 7.9575e-04
# Epoch 397/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0049 - val_loss: 7.8207e-04
# Epoch 398/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0043 - val_loss: 0.0049
# Epoch 399/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0046 - val_loss: 0.0017
# Epoch 400/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0035 - val_loss: 0.0025
# Epoch 401/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0048 - val_loss: 0.0024
# Epoch 402/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0049 - val_loss: 9.2246e-04
# Epoch 403/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0052 - val_loss: 0.0013
# Epoch 404/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0049 - val_loss: 0.0017
# Epoch 405/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0039 - val_loss: 0.0013
# Epoch 406/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0036 - val_loss: 0.0067
# Epoch 407/1000
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0044 - val_loss: 9.1949e-04
# Epoch 408/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0043 - val_loss: 0.0015
# Epoch 409/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0046 - val_loss: 0.0032

# %%
# 12. Dự báo dữ liệu test, val
train_predict=model.predict(X_train)
y_pred=model.predict(X_test)
y_pred_val=model.predict(X_val)

# In shape của từng tập dư liệu
print(train_predict.shape, y_pred.shape, y_pred_val.shape)
# Out:
# 29/29 [==============================] - 0s 857us/step
# 15/15 [==============================] - 0s 1ms/step
# 5/5 [==============================] - 0s 2ms/step
# (927, 1) (462, 1) (153, 1)

# %%
# 13. In shape của từng tập dư liệu y real
print(y_train.shape, ytest.shape, yval.shape)
# Out:
# (927,) (462,) (153,)

# %%
# 14. Chuẩn hóa dữ liệu y_pred, y_pred_val
train_predict=scaler.inverse_transform(train_predict)
y_pred=scaler.inverse_transform(y_pred)
y_pred_val=scaler.inverse_transform(y_pred_val)

# in head
print(train_predict[:5])
# Out:
# [[3408.7866]
#  [5020.054 ]
#  [5574.7617]
#  [4623.9014]
#  [4527.617 ]]

# %%
# 15. Chuẩn hóa ngược lại yval và ytest và y_train sau khi đã reshape
y_train = y_train.reshape(y_train.shape[0],1)
ytest = ytest.reshape(ytest.shape[0],1)
yval = yval.reshape(yval.shape[0],1)

y_train=scaler.inverse_transform(y_train)
ytest=scaler.inverse_transform(ytest)
yval=scaler.inverse_transform(yval)

#in head
print(y_train[:5])
# Out:
# [[3836.741211]
#  [3857.717529]
#  [3845.19458 ]
#  [4076.632568]
#  [4025.248291]]

# %%
# 16. Đánh giá độ chính xác thuật toán bằng MAE va RMSE
import math
from sklearn.metrics import mean_squared_error, mean_absolute_error


print('Train Mean Absolute Error:', mean_absolute_error(y_train, train_predict[:,0]))
print('Test Mean Absolute Error:', mean_absolute_error(ytest, y_pred[:,0]))
print('Val Mean Absolute Error:', mean_absolute_error(yval, y_pred_val[:,0]))
print('Train Root Mean Squared Error:',np.sqrt(mean_squared_error(y_train, train_predict[:,0])))
print('Test Root Mean Squared Error:',np.sqrt(mean_squared_error(ytest, y_pred[:,0])))
print('Val Root Mean Squared Error:',np.sqrt(mean_squared_error(yval, y_pred_val[:,0])))
# Out:
# Train Mean Absolute Error: 1729.5756558446265
# Test Mean Absolute Error: 2928.5367633319806
# Val Mean Absolute Error: 1166.6083732822713
# Train Root Mean Squared Error: 2416.641202870134
# Test Root Mean Squared Error: 3635.873021245231
# Val Root Mean Squared Error: 1467.353438269185

# %%
# 17. Đánh giá model bằng MAPE
def mean_absolute_percentage_error(y_true, y_pred):
    return numpy.mean(numpy.abs((y_true - y_pred) / y_true)) * 100

print('Train Mean Absolute Percentage Error:', mean_absolute_percentage_error(y_train[:,0], train_predict[:,0]))
print('Test Mean Absolute Percentage Error:', mean_absolute_percentage_error(ytest[:,0], y_pred[:,0]))
print('Val Mean Absolute Percentage Error:', mean_absolute_percentage_error(yval[:,0], y_pred_val[:,0]))
print('Train Score: %.2f MAPE' % (mean_absolute_percentage_error(y_train[:,0], train_predict[:,0])))
print('Test Score: %.2f MAPE' % (mean_absolute_percentage_error(ytest[:,0], y_pred[:,0])))
print('Val Score: %.2f MAPE' % (mean_absolute_percentage_error(yval[:,0], y_pred_val[:,0])))
# Out:
# Train Mean Absolute Percentage Error: 14.261887526897862
# Test Mean Absolute Percentage Error: 7.125917299555466
# Val Mean Absolute Percentage Error: 5.531249849095458
# Train Score: 14.26 MAPE
# Test Score: 7.13 MAPE
# Val Score: 5.53 MAPE

# %%
# 18. Lấy time_step ngày cuối cùng của dữ liệu train để dự đoán 30 ngày tiếp theo
x_input = val_data[-time_step:].reshape(-1, 1)   #[-time_step:] lấy time_step phần tử cuối cùng của dữ liệu
print("x_input.shape = ", x_input.shape)

# Dự đoán 30 ngày tiếp theo
lst_output = []

i = 1  # Biến đếm để dừng vòng lặp while
while(i <= 30):
    print("-----------------")
    # Đưa về mảng 1 chiều
    list_input = x_input.reshape(1, -1)[0]
    # in ra x_input của ngày thứ i trong 30 ngày tiếp theo
    print("day ", i, " have input = ", list_input)

    # Dự đoán giá đóng của ngày tiếp theo
    x_input = x_input.reshape(1, time_step, 1) # reshape lại về dạng (1, time_step, 1)
    yhat = model.predict(x_input, verbose=0) # dự đoán giá đóng của ngày tiếp theo

    # in ra giá đóng của ngày thứ i trong 30 ngày tiếp theo
    print("day ",i," have output = ", yhat[0][0])

    # thêm giá đóng của ngày thứ i vào lst_output
    lst_output.append(yhat[0][0])

    # Xóa phần tử đầu tiên x_input
    x_input = np.delete(x_input, 0)
    # thêm yhat vào x_input
    x_input = np.append(x_input, yhat[0][0])
    # Tăng biến đếm lên 1
    i = i + 1
# Out:
# x_input.shape =  (2, 1)
# -----------------
# day  1  have input =  [0.38390378 0.39083755]
# day  1  have output =  0.3568756
# -----------------
# day  2  have input =  [0.39083755 0.3568756 ]
# day  2  have output =  0.35703534
# -----------------
# day  3  have input =  [0.3568756  0.35703534]
# day  3  have output =  0.31593198
# -----------------
# day  4  have input =  [0.35703534 0.31593198]
# day  4  have output =  0.3189633
# -----------------
# day  5  have input =  [0.31593198 0.31896329]
# day  5  have output =  0.29954392
# -----------------
# day  6  have input =  [0.31896329 0.29954392]
# day  6  have output =  0.2876786
# -----------------
# day  7  have input =  [0.29954392 0.2876786 ]
# day  7  have output =  0.2799941
# -----------------
# day  8  have input =  [0.2876786 0.2799941]
# day  8  have output =  0.28352064
# -----------------
# day  9  have input =  [0.2799941  0.28352064]
# day  9  have output =  0.2884153
# -----------------
# day  10  have input =  [0.28352064 0.28841531]
# day  10  have output =  0.25685772
# -----------------
# day  11  have input =  [0.28841531 0.25685772]
# day  11  have output =  0.26884896
# -----------------
# day  12  have input =  [0.25685772 0.26884896]
# day  12  have output =  0.24145958
# -----------------
# day  13  have input =  [0.26884896 0.24145958]
# day  13  have output =  0.23309994
# -----------------
# day  14  have input =  [0.24145958 0.23309994]
# day  14  have output =  0.22553626
# -----------------
# day  15  have input =  [0.23309994 0.22553626]
# day  15  have output =  0.21552797
# -----------------
# day  16  have input =  [0.22553626 0.21552797]
# day  16  have output =  0.23271458
# -----------------
# day  17  have input =  [0.21552797 0.23271458]
# day  17  have output =  0.19911794
# -----------------
# day  18  have input =  [0.23271458 0.19911794]
# day  18  have output =  0.20170961
# -----------------
# day  19  have input =  [0.19911794 0.20170961]
# day  19  have output =  0.17837915
# -----------------
# day  20  have input =  [0.20170961 0.17837915]
# day  20  have output =  0.20247126
# -----------------
# day  21  have input =  [0.17837915 0.20247126]
# day  21  have output =  0.19724071
# -----------------
# day  22  have input =  [0.20247126 0.19724071]
# day  22  have output =  0.20447172
# -----------------
# day  23  have input =  [0.19724071 0.20447172]
# day  23  have output =  0.1907651
# -----------------
# day  24  have input =  [0.20447172 0.1907651 ]
# day  24  have output =  0.16199246
# -----------------
# day  25  have input =  [0.1907651  0.16199246]
# day  25  have output =  0.19457005
# -----------------
# day  26  have input =  [0.16199246 0.19457005]
# day  26  have output =  0.20478521
# -----------------
# day  27  have input =  [0.19457005 0.20478521]
# day  27  have output =  0.18659455
# -----------------
# day  28  have input =  [0.20478521 0.18659455]
# day  28  have output =  0.21247786
# -----------------
# day  29  have input =  [0.18659455 0.21247786]
# day  29  have output =  0.19006026
# -----------------
# day  30  have input =  [0.21247786 0.19006026]
# day  30  have output =  0.18365721

# %%
# 19.In ra 30 ngày tiếp theo
print(lst_output)
# Out:
# [0.3568756, 0.35703534, 0.31593198, 0.3189633, 0.29954392, 0.2876786, 0.2799941, 0.28352064, 0.2884153, 0.25685772, 0.26884896, 0.24145958, 0.23309994, 0.22553626, 0.21552797, 0.23271458, 0.19911794, 0.20170961, 0.17837915, 0.20247126, 0.19724071, 0.20447172, 0.1907651, 0.16199246, 0.19457005, 0.20478521, 0.18659455, 0.21247786, 0.19006026, 0.18365721]

# %%
# 20. Tạo mảng index tương ứng với các ngày
days = np.array(range(len(df), len(df) + len(lst_output)))

# Vẽ biểu đồ
plt.figure(figsize=(20,10))
plt.plot(days, lst_output, c='r', label='Next 30 days')
plt.plot(df1, c='black', label='Real data')
plt.show()

# %%
# 21.vẽ next 30 days
plt.figure(figsize=(20,10))
plt.plot(days, lst_output, c='r', label='Next 30 days')
plt.show()

# %%
# 22.Chuẩn hóa dữ liệu và chuyển đổi các giá trị dự đoán trở lại đơn vị ban đầu
train_data_inverse=scaler.inverse_transform(np.array(train_data).reshape(-1, 1))
test_data_inverse=scaler.inverse_transform(np.array(test_data).reshape(-1, 1))
val_data_inverse=scaler.inverse_transform(np.array(val_data).reshape(-1, 1))
next_30_days_inverse=scaler.inverse_transform(np.array(lst_output).reshape(-1, 1))

# in dữ liệu
print(train_data_inverse[:5])
print(test_data_inverse[:5])
print(val_data_inverse[:5])
print(next_30_days_inverse[:5])
# Out:
# [[3843.52002 ]
#  [3943.409424]
#  [3836.741211]
#  [3857.717529]
#  [3845.19458 ]]
# [[30817.83203]
#  [29807.34766]
#  [32110.69336]
#  [32313.10547]
#  [33581.55078]]
# [[20285.83594]
#  [20595.35156]
#  [20818.47656]
#  [20635.60352]
#  [20495.77344]]
# [[26299.236]
#  [26309.486]
#  [23671.992]
#  [23866.504]
#  [22620.414]]

# %%
# 23 .vẽ y_train nối với ytest và y_val với index tương ứng

train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
test_data_index = pd.RangeIndex(start=train_size, stop=train_size+test_size, step=1)
val_data_index = pd.RangeIndex(start=train_size+test_size, stop=train_size+test_size+val_size, step=1)
predict30_data_index = pd.RangeIndex(start=train_size+test_size+val_size, stop=train_size+test_size+val_size+30, step=1)

train_predict_index = pd.RangeIndex(start=0, stop=train_predict.shape[0], step=1)
y_pred_index = pd.RangeIndex(start=train_size+(train_size-train_predict.shape[0]), stop=train_size+(train_size-train_predict.shape[0])+y_pred.shape[0], step=1)
y_pred_val_index = pd.RangeIndex(start=train_size+(train_size-train_predict.shape[0])+y_pred.shape[0]+(val_size-y_pred_val.shape[0]), stop=train_size+(train_size-train_predict.shape[0])+y_pred.shape[0]+y_pred_val.shape[0]+(val_size-y_pred_val.shape[0]), step=1)
plt.figure(figsize=(20,10))
plt.grid(True)
plt.plot(train_data_index, train_data_inverse,  label='Train data')
plt.plot(test_data_index, test_data_inverse, label='Test data')
plt.plot(val_data_index, val_data_inverse,  label='Val data')
plt.plot(predict30_data_index, next_30_days_inverse, label='Predict 30 days')
plt.plot(y_pred_index, y_pred, label='Test predict')
plt.plot(y_pred_val_index, y_pred_val,  label='Val predict')
# trục x là giá trị của cột Close time của df1
plt.xticks(np.arange(0, len(df1), 100), df['Date'][0:len(df):100])
plt.xticks(rotation=60)
plt.legend()
plt.show()

# %%
# PHẦN THÊM : Đánh giá bằng R-Squared
from sklearn.metrics import r2_score
r_squared = r2_score(ytest, y_pred)
print("Test_R-squared: ", r_squared)
r_squared = r2_score(yval, y_pred_val)
print("Val_R-squared: ", r_squared)
# Out:
# Test_R-squared:  0.925729833613183
# Val_R-squared:  0.8381169191407603
